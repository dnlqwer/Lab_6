# %%
# !pip install ipython --upgrade
# Out:
# Requirement already satisfied: ipython in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (8.7.0)
# Requirement already satisfied: backcall in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from ipython) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from ipython) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from ipython) (2.13.0)
# Requirement already satisfied: decorator in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from ipython) (0.18.1)
# Requirement already satisfied: colorama in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: traitlets>=5 in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from ipython) (5.5.0)
# Requirement already satisfied: stack-data in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from ipython) (0.6.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from ipython) (3.0.32)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython) (0.2.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython) (1.2.0)
# Requirement already satisfied: pure-eval in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython) (2.1.0)
# Requirement already satisfied: six in c:\users\daniiladmin\appdata\local\programs\python\python39\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)
# WARNING: You are using pip version 21.2.3; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\DaniilAdmin\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    
    PER,
    NamesExtractor,
    DatesExtractor,
    MoneyExtractor,
    AddrExtractor,

    Doc
)

segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)
dates_extractor = DatesExtractor(morph_vocab)
money_extractor = MoneyExtractor(morph_vocab)
addr_extractor = AddrExtractor(morph_vocab)

text = open("Для обучения.txt",encoding="utf-8").read()
doc = Doc(text)
doc
# Out:
# Doc(text='ПРИГОВОР\\nИМЕНЕМ  РОССИЙСКОЙ ФЕДЕРАЦИИ\\n01 дека...)

# %%
from IPython.core.display_functions import display

doc.segment(segmenter)
display(doc)
display(doc.sents[:2])
display(doc.tokens[:5])
# Out:
# Doc(text='ПРИГОВОР\\nИМЕНЕМ  РОССИЙСКОЙ ФЕДЕРАЦИИ\\n01 дека..., tokens=[...], sents=[...])
# [DocSent(stop=2006, text='ПРИГОВОР\\nИМЕНЕМ  РОССИЙСКОЙ ФЕДЕРАЦИИ\\n01 дека..., tokens=[...]),
#  DocSent(start=2007, stop=6145, text='\\nВо исполнение своего совместного преступного п..., tokens=[...])]
# [DocToken(stop=8, text='ПРИГОВОР'),
#  DocToken(start=8, stop=9, text='\\'),
#  DocToken(start=9, stop=10, text='n'),
#  DocToken(start=10, stop=16, text='ИМЕНЕМ'),
#  DocToken(start=18, stop=28, text='РОССИЙСКОЙ')]

# %%
doc.tag_morph(morph_tagger)
doc.parse_syntax(syntax_parser)
display(doc.tokens[:5])
# Out:
# [DocToken(stop=8, text='ПРИГОВОР', id='1_1', head_id='1_317', rel='nsubj', pos='NOUN', feats=<Inan,Nom,Masc,Sing>),
#  DocToken(start=8, stop=9, text='\\', id='1_2', head_id='1_1', rel='punct', pos='PUNCT'),
#  DocToken(start=9, stop=10, text='n', id='1_3', head_id='1_1', rel='appos', pos='ADP'),
#  DocToken(start=10, stop=16, text='ИМЕНЕМ', id='1_4', head_id='1_62', rel='appos', pos='PROPN', feats=<Anim,Gen,Masc,Sing>),
#  DocToken(start=18, stop=28, text='РОССИЙСКОЙ', id='1_5', head_id='1_6', rel='amod', pos='ADJ', feats=<Gen,Pos,Fem,Sing>)]

# %%
doc.tag_ner(ner_tagger)
display(doc.spans[:5])
# Out:
# [DocSpan(start=129, stop=164, type='LOC', text='Москва\\nПреображенский районный суд', tokens=[...]),
#  DocSpan(start=165, stop=171, type='LOC', text='Москвы', tokens=[...]),
#  DocSpan(start=188, stop=203, type='PER', text='Духновской З.А.', tokens=[...]),
#  DocSpan(start=219, stop=233, type='PER', text='Горшковой А.А.', tokens=[...]),
#  DocSpan(start=274, stop=288, type='PER', text='Давыдовой Д.Е.', tokens=[...])]

# %%
doc.ner.print()
# Out:
# ПРИГОВОР\nИМЕНЕМ  РОССИЙСКОЙ ФЕДЕРАЦИИ\n01 декабря 2016 года
#
# Москва\nПреображенский районный суд Москвы в составе судьи Духновской
# LOC──────────────────────────────── LOC───                 PER────────
# З.А., при секретаре Горшковой А.А., с участием государственных
# ────                PER───────────
# обвинителей Давыдовой Д.Е., Дудукова М.Ю., Чубенко А.А., подсудимого
#             PER───────────  PER──────────  PER─────────
# ************а А.А., его защитников – адвокатов Попова А.В.,
#               PER─                             PER────────
# Колокольниковой Е.В., рассмотрев в открытом судебном заседании
# PER─────────────────
# уголовное дело по обвинению:\n************ ****** **************, **
# ** **** года рождения, уроженца г. Москвы, гражданина РФ,
#                                    LOC───             LO
# зарегистрированного по адресу: *****************, со средне-
# специальным образованием, холостого, не работающего, не судимого,  в
# совершении преступления, предусмотренного ч. 3 ст. 30, п.«г» ч. 4 ст.
# 228-1 УК РФ, \nУСТАНОВИЛ:\n************ ****** ******** совершил
#          LO
# покушение на незаконный сбыт наркотических средств, то есть умышленные
#  действия, непосредственно направленные на незаконный сбыт
# наркотических средств, совершенные группой лиц по предварительному
# сговору, в крупном размере, при этом преступление не было доведено до
# конца по не зависящим от него обстоятельствам, а именно:\nТак
# ************ А.А., с целью быстрого и незаконного материального
# обогащения, из корыстных побуждений, имея преступный умысел,
# направленный на незаконный сбыт наркотических средств группой лиц по
# предварительному сговору, в крупном размере, осознавая общественную
# опасность последствий своих действий и желая их наступления, в
# нарушение ст. ст. 5, 8, 14, 20 и 24 Федерального Закона РФ от 8 января
#                                                         LO
#  1998 года № 3-ФЗ «О наркотических средствах и психотропных
# веществах», в неустановленное время и месте, в период до 17 часов 59
# минут 16 сентября 2015 года, вступил в предварительный преступный
# сговор с неустановленными соучастниками, с целью незаконного
# приобретения и последующего умышленного и незаконного сбыта
# наркотических средств, в крупном размере, распределили между собой
# преступные роли каждого и разработали преступный план. \nВо исполнение
#  своего совместного преступного плана, согласно распределению ролей,
# один из его неустановленных соучастников, в неустановленном время и
# месте, в период до 17 часов 59 минут 16 сентября 2015 года, при
# неустановленных обстоятельствах, в нарушение Федерального закона РФ от
#                                                                  LO
#  8 января 1998 года № 3-ФЗ «О наркотических средствах и психотропных
# веществах» незаконно приобрел у неустановленного  лица наркотическое
# средство – героин, в крупном размере, расфасованное в сто пятьдесят
# один сверток из полимерного материала общей массой 293,25 г.,
# упакованные в сверток из полимерного материала с веществом, после
# чего, второй неустановленный соучастник ************а А.А., продолжая
#                                                       PER─
# реализовывать совместный с последним преступный умысел, поместил
# указанный сверток с наркотическим средством в тайник, оборудованный
# возле одиннадцатого дерева от начала зеленого забора на парковке,
# возле ресторана «Чайхона» по адресу: г.Москва, ул.Первомайская, д.
#                  ORG────               LOC───
# 106а, о месте нахождения которого сообщил ************у А.А. в ходе
#                                                         PER─
# телефонного разговора первый неустановленный соучастник.\nПродолжая
# реализовывать совместный с соучастниками преступный умысел, в
# совместных с соучастниками интересах, ************ А.А. 16 сентября
#                                                    PER─
# 2015 года, в 17 часов 59 минут прибыл по вышеуказанному адресу, где
# забрал из вышеуказанного тайника сверток со ста пятьюдесятью одним
# свертком из полимерного материала, с находящимся внутри каждого
# свертка наркотическим средством - героин, общей массой 293,25 г., о
# чем сообщил в ходе телефонного разговора своему первому
# неустановленному соучастнику, после чего ************ А.А. убрал
#                                                       PER─
# вышеуказанный сверток с наркотическим средством – героин, в левый
# карман джинсовых брюк одетых на нём, которое хранил при себе, и данное
#  наркотическое средство по указанию своего первого неустановленного
# соучастника, с целью дальнейшего сбыта указанного наркотического
# средства неустановленным лицам через «закладку» должен был направиться
#  по адресу, где совместно и согласованно, по указанию второго,
# неустановленного соучастника, планировал поместить наркотические
# средства в «закладки» в неустановленных местах, однако ************
# А.А. и его неустановленные соучастники не смогли осуществить свой
# PER─
# преступный умысел до конца, по не зависящим от них обстоятельствам,
# так как в 18 часов 10 минут 16 сентября 2015 года ************ А.А.
#                                                                PER─
# был задержан сотрудниками 2 отдела Службы по ВАО ФСКН России по
#                                    ORG────── LOC ORG─ LOC───
# г.Москве в ходе проведенного оперативно – розыскного мероприятия
#   LOC───
# «Наблюдение» по адресу: г.Москва, ул.Первомайская, д. 106а. \nДалее,
#  ORG───────               LOC───
# 16 сентября 2015 года, в период времени с 19 часов 25 минут по 20
# часов 10 минут, в помещении Службы по ВАО ФСКН России по г. Москве,
#                             ORG───    LOC ORG─ LOC───       LOC───
# расположенном по адресу: г. Москва, ул. Буженинова, д. 12, в ходе
#                             LOC───
# проведения личного досмотра, из левого кармана джинсовых штанов,
# одетых на ************е А.А., был обнаружен и изъят сверток из
#                         PER─
# полимерного материала, внутри которого находился 151 (сто пятьдесят
# один) расфасованный в полимерный материал сверток, с веществом в виде
# порошка и комков внутри каждого свертка, которое, согласно заключению
# эксперта №  Э-1/2317-15 от 16 октября 2015 года является наркотическим
#  средством – героин, и которое, согласно Постановлению Правительства
# Российской Федерации от 30 июня 1998 года № 681 «Об утверждении
# LOC─────────────────
# перечня наркотических средств, психотропных веществ и их прекурсоров,
# подлежащих контролю в Российской Федерации» (в редакции постановления
#                       LOC─────────────────
# Правительства Российской Федерации от 1 апреля 2016 года № 256),
# ORG────────── LOC─────────────────
# является наркотическим средством и входят в список наркотических
# средств, оборот которых в Российской Федерации запрещен, общей массой
#                           LOC─────────────────
# 293,25 г. из ста пятидесяти одного свертка, что согласно Постановлению
#  Правительства РФ от 1 октября 2012 года № 1002 «Об утверждении
#                LO
# значительного, крупного и особо крупного размеров наркотических
# средств и психотропных веществ, а также значительного, крупного и
# особо крупного размеров для растений, содержащих наркотические
# средства или психотропные вещества, либо их частей, содержащих
# наркотические средства или психотропные вещества, для целей статей
# 228, 228¹, 229 и 229¹ УК РФ», является крупным размером. \nТаким
#                          LO
# образом, ************ А.А. и его неустановленные соучастники, действуя
#                       PER─
#  совместно и согласованно, не довели свой совместный преступный
# умысел, направленный на незаконный сбыт наркотических средств, в
# крупном размере до конца, по не зависящим от них обстоятельствам, так
# как ************ А.А. был задержан сотрудниками 2 отдела Службы по ВАО
#                  PER─                                    ORG────── LOC
#  ФСКН России по г. Москве в ходе проведенного оперативно – розыскного
#  ORG─ LOC───       LOC───
# мероприятия «Наблюдение» по адресу: г. Москва, ул. Первомайская, д.
#              ORG───────                LOC───
# 106а, и вышеуказанное наркотическое средство было изъято в ходе
# проведения личного досмотра ************а А.А.\nДопрошенный в судебном
#                                           PER──────────────
#  заседании подсудимый вину признал частично, подтвердил фактические
# обстоятельства, изложенные выше, показал, что приобрел и хранил для
# собственного употребления наркотическое средство общим весом 293,25
# г., которое 16 сентября 2015 года было обнаружено и изъято при
# изложенных обстоятельствах,  отрицал умысел на покушение на сбыт.
# \nСуд, проведя судебное следствие, выслушав судебные прения и
# последнее слово подсудимого, считает, что в судебном заседании  вина
# ************а А.А. в инкриминируемом преступлении доказана следующими
#               PER─
# исследованными в судебном заседании доказательствами:\n- показаниями
# ************а А.А. на предварительном следствии, согласно которым
#               PER─
# извлек из закладки  сверток  с героином  массой 293,25 г., с целью
# дальнейшего сбыта, которое 16 сентября 2015 года было обнаружено и
# изъято при изложенных обстоятельствах;\n- показаниями свидетелей
# Биткова А.Ю.  и Орел И.В., понятых, в основном аналогичными, согласно
# PER─────────    PER──────
# которым 16 сентября 2015 года у ************а А.А. при личном досмотре
#                                               PER─
#   изъяты: из левого кармана джинс - полимерный сверток со 151
# свертками из полиэтилена, с веществом, мобильные телефоны «Самсунг» и
#                                                            ORG────
# «Сони Эриксон»,  сим-карты, шприц, два пузырька. ************ А.А.
#                                                               PER─
# пояснил, что в 151 свертках - наркотическое средство, героин, которое
# извлек из закладки  с целью  сбыта. Процедура досмотра снималась на
# видеокамеру;\n- показаниями свидетеля Русинова А.А., согласно которым
#                                       PER──────────
# 16 сентября 2015 года, в вечернее время, он, Русинов А.А., и
#                                              PER─────────
# ************ А.А., по предложению последнего,  подошли к дому 106 по
#              PER─
# ул. Первомайской г.Москвы,  ресторану  «Чайхана», где  ************
#                    LOC───               ORG────
# А.А., подняв что-то около дерева, положил в левый карман джинс. Около
# PER─
# дома 106А по ул. Первомайская г. Москвы были задержаны полицией,
#                                  LOC───
# доставлены  по адресу: г. Москва, ул. Буженинова, д.12, где проведен
#                           LOC───
# личный досмотр, получены срезы ногтевых пластин, смывы;\n- показаниями
#  свидетелей Прасолова Д.А., Кормилицына Д.А., Лукашенко А.А.,
#             PER───────────  PER─────────────  PER───────────
# полицейских, в основном аналогичными, согласно которым 16 сентября
# 2015 года в рамках ОРМ «Наблюдение» по адресу: г. Москва, ул.
#                    ORG─────────────               LOC───
# Первомайская, д. 106а задержан ************ А.А. В ходе досмотра у
# ************а А.А. изъяты: из левого кармана джинс полимерный сверток
#               PER─
# со 151 свертками из полиэтилена, с веществом, также изъяты мобильные
# телефоны «Самсунг» и «Сони Эриксон», сим-карты, шприц, два пузырька.
#           ORG────
# ************ А.А. пояснил, что в 151 свертке наркотическое средство -
#              PER─
# героин, которое извлек из закладки  с целью  сбыта, мобильные телефоны
#  принадлежат ему, ************у А.А., рюкзак - Русинову А.А. Лукашенко
#                                 PER─           PER────────────────────
#  А.А. выдал Кормилицыну Д.А. видеокамеру. При осмотре  обнаружен
#  PER─       PER─────────────
# видеофайл с личным досмотром ************а А.А.;\n- протоколом очной
#                                            PER─
# ставки между обвиняемым и свидетелем Русиновым А.А., в ходе проведения
#                                      PER───────────
#  которой ************ А.А. дал показания аналогичные ранее данным на
#                       PER─
# предварительном следствии, Русинов А.А. – аналогичные изложенным выше
#                            PER─────────
#   (л.д. 82-86);\n- актом досмотра и изъятия, согласно которым 16
# сентября 2015 года, по адресу: г. Москва, ул. Буженинова д. 12, в
#                                   LOC───
# присутствии понятых, в ходе проведения личного досмотра из левого
# кармана джинс ************а А.А. изъят сверток  со 151 свертками из
#                             PER─
# полимерного материала, с веществом в виде порошка светлого цвета,
# также изъяты мобильные телефоны «SONY ERICSSON»,  IMEI:
#                                  ORG──────────
# 3559901-570169-9 с сим-картой оператора сотовой связи «Билайн»,
#                                                        ORG───
# «Samsung»,  IMEI: 357795/05/044571/1 с сим-картой оператора сотовой
#  ORG────
# связи «Мегафон» (л.д.15-20);\n- актом осмотра и копирования видео-
#        ORG────
# материалов, согласно которого по адресу: г.Москва, ул.Буженинова, д.12
#                                            LOC───
#  Лукашенко А.А. выдана цифровая видеокамера Panasonic HC-V11ЕЕ, камера
#  PER───────────                             ORG──────
#  осмотрена, обнаруженная информация перекопирована на диск DVD-R (л.д.
#  25);\n- протоколами осмотра предметов, согласно которым осмотрены:
# конверты и полимерный пакет, поступившие с экспертизы, в ходе осмотра
# не вскрывались; конверты с мобильными телефонами, шприцем, два
# пузырька, диск формата DVD R № MFP 696SKO222264 с видеозаписью личного
#  досмотра ************а А.А.; компакт диски «Smart Track» CD-R 52х  с
#                         PER─
# записями ОРМ «ПТП»   (л.д.106-108,114-115,160-168);\n- заключением
#          ORG──────
# химической судебной экспертизы №  Э-1/2317-15, согласно которому
# вещества в виде порошка и комков светло-бежевого цвета из 151
# упаковки, изъятые у ************а А.А., - наркотическое средство,
#                                   PER─
# героин, массой 293,15 г. После экспертизы - масса 290,13 г.
# (л.д.97-103);\n- рапортом об обнаружении признаков преступления в
# действиях ************а А.А. (л.д. 3);\n- справкой об исследовании №
#                         PER─
# И-1/1657, согласно которой в пакете: 151  сверток из полимерного
# материала, в каждом   -  сверток  с веществом в виде порошка и комков.
#  На исследование отбиралась представительная проба по 0,01 г от десяти
#  свертков. Общая масса исследованных веществ 20,05 г. Установлено, что
#  в составе исследуемых веществ содержится героин (л.д. 51);\n-
# протоколом осмотра места происшествия, согласно которого осмотрен
# участок местности по адресу: г. Москва, ул. Первомайская, д. 106а,
#                                 LOC───
# возле одиннадцатого дерева от начала забора на парковке ресторана
# «Чайхана», ничего не изымалось (л.д. 205-206);\n- постановлением о
#  ORG────
# признании и приобщении в качестве вещественных доказательств: героина,
#  изъятого в ходе личного досмотра ************а А.А, срезов ногтевых
#                                                 PER
# пластин, смывов, компакт-дисков, мобильный телефон (л.д.109-110,
# 117-118).\nОценивая вышеприведенные доказательства в их совокупности и
#  признавая их относимыми, допустимыми доказательствами по делу,
# существенных противоречий не содержащих, достаточными, суд приходит к
# выводу о доказанности вины ************а А.А.  в совершении
#                                          PER─
# преступления, описанного в приговоре выше, в связи с этим суд
# квалифицирует действия ************а А.А. по ч.3 ст.30, п.«г» ч.4
#                                      PER─
# ст.228-1 УК РФ, как покушение на незаконный сбыт наркотических
#             LO
# средств, то есть умышленные действия, непосредственно направленные на
# незаконный сбыт наркотических средств, совершенные группой лиц по
# предварительному сговору, в крупном размере, при этом, преступление не
#  было доведено до конца по не зависящим от него обстоятельствам.\nПри
# этом суд не доверяет показаниям подсудимого в судебном заседании в
# части отрицания умысла на сбыт, считает, что показания в этой части
# опровергаются показаниями подсудимого на предварительном следствии,
# которым у суда оснований не доверять нет, так как они последовательны,
#  непротиворечивы, и согласуются со всеми исследованными в судебном
# заседании доказательствами. \nКроме того о наличии в действиях
# ************а А.А. умысла на сбыт наркотического средства по мнению
#               PER─
# суда свидетельствует объем изъятого наркотического средства, его
# расфасовка, то, что изъятие произошло в рамках ОРМ. \nПри назначении
#                                                ORG
# наказания суд учитывает характер и степень общественной опасности
# совершенного преступления, отнесенного законодателем к категории особо
#  тяжких, и данные о личности подсудимого, учитывая
# следующее.\nПодсудимый ************ А.А. не судим, вину частично
#                                     PER─
# признал,  страдает заболеваниями, мать пенсионерка, ветеран труда,
# также страдает заболеваниями, что суд признает в качестве
# обстоятельств, смягчающих наказание.\nОбстоятельств, отягчающих
# наказание, судом не установлено.\nС учетом конкретных обстоятельств
# дела, данных о личности подсудимого, суд приходит к выводу, что
# исправление ************а А.А. возможно только в условиях изоляции от
#                           PER─
# общества и, назначая наказание в виде лишения свободы, не усматривает
# оснований для применения ст.ст.15 ч.6,64,73 УК РФ.\nСуд, учитывая
#                                                LO
# смягчающие обстоятельства, полагает нецелесообразным назначение
# дополнительного наказания в виде штрафа.\nУчитывая, что подсудимый не
# работает, оснований для назначения дополнительного наказания в виде
# лишения права занимать определенные должности или заниматься
# определенной деятельностью, суд не усматривает.\nМестом отбывания
# наказания суд определяет исправительную колонию строгого режима. \nПри
#  постановлении приговора суд считает необходимым распорядиться судьбой
#  вещественных доказательств.\nНа основании изложенного и
# руководствуясь ст.ст.296-299, 307-309 УПК РФ,
#                                           LO
# суд\nПРИГОВОРИЛ:\n****************** признать виновным в совершении
# преступления, предусмотренного ч.3 ст. 30, п.«г» ч. 4 ст. 228-1 УК РФ
#                                                                    LO
# и  назначить уголовное наказание в виде лишения свободы сроком 10
# (десять) лет, с отбыванием наказания в исправительной колонии строгого
#  режима, с исчислением срока наказания с 01 декабря 2016
# года.\nЗасчитать в срок отбытия наказания срок содержания
# ************а Андрея Александровича  под стражей с  16 сентября 2015
#               PER──────────────────
# года до 01 декабря  2016 года.\nМеру пресечения осужденному
# *************************** до вступления приговора в законную силу
# оставить прежней, – содержание под стражей.\nВещественное
# доказательство: наркотическое средство, конверты, срезы ногтевых
# пластин, смывы, сим карту оператора «Мегафон», - уничтожить; компакт
#                                      ORG────
# диск, - оставить при материалах уголовного дела; мобильный телефон
# «Samsung» IMEI:357795/05/044571/1, - вернуть по принадлежности
#  ORG────
# ************у  А.А.   \n  Приговор может быть обжалован в Московский
#                PER────────────────                        ORG────────
# городской суд в течение 10 дней со дня его провозглашения, осужденным
# ─────────────
# в тот же срок со дня получения им копии приговора. В случае подачи
# апелляционной жалобы осужденный имеет право принять участие в
# рассмотрении дела судом апелляционной инстанции.\n\n\tСудья
#
# Духновская З.А. \n Ключевые слова: политология, история, экономика,
# военный бизнес, социум.\nПервые из существующих частных военных
# компаний (ЧВК) появились во время холодной войны. В то же время
# руководство Соединенных Штатов, Великобритании, Израиля и Южной Африки
#             LOC───────────────  LOC───────────  LOC────   LOC─────────
#  непосредственно способствовало их созданию. ЧВК могли поручать самую
# “грязную” работу (например, свержение законных правительств или
# организацию террористических группировок), а в случае неудачи
# открещиваться от них под предлогом того, что действовали коммерческие
# структуры.\nПосле окончания холодной войны спрос на услуги ЧВК стал
#                                                            ORG
# еще выше, в то время как взрывной рост предложения произошел из-за
# развала вооруженных сил на Западе и на Востоке: многие уволенные
#                            LOC───      LOC────
# военнослужащие вышли на рынок труда. \n К середине 2000-х годов
# количество ЧВК (речь идет о компаниях, оказывающих военные услуги, а
#            ORG
# не занимающихся логистикой) перевалило за сотню, численность их
# сотрудников достигла 2 миллионов человек, общая рыночная капитализация
#  превысила 20 миллиардов долларов, а объем предоставляемых услуг
# составил различные данные, от 60 до 180 миллиардов долларов в год.
# Наиболее известными и крупными ЧВК являются Hulliburton, Blackwater,
#                                ORG          ORG────────  ORG───────
# DynCorp, Logicon, Brown & Root, MPRI, Control Risks, Bechtel,
# ORG────  ORG────                ORG─  ORG──────────  ORG────
# ArmorGroup, Erinys, Sandline International, Международная оборона и
# ORG───────  ORG───  ORG───────────────────  ORG─────────────────────
# безопасность. Их услуги становятся все более разнообразными. Они
# ────────────
# занимаются разминированием, охраной важных объектов, организацией
# доставки различного рода грузов, разработкой планов военного
# строительства и боевого применения вооруженных сил (например, MPRI
# обучала хорватские вооруженные силы, которые осенью 1995 года
# разгромили и ликвидировали Сербскую Краину). В связи с этим
#                            LOC────────────
# официальные международные организации, включая ООН, иногда становятся
#                                                ORG
# работодателями для ЧВК. \n Услуги ЧВК тем более востребованы в
#                    ORG            ORG
# ситуации, когда большинство западных армий совершенно не готовы к
# проведению операций, подразумевающих серьезные потери. Но "частники"
# не считаются с убытками. Их потери не включены в официальную
# статистику стран, что очень удобно с точки зрения пропаганды. А в
# составе частных комитетов безопасности есть граждане и тех стран,
# которые официально не участвуют в войне и даже осуждают ее. Например,
# значительное количество наемников из Германии воюет в Ираке в рядах
#                                      LOC─────         LOC──
# американских и британских ЧВК, хотя немецкое руководство было и
#                           ORG
# остается одним из главных противников этой войны. А недавно стало
# известно, что немецкая частная охранная компания Asgaard German
#                                                  ORG────────────
# Security Group (о которой писали "Известия") направила в Сомали группу
# ──────────────                    ORG─────               LOC───
#  из 100 бойцов, которые будут воевать на стороне самопровозглашенного
# "президента Сомалийской Республики" Галадида Дармана, не получившего
#             LOC───────────────────  PER─────────────
# признания со стороны международного сообщества. \n Многие ЧВК
#                                                           ORG
# стремятся вербовать иностранцев. При этом предпочтение часто отдается
# гражданам Восточной Европы и бывшего СССР, а также развивающихся
#           LOC─────────────           LOC─
# стран, поскольку они отличаются хорошим уровнем подготовки и готовы
# воевать за меньшие деньги, чем граждане западных стран, чьи зарплаты в
#  зонах конфликтов могут достигать 20 тысяч долларов в месяц.
# Содержание наемника, кстати, стоит примерно в 10 раз дороже, чем
# солдата регулярной армии. \n Тот факт, что руководство государства
# формально не несет ответственности ни за потери ЧВК, ни за
#                                                 ORG
# преступления, совершенные их сотрудниками, приводит к их все большему
# вовлечению в войны с регулярными армиями или вместо них. Высокая
# стоимость отходит на второй план. Так, на сегодняшний день в Ираке
#                                                              LOC──
# задействовано более 400 ЧВК, общая численность их личного состава
# превышает 200 тысяч человек, то есть больше, чем войска США и их
#                                                         LOC
# союзников. Потери этих структур, по крайней мере, не меньше, чем у
# регулярных армий, но они не учитываются в официальной статистике. При
# этом ЧВК постоянно становятся участниками разного рода скандалов,
#      ORG
# поскольку их сотрудники ведут себя по отношению к гражданскому
# населению гораздо более жестко, чем "официальные" военнослужащие (в
# Ираке этим особенно славится Blackwater) \n В дополнение к
# LOC──                        ORG───────
# "фактической войне" ЧВК берут на себя все больше и больше
#                     ORG
# вспомогательных функций. Это все виды логистики (включая, например,
# приготовление пищи для военнослужащих и уборку казарм), инженерное
# дело, аэродромное обслуживание, транспортные услуги. В последнее время
#  разведка стала новой сферой деятельности для ЧВК (еще 10 лет назад
#                                               ORG
# такое и представить было невозможно). Таким образом, разработчики
# беспилотников Predator и Global Hawk, активно используемых
# американцами в Ираке и Афганистане, полностью занимаются их
#                LOC──   LOC────────
# обслуживанием и управлением, в том числе непосредственно в боевых
# ситуациях. Офицер регулярной армии только ставит общую задачу. Другие
# ЧВК занимаются сбором и анализом информации о террористических
# ORG
# группировках (в том числе через интернет), предоставляют для
# вооруженных сил услуги переводчиков с восточных языков. \n И
# постепенно количество перешло в качество. Недавно Пентагон обнаружил,
#                                                   ORG─────
# что вооруженные силы США в принципе больше не могут функционировать
#                      LOC
# без частных компаний, без них не может быть проведена даже
# ограниченная военная операция. Например, выяснилось, что поставки
# топлива для группировки союзников в Ираке были приватизированы на
#                                     LOC──
# 100%. Когда-то предполагалось, что привлечение частных собственников
# приведет к экономии военного бюджета. Теперь очевидно, что ситуация
# обратная: их услуги стоят намного дороже, чем если бы
# “государственные” военные выполняли ту же работу самостоятельно. Но,
# видимо, уже слишком поздно. Этот процесс стал необратимым. \n По пути
# создания ЧВК, к тому же действующих в интересах государства, может
#          ORG
# пойти Китай. По крайней мере, об этом говорилось в нашумевшей книге
#       LOC──
# "Китай недоволен", опубликованной год назад и рассматривавшейся как
#  LOC──
# описание плана глобальной военной экспансии КНР. Частные военные
#                                             LOC
# компании, названные в книге "компании по охране безопасности морей",
# должны стать важной частью этого расширения: "Мы можем сказать еще
# более четко: а именно, речь идет об использовании демобилизованных
# военнослужащих, уволившихся из армии. У нас есть такие преимущества,
# как люди и организации, и наши "компании по защите безопасности морей"
#  могут восстановить мир во многих регионах мира, где царят беззаконие
# и беспорядок. Как вы знаете, Китай очень активно занимается
#                              LOC──
# экономической экспансией в Азии и Африке, будет логично, если
#                            LOC─   LOC───
# китайские военные, формально считающиеся "частными владельцами",
# придут за инженерами и рабочими. \n\nВведение \n В истории русского
# народа было две Отечественные войны – 1812 и 1939-1945 годов. Они обе
# являются трагическими в истории России. \n Отечественная война 1812
#                                 LOC───
# года – это война между Французской и Российской империями, которая
#                        LOC────────   LOC─────────────────
# проходила на территории России. Несмотря на превосходство французской
#                         LOC───
# армии, под руководством Наполеона Бонапарта, "русским" войскам удалось
#                         PER────────────────
#  одержать победу, несмотря на огромные потери. \n Более того, русским
# удалось выйти победителями в этом тяжелом противостоянии. \n
# Отечественная война 1812 года произошла вследствие стремления
# Наполеона к мировому господству. До этого ему удалось подчинить почти
# PER──────
# всю Европу. Почему почти? Единственным противником Франции в Европе
#     LOC───                                         LOC────   LOC───
# оставалась Великобритания, которую Наполеон не мог подчинить силой
#            LOC───────────          PER─────
# оружия, но пытался континентальной блокадой. \n Стоит заметить, что в
# 1807 году между Францией и Россией был подписан Тильзитский мирный
#                 LOC─────   LOC────
# договор, по главному пункту которого российский император Александр 1
#                                                           PER──────
# обязывался поддерживать Наполеона в континентальной блокаде
#                         PER──────
# Великобритании. Тем не менее обе стороны понимали, что между Францией
# LOC───────────                                               LOC─────
# и Россией тоже начнётся война, так как было понятно, что Наполеон не
#   LOC────                                                PER─────
# остановится на покорении Европы. \n Именно поэтому страны начали
#                          LOC───
# наращивать свой военный потенциал.\nВ 1812 году Наполеон с Французской
#                                                 PER─────   ORG────────
#  армией, состоящей из 675 тысяч человек, вторгся на территорию
# ───────
# Российской Империи. Так для России и российского народа началась
# LOC───────────────          LOC───
# Отечественная война 1812 года. \n Эта война знаменита многими
# сражениями, но в этой работе речь в основном пойдёт о самом знаменитом
#  сражении - сражение при Бородино, что под Москвой. Эта война и битва
#                          LOC─────          LOC────
# будут рассмотрены с необычной стороны, а именно со стороны французской
#  армии. \n В работе будут присутствовать воспоминания французских
# военнослужащих о войне в России и в частности о Бородинском сражении.
#                          LOC───
# Я считаю, что очень интересно посмотреть на уже давно знакомые всем
# события с другой точки зрения и понять, что ощущали противники и как
# относились к происходящему. Хочу отметить, что воспоминания в основном
#  о Бородинском сражении, так как это самый яркий эпизод войны. \n
# Целью проекта является: посмотреть на события 1812 года глазами
# французов. \n Задачи: \n 1. Оживить память о событиях отечественной
# войны 1812 года. \n 2. Показать воспоминания французских
# военнослужащих. \n  3.Рассказать о нашем земляке - участнике войны
# 1812 года. \n Методы исследования: \n Так как я учусь в одиннадцатом
# классе, я провёл дебаты со своими сверстниками. В классе обучается 19
# человек. Был поставлен вопрос о героизме французских и русских солдат
# во время войны 1812 года и Бородинского сражения в частности. Мы
# столкнулись с не большим спором, результатом, которого стала данная
# диаграмма. Я отношусь к 30% и в подтверждение своей точки зрения я
# приведу в пример слова Французского императора Наполеона Бонапарта. \n
#                                                PER────────────────
#  «Из всех моих сражений самое ужасное то, что я дал под Москвой.
#                                                         LOC────
# Французы показали себя в нем достойными одержать победу, а русские –
# называться непобедимыми». \n Так же мной был проведён поиск и анализ
# информации содержащейся в данной работе. Вся информация,
# представленная в проекте, имеет своё подтверждение в литературе,
# находящейся в литературном списке в конце работы. \n Гипотеза: \n
# Целью работы является, как можно более правдиво рассказать о войне
# 1812 года, затронув при этом документы и воспоминания людей, которые
# непосредственно являлись участниками этой войны. Одним из главных
# источников информации по данной теме является дневник Цезаря Ложье де
#                                                       PER─────────────
# Беллекура, под названием «Дневник офицера великой армии в 1812 году».
# ─────────
# \n Данный источник интересен тем, что писался во время непосредственно
#  самой компании и захватывает, как быт солдат, так и события,
# произошедшие за время той войны.\nТак же в поиске информации
# использовался сборник: «Французы в России: 1812 год по воспоминаниям
#                                    LOC───
# современников-иностранцев». Данный сборник включает в себя отрывки из
# воспоминаний многих военнослужащих французской армии, прошедших войну
# 1812 года, чем собственно и ценен. \n В ходе исследовательской работы
# я столкнулся с очень интересными фактами, которые заинтересовали меня,
#  а именно в деревне Жорновка Тверской области, находилась усадьба
#                     LOC───── LOC─────────────
# Фёдора Фёдоровича Трефорта, генерал-майора, коменданта Твери, которая
# PER───────────────────────                             LOC──
# на сегодняшний день не сохранилась. \n К сожалению, территория усадьбы
#  распродана под дачные участки, но сохранилась церковь. В ходе
# исследования я пообщался с местными жителями, которые утверждают, что
# в период СССР местная церковь была клубом. \n Многие жители даже
#          LOC─
# сегодня наслышаны о том, что данная территория, когда-то принадлежала
# дворянскому роду Трефортов, член которого принимал участие во всех
#                  PER──────
# наполеоновских войнах. Подтверждением этому является могила,
# расположенная на церковном погосте, за которой ухаживают местные
# жители. \n Часть церкви (алтарь) перед семейным захоронением Трефортов
#                                                              PER──────
#  (вся церковь находится в очень плачевном состоянии), деревня
# Жорновка, Тверская область, 13.02.2021 г. \n Подходы к определению
# LOC─────  LOC─────────────
# англицизмов\n 12 июня 1812 года (по старому стилю) французская армия
# переправившись, через реку Неман в районе города Ковно, вторглась на
#                            LOC──                 LOC──
# территорию Российской Империи. Полумиллионная армия, включавшая в свой
#            LOC───────────────
#  состав не только французов, но и представителей почти всей Европы,
#                                                             LOC───
# окрылённая многочисленными победами и ведомая самим Наполеоном
#                                                     PER────────
# Бонапартом и многочисленными прославленными генералами и маршалами
# ──────────
# начала быстрое продвижение вглубь большой страны. \n Сильными
# сторонами французской армии являлись большая численность, современное
# вооружение, хорошее снабжение, накопленный с годами войн боевой опыт и
#  вера в непобедимость армии. Противостоящая этой силе русская армия на
#  момент начала войны насчитывала лишь одну треть от общего числа
# французской. \n В связи с недавно окончившейся русско-турецкой войной
# 1806-1812 годов, была разделена на три далеко расположенные друг от
# друга группировки (под командованием М. Б. Барклая-де-Толли , П. И.
#                                      PER───────────────────   PER───
# Багратиона и А. П. Тормасова). Александр I находился при штабе армии
# ──────────   PER────────────   PER────────
# Барклая. Первые удары французской армии приняли на себя, размещённые
# PER────
# на западной границе войска 1-вой армии Барклая-де-Толли и 2-ой армии
# Багратиона (всего 153 тысячи солдат). \n Начало войны было успешным
# LOC───────
# для Наполеона и его армии. Уже к 6 часам утра 12 (24) июня 1812 года
#     PER──────
# авангард французской армии вошёл в российский город Ковно, в течение
#                                                     LOC──
# следующих четырёх дней на берег у Ковно было переправлено ещё 220
#                                   LOC──
# тысяч солдат великой армии. \n Спустя пять дней южнее переправилась
# ещё одна группировка в составе 79 тысяч человек, под командованием
# вице-короля Италии Евгения Богарне. Одновременно ещё южнее Неман
#             LOC─── PER────────────                         LOC──
# пересекают ещё 4 корпуса(79 тысяч человек) под общим командованием
# короля Вестфалии Жерома Бонапарта. \n На северном направлении Неман
#        PER───────────────────────                             LOC──
# пересёк отдельный 10-тый корпус под командованием маршала Макдональда
#                                                           PER────────
# (32 тыс. солдат), который был нацелен на Петербург. На южном
#                                          LOC──────
# направлении через Буг начал переправу и вторжение отдельный
#                   LOC
# Австрийский корпус генерала Шварценберга (30—33 тысяч солдат).
# ORG───────────────          PER─────────
# \n\Быстрое продвижение французских войск заставило российскую армию,
# под командованием Барклая-де-Толли, отступать вглубь страны, уклоняясь
#                   PER─────────────
#  от генерального сражения, дабы сохранить силы и соединиться с армией
# Багратиона. В связи с численным перевесом противника встал вопрос о
# LOC───────
# быстром пополнении российской армии. \n Но в российской Империи не
#                                                         LOC────
# было всеобщей воинской повинности, армия набиралась посредству
# рекрутских наборов. Тогда император Александр 1 решился на необычный
#                                     PER──────
# шаг. 6 июля он издал манифест с призывом создать народное ополчение,
# так армия пополнилась людьми и появились первые партизанские отряды.
# \n Армии Барклая и Багратиона встретились под Смоленском в конце июля,
#                    PER───────                 LOC───────
#  достигнув, таким образом, первого стратегического успеха. \n 16
# августа по (новому стилю) французская армия (180 тысяч человек) под
# командованием Наполеона подошла к Смоленску. После соединения русских
#               PER──────           LOC──────
# армий, генералитет начал требовать от главнокомандующего Барклая-де-
#                                                          ORG────────
# Толли генерального сражения. В6 часов утра французская армия начала
# ─────
# штурм Смоленска. \n Русская армия сражалась стойко и бесстрашно, бой
#       LOC──────
# за город шёл два дня. Сражение за Смоленск ознаменовало развёртывание
#                                   LOC─────
# всенародной войны русского народа с неприятелем. Надежда Наполеона на
#                                                  PER──────────────
# молниеносную войну рухнула. После двух дней боёв Барклая-де-Толли
# отвёл войска из горящего города, чтобы избежать лишних потерь и уже
# заранее проигранного кровопролитного сражения. После взятия Смоленска
#                                                             LOC──────
# армия Наполеона двинулась на Москву. \n Между тем затянувшееся
#       LOC──────              LOC───
# отступление подогревала общественное недовольство. Так же сдача
# Смоленска усугубила положение. Поэтому 20 августа (по новому стилю)
# LOC──────
# император Александр 1 подписывает указ о назначении главнокомандующим
#           PER──────
# русскими войсками М.И. Кутузова. \n В то время Кутузову уже был 67-ой
#                   PER──────────                PER─────
# год. Полководец Суворовской школы, обладавший полувековым боевым
#                 ORG──────────────
# опытом, был уважаем как в рядах армии, так и в народе. Но всё же и ему
#  пришлось отступать, дабы выиграть время для сбора все наличных сил.
# \n По политическим и моральным причинам Кутузов не мог избежать
#                                         PER────
# генерального сражения. 3 сентября (по новому стилю) русская армия
# отступила к деревне Бородино. Дальнейшее отступление означало сдачу
#                     LOC─────
# Москвы. Так же французская армия за время наступления понесла потери и
# LOC───
#  сравнялась по численности с российской. Исходя из всех этих фактов,
# Кутузов решил дать генеральное сражение в 125 км от Москвы у деревни
# PER────                                             LOC───
# Бородино. \n 26 августа (7 сентября по новому стилю) 1812 года
# LOC─────
# произошло сражение, навсегда вошедшее в историю нашего народа.
# Бородинское сражение – крупнейшее сражение Отечественной войны 1812
# года между русской и французской армиями. \n Русская армия насчитывала
#  132 тысячи человек (в том числе 21 тысячу ополченцев). Французская
# насчитывала 135 тысяч солдат. План боя был прост- французы штурмуют
# линию из русских укреплений- флешей и редутов (карта поля боя указана
# ниже) \n Воспоминания французов\n Прежде чем поговорить о дальнейших
# событиях войны стоит отметить то, как французы входили в Россию. \n
#                                                          LOC───
# Прибыли в Кальварию. Никто не сомневался более в войне, но никакого
#           LOC──────
# официального приказа нам еще не было объявлено. Мы провели ночь в
# Кальварии, а наутро нам был прочитан приказ: \n «Солдаты! Вторая
# LOC──────
# польская война началась. Первая окончилась Фридландом и Тильзитом!..
#                                            PER───────   PER──────
# \n В Тильзите Россия поклялась быть в вечной дружбе с Францией и
#      LOC───── LOC───                                  LOC─────
# воевать с Англией. Она нарушает теперь свои клятвы; она не желает
#           LOC────
# более давать никакого объяснения своего странного требования, чтобы
# французские орлы не переходили Рейна, оставляя тем самым наших
#                                PER──
# союзников в ее распоряжении... Россия увлекаема роком, ее судьбы
#                                LOC───
# должны совершиться. \n Неужели она думает, что мы выродились? Разве мы
#  уже не солдаты Аустерлица? Она ставит нас между бесчестьем и войной:
#                 PER───────
# выбор ясен. Итак, идем вперед, перейдем Неман и внесем войну на ее
# территорию. \n Вторая война польская будет столь же славной, как и
# первая, но мир, который мы заключим, принесет с собой и гарантию: он
# положит предел тому гибельному влиянию, которое уже 50 лет оказывает
# Россия на дела Европы. Наполеон» \n Как описать впечатление,
# LOC───         LOC───
# произведенное на нас словами нашего вождя? Горделивый трепет волнует
# нас. Скольким победам предшествовали подобные воззвания! Нельзя
# сомневаться, что и нынешнее воззвание окажется таким же
# ...
#    PER────
# мягкий, ласковый, старческий. Мерцалов молчал, не оборачиваясь.— А я
#                               PER─────
# вот ребятишкам знакомым подарочки купил, — продолжал незнакомец (в
# руках у него было несколько свертков). — Да вот по дороге не утерпел,
# сделал круг, чтобы садом пройти: очень уж здесь хорошо.Мерцалов вообще
#                                                        PER─────
#  был кротким и застенчивым человеком, но при последних словах
# незнакомца его охватил вдруг прилив отчаянной злобы. Он резким
# движением повернулся в сторону старика и закричал, нелепо размахивая
# руками и задыхаясь:— Подарочки!.. Подарочки!.. Знакомым ребятишкам
#                      PER──────
# подарочки!.. А я... а у меня, милостивый государь, в настоящую минуту
# мои ребятишки с голоду дома подыхают... Подарочки!.. А у жены молоко
# пропало, и грудной ребенок целый день не ел... Подарочки!..Мерцалов
# ожидал, что после этих беспорядочных, озлобленных криков старик
# поднимется и уйдет, но он ошибся. Старик приблизил к нему свое умное,
# серьезное лицо с седыми баками и сказал дружелюбно, но серьезным
# тоном:— Подождите... не волнуйтесь! Расскажите мне все по порядку и
# как можно короче. Может быть, вместе мы придумаем что-нибудь для вас.В
#  необыкновенном лице незнакомца было что-то до того спокойное и
# внушающее доверие, что Мерцалов тотчас же без малейшей утайки, но
#                        PER─────
# страшно волнуясь и спеша, передал свою историю. Он рассказал о своей
# болезни, о потере места, о смерти ребенка, обо всех своих несчастиях,
# вплоть до нынешнего дня. Незнакомец слушал, не перебивая его ни
# словом, и только все пытливее и пристальнее заглядывал в его глаза,
# точно желая проникнуть в самую глубь этой наболевшей, возмущенной
# души. Вдруг он быстрым, совсем юношеским движением вскочил с своего
# места и схватил Мерцалова за руку. Мерцалов невольно тоже встал.—
#                 PER──────          PER─────
# Едемте! — сказал незнакомец, увлекая за руку Мерцалова. — Едемте
# PER───                                       PER──────
# скорее!.. Счастье ваше, что вы встретились с врачом. Я, конечно, ни за
#  что не могу ручаться, но... поедемте!Минут через десять Мерцалов и
#                                                          PER─────
# доктор уже входили в подвал. Елизавета Ивановна лежала на постели
#                              PER───────────────
# рядом со своей больной дочерью, зарывшись лицом в грязные,
# замаслившиеся подушки. Мальчишки хлебали борщ, сидя на тех же местах.
# Испуганные долгим отсутствием отца и неподвижностью матери, они
# плакали, размазывая слезы по лицу грязными кулаками и обильно проливая
#  их в закопченный чугунок. Войдя в комнату, доктор скинул с себя
# пальто и, оставшись в старомодном, довольно поношенном сюртуке,
# подошел к Елизавете Ивановне. Она даже не подняла головы при его
#           PER───────────────
# приближении.— Ну, полно, полно, голубушка, — заговорил доктор, ласково
#  погладив женщину по спине. — Вставайте-ка! Покажите мне вашу
# больную.И точно так же, как недавно в саду, что-то ласковое и
# убедительное, звучавшее в его голосе, заставило Елизавету Ивановну
#                                                 PER───────────────
# мигом подняться с постели и беспрекословно исполнить все, что говорил
# доктор. Через две минуты Гришка уже растапливал печку дровами, за
#                          PER───
# которыми чудесный доктор послал к соседям, Володя раздувал изо всех
#                                            PER───
# сил самовар, Елизавета Ивановна обворачивала Машутку согревающим
#              PER───────────────              PER────
# компрессом... Немного погодя явился и Мерцалов. На три рубля,
#                                       PER─────
# полученные от доктора, он успел купить за это время чаю, сахару, булок
#  и достать в ближайшем трактире горячей пищи. Доктор сидел за столом и
#  что-то писал на клочке бумажки, который он вырвал из записной книжки.
#  Окончив это занятие и изобразив внизу какой-то своеобразный крючок
# вместо подписи, он встал, прикрыл написанное чайным блюдечком и
# сказал:— Вот с этой бумажкой вы пойдете в аптеку... давайте через два
# часа по чайной ложке. Это вызовет у малютки отхаркивание...
# Продолжайте согревающий компресс... Кроме того, хотя бы вашей дочери и
#  сделалось лучше, во всяком случае пригласите завтра доктора
# Афросимова. Это дельный врач и хороший человек. Я его сейчас же
# PER───────
# предупрежу. Затем прощайте, господа! Дай бог, чтобы наступающий год
# немного снисходительнее отнесся к вам, чем этот, а главное — не
# падайте никогда духом.Пожав руки Мерцалову и Елизавете Ивановне, все
#                                  PER──────   PER───────────────
# еще не оправившимся от изумления, и потрепав мимоходом по щеке
# разинувшего рот Володю, доктор быстро всунул свои ноги в глубокие
#                 PER───
# калоши и надел пальто. Мерцалов опомнился только тогда, когда доктор
#                        PER─────
# уже был в коридоре, и кинулся вслед за ним.Так как в темноте нельзя
# было ничего разобрать, то Мерцалов закричал наугад:— Доктор! Доктор,
#                           PER─────
# постойте!.. Скажите мне ваше имя, доктор! Пусть хоть мои дети будут за
#  вас молиться!И он водил в воздухе руками, чтобы поймать невидимого
# доктора. Но в это время в другом конце коридора спокойный старческий
# голос произнес:— Э! Вот еще пустяки выдумали!.. Возвращайтесь-ка домой
#  скорей!Когда он возвратился, его ожидал сюрприз: под чайным блюдцем
# вместе с рецептом чудесного доктора лежало несколько крупных кредитных
#  билетов...В тот же вечер Мерцалов узнал и фамилию своего неожиданного
#                           PER─────
#  благодетеля. На аптечном ярлыке, прикрепленном к пузырьку с
# лекарством, четкою рукою аптекаря было написано: «По рецепту
# профессора Пирогова».Я слышал этот рассказ, и неоднократно, из уст
# самого Григория Емельяновича Мерцалова — того самого Гришки, который в
#        PER────────────────────────────               PER───
#  описанный мною сочельник проливал слезы в закоптелый чугунок с пустым
#  борщом. Теперь он занимает довольно крупный, ответственный пост в
# одном из банков, слывя образцом честности и отзывчивости на нужды
# бедности. И каждый раз, заканчивая свое повествование о чудесном
# докторе, он прибавляет голосом, дрожащим от скрываемых слез:— С этих
# пор точно благодетельный ангел снизошёл в нашу семью. Все
# переменилось. В начале января отец отыскал место, матушка встала на
# ноги, меня с братом удалось пристроить в гимназию на казенный счет.
# Просто чудо совершил этот святой человек. А мы нашего чудесного
# доктора только раз видели с тех пор — это когда его перевозили
# мертвого в его собственное имение Вишню. Да и то не его видели, потому
#                                   PER──
#  что то великое, мощное и святое, что жило и горело в чудесном докторе
#  при его жизни, угасло невозвратимо.\n Землемер Глеб Гаврилович
#                                                 PER─────────────
# Смирнов приехал на станцию «Гнилушки». До усадьбы, куда он был вызван
# ───────                     LOC─────
# для межевания, оставалось еще проехать на лошадях верст
# тридцать—сорок. (Ежели возница не пьян и лошади не клячи, то и
# тридцати верст не будет, а коли возница с мухой да кони наморены, то
# целых пятьдесят наберется.)\n— Скажите, пожалуйста, где я могу найти
# здесь почтовых лошадей? — обратился землемер к станционному
# жандарму.\n— Которых? Почтовых? Тут за сто верст путевой собаки не
# сыщешь, а не то что почтовых… Да вам куда ехать?\n— В Девкино, имение
#                                                       LOC────
# генерала Хохотова.\n— Что ж? — зевнул жандарм. — Ступайте за станцию,
#          PER─────
# там на дворе иногда бывают мужики, возят пассажиров.\nЗемлемер
# вздохнул и поплелся за станцию. Там, после долгих поисков, разговоров
# и колебаний, он нашел здоровеннейшего мужика, угрюмого, рябого,
# одетого в рваную сермягу и лапти.\n— Чёрт знает какая у тебя телега! —
#                                      PER─
#  поморщился землемер, влезая в телегу. — Не разберешь, где у нее зад,
# где перед…\n— Что ж тут разбирать-то? Где лошадиный хвост, там перед,
# а где сидит ваша милость, там зад…\nЛошаденка была молодая, но тощая,
#                                     PER──────
# с растопыренными ногами и покусанными ушами. Когда возница приподнялся
#  и стегнул ее веревочным кнутом, она только замотала головой, когда же
#  он выбранился и стегнул ее еще раз, то телега взвизгнула и задрожала,
#  как в лихорадке. После третьего удара телега покачнулась, после же
# четвертого она тронулась с места.\n— Этак мы всю дорогу поедем? —
# спросил землемер, чувствуя сильную тряску и удивляясь способности
# русских возниц соединять тихую, черепашью езду с душу выворачивающей
# тряской.\n— До-о-едем! — успокоил возница. — Кобылка молодая, шустрая…
#             PER──────
#  Дай ей только разбежаться, так потом и не остановишь… Но-о-о,
# прокля…тая!\nКогда телега выехала со станции, были сумерки. Направо от
#  землемера тянулась темная, замерзшая равнина, без конца и краю…
# Поедешь по ней, так наверно заедешь к чёрту на кулички. На горизонте,
# где она исчезала и сливалась с небом, лениво догорала холодная осенняя
#  заря… Налево от дороги в темнеющем воздухе высились какие-то бугры,
# не то прошлогодние стоги, не то деревня. Что было впереди, землемер не
#  видел, ибо с этой стороны всё поле зрения застилала широкая,
# неуклюжая спина возницы. Было тихо, но холодно, морозно.\n«Какая,
# однако, здесь глушь! — думал землемер, стараясь прикрыть свои уши
# воротником от шинели. — Ни кола ни двора. Не ровен час — нападут и
# ограбят, так никто и не узнает, хоть из пушек пали… Да и возница
# ненадежный… Ишь, какая спинища! Этакое дитя природы пальцем тронет,
# так душа вон! И морда у него зверская, подозрительная».\n— Эй, милый,
# — спросил землемер, — как тебя зовут?\n— Меня-то? Клим.\n— Что, Клим,
#                                                   PER─          PER─
# как у вас здесь? Не опасно? Не шалят?\n— Ничего, бог миловал… Кому ж
# шалить?\n— Это хорошо, что не шалят… Но на всякий случай все-таки я
# взял с собой три револьвера, — соврал землемер. — А с револьвером,
# знаешь, шутки плохи. С десятью разбойниками можно
# справиться…\nСтемнело. Телега вдруг заскрипела, завизжала, задрожала
# и, словно нехотя, повернула налево.\n«Куда же это он меня повез? —
# подумал землемер. — Ехал всё прямо и вдруг налево. Чего доброго,
# завезет, подлец, в какую-нибудь трущобу и… и… Бывают ведь случаи!»\n—
# Послушай, — обратился он к вознице. — Так ты говоришь, что здесь не
# опасно? Это жаль… Я люблю с разбойниками драться… На вид-то я худой,
# болезненный, а силы у меня, словно у быка… Однажды напало на меня три
# разбойника… Так что ж ты думаешь? Одного я так трахнул, что… что,
# понимаешь, богу душу отдал, а два другие из-за меня в Сибирь пошли на
#                                                       LOC───
# каторгу. И откуда у меня сила берется, не знаю… Возьмешь одной рукой
# какого-нибудь здоровилу, вроде тебя, и…. и сковырнешь.\nКлим оглянулся
#                                                         PER─
#  на землемера, заморгал всем лицом и стегнул по лошаденке.\n— Да,
# брат… — продолжал землемер. — Не дай бог со мной связаться. Мало того,
#  что разбойник без рук, без ног останется, но еще и перед судом
# ответит… Мне все судьи и исправники знакомы. Человек я казенный,
# нужный… Я вот еду, а начальству известно… так и глядят, чтоб мне кто-
# нибудь худа не сделал. Везде по дороге за кустиками урядники да
# сотские понатыканы… По… по…постой! — заорал вдруг землемер. — Куда же
# это ты въехал? Куда ты меня везешь?\n— Да нешто не видите?
# Лес!\n«Действительно, лес… — подумал землемер. — А я-то испугался!
# Однако, не нужно выдавать своего волнения… Он уже заметил, что я
# трушу. Отчего это он стал так часто на меня оглядываться? Наверное,
# замышляет что-нибудь… Раньше ехал еле-еле, нога за ногу, а теперь ишь
# как мчится!»\n— Послушай, Клим, зачем ты так гонишь лошадь?\n— Я ее не
#                           PER─
#  гоню. Сама разбежалась… Уж как разбежится, так никаким средствием ее
# не остановишь… И сама она не рада, что у ней ноги такие.\n— Врешь,
# брат! Вижу, что врешь! Только я тебе не советую так быстро ехать.
# Попридержи-ка лошадь… Слышишь? Попридержи!\n— Зачем?\n— А затем…
# затем, что за мной со станции должны выехать четыре товарища. Надо,
# чтоб они нас догнали… Они обещали догнать меня в этом лесу… С ними
# веселей будет ехать… Народ здоровый, коренастый… у каждого по
# пистолету… Что это ты всё оглядываешься и движешься, как на иголках?
# а? Я, брат, тово… брат… На меня нечего оглядываться… интересного во
# мне ничего нет… Разве вот револьверы только… Изволь, если хочешь, я их
#  выну, покажу… Изволь…\nЗемлемер сделал вид, что роется в карманах, и
# в это время случилось то, чего он не мог ожидать при всей своей
# трусости. Клим вдруг вывалился из телеги и на четвереньках побежал к
#           PER─
# чаще.\n— Караул! — заголосил он. — Караул! Бери, окаянный, и лошадь и
# телегу, только не губи ты моей души! Караул!\nПослышались скорые,
# удаляющиеся шаги, треск хвороста — и всё смолкло… Землемер, не
# ожидавший такого реприманда, первым делом остановил лошадь, потом
# уселся поудобней на телеге и стал думать.\n«Убежал… испугался, дурак…
# Ну, как теперь быть? Самому продолжать путь нельзя, потому что дороги
# не знаю, да и могут подумать, что я у него лошадь украл… Как быть?» —
# Клим! Клим!\n— Клим!.. — ответило эхо.\nОт мысли, что ему всю ночь
# PER─  PER─     PER─
# придется просидеть в темном лесу на холоде и слышать только волков,
# эхо да фырканье тощей кобылки, землемера стало коробить вдоль спины,
# словно холодным терпугом.\n— Климушка! — закричал он. — Голубчик! Где
#                              PER─────                   PER─────
# ты, Климушка?\nЧаса два кричал землемер, и только после того, как он
#     PER─────
# охрип и помирился с мыслью о ночевке в лесу, слабый ветерок донес до
# него чей-то стон.\n— Клим! Это ты, голубчик? Поедем!\n— У… убьешь!\n—
#                      PER─
# Да я пошутил, голубчик! Накажи меня господь, пошутил! Какие у меня
# револьверы! Это я от страха врал! Сделай милость, поедем!
# Мерзну!\nКлим, сообразив, вероятно, что настоящий разбойник давно бы
#          PER─
# уж исчез с лошадью и телегой, вышел из лесу и нерешительно подошел к
# своему пассажиру.\n— Ну, чего, дура, испугался? Я… я пошутил, а ты
# испугался… Садись!\n— Бог с тобой, барин, — проворчал Клим, влезая в
#                                                       PER─
# телегу. — Если б знал, и за сто целковых не повез бы. Чуть я не помер
# от страха…\nКлим стегнул по лошаденке. Телега задрожала. Клим стегнул
#             PER─                                         PER─
# еще раз, и телега покачнулась. После четвертого удара, когда телега
# тронулась с места, землемер закрыл уши воротником и задумался. Дорога
# и Клим ему уже не казались опасными.
#   PER─

# %%
sent = doc.sents[0]
sent.morph.print()
# Out:
#             ПРИГОВОР NOUN|Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
#                    \ PUNCT
#                    n ADP
#               ИМЕНЕМ PROPN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
#           РОССИЙСКОЙ ADJ|Case=Gen|Degree=Pos|Gender=Fem|Number=Sing
#            ФЕДЕРАЦИИ PROPN|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
#                    \ PUNCT
#                    n X|Foreign=Yes
#                   01 ADJ
#              декабря NOUN|Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#                 2016 ADJ
#                 года NOUN|Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#               Москва PROPN|Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing
#                    \ PUNCT
#                    n X|Foreign=Yes
#       Преображенский ADJ|Case=Nom|Degree=Pos|Gender=Masc|Number=Sing
#             районный ADJ|Case=Nom|Degree=Pos|Gender=Masc|Number=Sing
#                  суд NOUN|Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
#               Москвы PROPN|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
#                    в ADP
#              составе NOUN|Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
#                судьи NOUN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
#           Духновской PROPN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
#                    З PROPN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
#                    . PUNCT
#                    А PROPN|Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
#                    . PUNCT
#                    , PUNCT
#                  при ADP
#            секретаре NOUN|Animacy=Anim|Case=Loc|Gender=Masc|Number=Sing
#            Горшковой PROPN|Animacy=Anim|Case=Loc|Gender=Masc|Number=Sing
#                    А PROPN|Animacy=Anim|Case=Loc|Gender=Masc|Number=Sing
#                    . PUNCT
#                    А PROPN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
#                    . PUNCT
#                    , PUNCT
#                    с ADP
#             участием NOUN|Animacy=Inan|Case=Ins|Gender=Neut|Number=Sing
#      государственных ADJ|Case=Gen|Degree=Pos|Number=Plur
#          обвинителей NOUN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur
#            Давыдовой PROPN|Animacy=Anim|Case=Gen|Gender=Fem|Number=Sing
#                    Д PROPN|Animacy=Anim|Case=Gen|Gender=Fem|Number=Sing
#                    . PUNCT
#                    Е PROPN|Animacy=Anim|Case=Gen|Gender=Fem|Number=Sing
#                    . PUNCT
#                    , PUNCT
#             Дудукова PROPN|Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
#                    М PROPN|Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
#                    . PUNCT
#                    Ю PROPN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
#                    . PUNCT
#                    , PUNCT
#              Чубенко PROPN|Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
#                    А PROPN|Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
#                    . PUNCT
#                    А PROPN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
#                    . PUNCT
#                    , PUNCT
#          подсудимого NOUN|Animacy=Anim|Case=Acc|Gender=Masc|Number=Sing
#         ************ PUNCT
#                    а CCONJ
#                    А PROPN|Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
#                    . PUNCT
#                    А PROPN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
#                    . PUNCT
#                    , PUNCT
#                  его PRON|Case=Gen|Gender=Masc|Number=Sing|Person=3
#           защитников NOUN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur
#                    – PUNCT
#            адвокатов NOUN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur
#               Попова PROPN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
#                    А PROPN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
#                    . PUNCT
#                    В PROPN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
#                    . PUNCT
#                    , PUNCT
#      Колокольниковой PROPN|Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
#                    Е PROPN|Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
#                    . PUNCT
#                    В PROPN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
#                    . PUNCT
#                    , PUNCT
#           рассмотрев VERB|Aspect=Perf|Tense=Past|VerbForm=Conv|Voice=Act
#                    в ADP
#             открытом VERB|Aspect=Perf|Case=Loc|Gender=Neut|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass
#             судебном ADJ|Case=Loc|Degree=Pos|Gender=Neut|Number=Sing
#            заседании NOUN|Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing
#            уголовное ADJ|Animacy=Inan|Case=Acc|Degree=Pos|Gender=Neut|Number=Sing
#                 дело NOUN|Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing
#                   по ADP
#            обвинению NOUN|Animacy=Inan|Case=Dat|Gender=Neut|Number=Sing
#                    : PUNCT
#                    \ PUNCT
#                    n X|Foreign=Yes
#         ************ PUNCT
#               ****** PUNCT
#       ************** PUNCT
#                    , PUNCT
#                   ** PUNCT
#                   ** PUNCT
#                 **** PUNCT
#                 года NOUN|Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#             рождения NOUN|Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
#                    , PUNCT
#             уроженца ADJ|Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
#                    г NOUN|Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#                    . PUNCT
#               Москвы PROPN|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
#                    , PUNCT
#           гражданина NOUN|Animacy=Anim|Case=Acc|Gender=Masc|Number=Sing
#                   РФ PROPN|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
#                    , PUNCT
#  зарегистрированного VERB|Aspect=Perf|Case=Gen|Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass
#                   по ADP
#               адресу NOUN|Animacy=Inan|Case=Dat|Gender=Masc|Number=Sing
#                    : PUNCT
#    ***************** PUNCT
#                    , PUNCT
#                   со ADP
#   средне-специальным ADJ|Case=Ins|Degree=Pos|Gender=Neut|Number=Sing
#         образованием NOUN|Animacy=Inan|Case=Ins|Gender=Neut|Number=Sing
#                    , PUNCT
#            холостого ADJ|Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
#                    , PUNCT
#                   не PART|Polarity=Neg
#          работающего VERB|Aspect=Imp|Case=Gen|Gender=Masc|Number=Sing|Tense=Pres|VerbForm=Part|Voice=Act
#                    , PUNCT
#                   не PART|Polarity=Neg
#             судимого VERB|Aspect=Imp|Case=Gen|Gender=Masc|Number=Sing|Tense=Pres|VerbForm=Part|Voice=Pass
#                    , PUNCT
#                    в ADP
#           совершении NOUN|Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing
#         преступления NOUN|Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
#                    , PUNCT
#     предусмотренного VERB|Aspect=Perf|Case=Gen|Gender=Neut|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass
#                    ч NOUN|Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing
#                    . PUNCT
#                    3 NUM
#                   ст NOUN|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
#                    . PUNCT
#                   30 NUM
#                    , PUNCT
#                    п NOUN|Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing
#                    . PUNCT
#                    « PUNCT
#                    г NOUN|Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing
#                    » PUNCT
#                    ч NOUN|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
#                    . PUNCT
#                    4 NUM
#                   ст NOUN|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
#                    . PUNCT
#                228-1 NUM
#                   УК NOUN|Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#                   РФ PROPN|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
#                    , PUNCT
#                    \ PUNCT
#                    n NOUN
#            УСТАНОВИЛ PROPN|Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
#                    : PUNCT
#                    \ PUNCT
#                    n X|Foreign=Yes
#         ************ PUNCT
#               ****** PUNCT
#             ******** PUNCT
#             совершил VERB|Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
#            покушение NOUN|Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing
#                   на ADP
#           незаконный ADJ|Animacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing
#                 сбыт NOUN|Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
#        наркотических ADJ|Case=Gen|Degree=Pos|Number=Plur
#              средств NOUN|Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur
#                    , PUNCT
#                   то PRON|Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing
#                 есть VERB|Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
#           умышленные ADJ|Case=Nom|Degree=Pos|Number=Plur
#             действия NOUN|Animacy=Inan|Case=Nom|Gender=Neut|Number=Plur
#                    , PUNCT
#      непосредственно ADV|Degree=Pos
#         направленные VERB|Aspect=Perf|Case=Nom|Number=Plur|Tense=Past|VerbForm=Part|Voice=Pass
#                   на ADP
#           незаконный ADJ|Animacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing
#                 сбыт NOUN|Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
#        наркотических ADJ|Case=Gen|Degree=Pos|Number=Plur
#              средств NOUN|Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur
#                    , PUNCT
#          совершенные VERB|Animacy=Inan|Aspect=Perf|Case=Acc|Number=Plur|Tense=Past|VerbForm=Part|Voice=Pass
#              группой NOUN|Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing
#                  лиц NOUN|Animacy=Anim|Case=Gen|Gender=Neut|Number=Plur
#                   по ADP
#     предварительному ADJ|Case=Dat|Degree=Pos|Gender=Neut|Number=Sing
#              сговору NOUN|Animacy=Inan|Case=Dat|Gender=Neut|Number=Sing
#                    , PUNCT
#                    в ADP
#              крупном ADJ|Case=Loc|Degree=Pos|Gender=Masc|Number=Sing
#              размере NOUN|Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
#                    , PUNCT
#                  при ADP
#                 этом PRON|Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing
#         преступление NOUN|Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing
#                   не PART|Polarity=Neg
#                 было AUX|Aspect=Imp|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
#             доведено VERB|Aspect=Perf|Gender=Neut|Number=Sing|Tense=Past|Variant=Short|VerbForm=Part|Voice=Pass
#                   до ADP
#                конца NOUN|Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#                   по ADP
#                   не PART|Polarity=Neg
#            зависящим VERB|Aspect=Imp|Case=Dat|Number=Plur|Tense=Pres|VerbForm=Part|Voice=Act
#                   от ADP
#                 него PRON|Case=Gen|Gender=Masc|Number=Sing|Person=3
#      обстоятельствам NOUN|Animacy=Inan|Case=Dat|Gender=Neut|Number=Plur
#                    , PUNCT
#                    а CCONJ
#               именно PART
#                    : PUNCT
#                    \ PUNCT
#                    n X|Foreign=Yes
#                  Так ADV|Degree=Pos
#         ************ PUNCT
#                    А PROPN|Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
#                    . PUNCT
#                    А PROPN|Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing
#                    . PUNCT
#                    , PUNCT
#                    с ADP
#                целью NOUN|Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing
#             быстрого ADJ|Case=Gen|Degree=Pos|Gender=Neut|Number=Sing
#                    и CCONJ
#          незаконного ADJ|Case=Gen|Degree=Pos|Gender=Neut|Number=Sing
#        материального ADJ|Case=Gen|Degree=Pos|Gender=Neut|Number=Sing
#           обогащения NOUN|Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
#                    , PUNCT
#                   из ADP
#            корыстных ADJ|Case=Gen|Degree=Pos|Number=Plur
#           побуждений NOUN|Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur
#                    , PUNCT
#                 имея VERB|Aspect=Imp|Tense=Pres|VerbForm=Conv|Voice=Act
#           преступный ADJ|Animacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing
#               умысел NOUN|Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
#                    , PUNCT
#         направленный VERB|Animacy=Inan|Aspect=Perf|Case=Acc|Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass
#                   на ADP
#           незаконный ADJ|Animacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing
#                 сбыт NOUN|Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
#        наркотических ADJ|Case=Gen|Degree=Pos|Number=Plur
#              средств NOUN|Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur
#              группой NOUN|Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing
#                  лиц NOUN|Animacy=Anim|Case=Gen|Gender=Neut|Number=Plur
#                   по ADP
#     предварительному ADJ|Case=Dat|Degree=Pos|Gender=Neut|Number=Sing
#              сговору NOUN|Animacy=Inan|Case=Dat|Gender=Neut|Number=Sing
#                    , PUNCT
#                    в ADP
#              крупном ADJ|Case=Loc|Degree=Pos|Gender=Masc|Number=Sing
#              размере NOUN|Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
#                    , PUNCT
#            осознавая VERB|Aspect=Imp|Tense=Pres|VerbForm=Conv|Voice=Act
#         общественную ADJ|Case=Acc|Degree=Pos|Gender=Fem|Number=Sing
#            опасность NOUN|Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing
#          последствий NOUN|Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur
#                своих DET|Case=Gen|Number=Plur
#             действий NOUN|Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur
#                    и CCONJ
#                желая VERB|Aspect=Perf|VerbForm=Inf|Voice=Act
#                   их DET
#          наступления NOUN|Animacy=Inan|Case=Acc|Gender=Neut|Number=Plur
#                    , PUNCT
#                    в ADP
#            нарушение NOUN|Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing
#                   ст NOUN|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
#                    . PUNCT
#                   ст NOUN|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
#                    . PUNCT
#                   5, NUM
#                   8, NUM
#                  14, NUM
#                   20 NUM
#                    и CCONJ
#                   24 NUM
#         Федерального ADJ|Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
#               Закона PROPN|Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#                   РФ PROPN|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
#                   от ADP
#                    8 ADJ
#               января NOUN|Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#                 1998 ADJ
#                 года NOUN|Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#                    № SYM
#                 3-ФЗ NUM
#                    « PUNCT
#                    О ADP
#        наркотических ADJ|Case=Loc|Degree=Pos|Number=Plur
#            средствах NOUN|Animacy=Inan|Case=Loc|Gender=Neut|Number=Plur
#                    и CCONJ
#         психотропных ADJ|Case=Loc|Degree=Pos|Number=Plur
#            веществах NOUN|Animacy=Inan|Case=Loc|Gender=Neut|Number=Plur
#                    » PUNCT
#                    , PUNCT
#                    в ADP
#      неустановленное ADJ|Animacy=Inan|Case=Acc|Degree=Pos|Gender=Neut|Number=Sing
#                время NOUN|Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing
#                    и CCONJ
#                месте NOUN|Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing
#                    , PUNCT
#                    в ADP
#               период NOUN|Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
#                   до ADP
#                   17 NUM
#                часов NOUN|Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
#                   59 NUM
#                минут NOUN|Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur
#                   16 ADJ
#             сентября NOUN|Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#                 2015 ADJ
#                 года NOUN|Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#                    , PUNCT
#              вступил VERB|Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
#                    в ADP
#      предварительный ADJ|Animacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing
#           преступный ADJ|Animacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing
#               сговор NOUN|Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
#                    с ADP
#     неустановленными ADJ|Case=Ins|Degree=Pos|Number=Plur
#        соучастниками NOUN|Animacy=Anim|Case=Ins|Gender=Masc|Number=Plur
#                    , PUNCT
#                    с ADP
#                целью NOUN|Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing
#          незаконного ADJ|Case=Gen|Degree=Pos|Gender=Neut|Number=Sing
#         приобретения NOUN|Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
#                    и CCONJ
#         последующего ADJ|Case=Gen|Degree=Pos|Gender=Neut|Number=Sing
#          умышленного NOUN|Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
#                    и CCONJ
#          незаконного ADJ|Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
#                сбыта NOUN|Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
#        наркотических ADJ|Case=Gen|Degree=Pos|Number=Plur
#              средств NOUN|Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur
#                    , PUNCT
#                    в ADP
#              крупном ADJ|Case=Loc|Degree=Pos|Gender=Masc|Number=Sing
#              размере NOUN|Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
#                    , PUNCT
#         распределили VERB|Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act
#                между ADP
#                собой PRON|Case=Ins
#           преступные ADJ|Animacy=Inan|Case=Acc|Degree=Pos|Number=Plur
#                 роли NOUN|Animacy=Inan|Case=Acc|Gender=Fem|Number=Plur
#              каждого DET|Case=Gen|Gender=Masc|Number=Sing
#                    и CCONJ
#          разработали VERB|Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act
#           преступный ADJ|Animacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing
#                 план NOUN|Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
#                    . PUNCT

# %%
sent.syntax.print()
# Out:
# ┌────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────► ПРИГОВОР            nsubj
# │                                                                                                                                                                                                                                      \
# │                                                                                                                                                                                                                                      n
# │           ┌───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┌────────────────────────────────────────────────────────────► ИМЕНЕМ              appos
# │           │                                                                                                                                                           │                                                           ┌► РОССИЙСКОЙ          amod
# │           │                                                                                                                                                           │                                                       ┌──►└─ ФЕДЕРАЦИИ           nmod
# │           │                                                               ┌──────────────────────────────────────────────────────────────────────────────────────────►│                                                       │      \                   appos
# │           │                                                               │                                                                                           │ ┌────────────────────────────────────────────────────►│      n                   punct
# │           │                                                               │           ┌──────────────────────────────────────────────────────────────────────────────►│ │                                                     │      01                  nmod
# │           │   ┌──────────────────────────────────────────────────────────►│           │                                                                               │ │                                                     │      декабря             flat
# │           │   │                                                           │           │                                                                               │ │                                                     │   ┌► 2016                amod
# │     ┌────►│   │                                                           │           │                                                                               │ │                                                     │   └─ года                nmod
# │   ┌►│     │   │                                                           │     ┌───┌─│                                                                               │ │                                                     │   ┌─ Москва              nsubj
# │   │ │     │   │                                                           │     │   │ │                                                                               │ │                                                     │   └► \                   punct
# │   │ │     │   │                                                           │     │   │ │                                                                               │ │           ┌────────────────────────────────────────►│      n                   punct
# │   │ │     │   │                                                           │     │   │ │                                                                               │ │           │                                         │ ┌──► Преображенский      amod
# │   │ │     │   │                                                           │     │   │ │                                                                               │ │           │                                         │ │ ┌► районный            amod
# │   │ │ ┌──►│   │                                                           │     │   │ │                                                                               │ │           │                                         │ └─└─ суд                 nsubj
# │   │ │ │   │   │                                                           │     │   │ │                                                                               │ │           │                                         │ └──► Москвы              nmod
# │   │ │ │   │   │                                                           │     │   │ │                                                                               │ │           │                                         │   ┌► в                   case
# │   │ │ │ ┌►│   │                                                           │     │   │ │                                                                               │ │           │                                         │ ┌─└─ составе             obl
# │   │ │ │ │ │   │   ┌───────────────────────────────────────────────────────│     │   │ │                                                 ┌─────────────────────────────│ │           │                                         └─└──► судьи               nmod
# │   │ │ │ │ │   │   │                                                       │     │   │ │                                                 │                             │ │ ┌────────►│                                         ┌───┌─ Духновской          appos
# │   │ │ │ │ │   │   │                                                       │     │   │ │                                                 │                             │ │ │         │                                         │   └► З                   flat:name
# │   │ │ │ │ │   │   │                                                       │     │   │ │                                                 │                             │ │ │         │ ┌──────────────────────────────────────►│      .                   punct
# │   │ │ │ │ │   │   │                                                       │     │   │ │                                                 │                             │ │ │         │ │ ┌────────────────────────────────────►│      А                   flat:name
# │   │ │ │ │ │   │   │                                                       │     │   │ │                                                 │                             │ │ │         │ │ │ ┌──────────────────────────────────►│      .                   punct
# │   │ │ │ │ │   │   │                                                       │     │   │ │                                                 │         ┌──────────────────►│ │ │         │ │ │ │                                   │      ,                   punct
# │   │ │ │ │ │   │   │                                                       │     │   │ │                                                 │         │                   │ │ │         │ │ │ │                                   │   ┌► при                 case
# │ ┌►│ │ │ │ │   │   │                                                       │     │   │ │ ┌───────────────────────────────────────────────│         │                   │ │ │         │ │ │ │                                   │ ┌─└─ секретаре           obl
# │ │ │ │ │ │ │   │   │                                                       │     │   │ │ │                                               │         │                   │ │ │         │ │ │ │                                   │ └──► Горшковой           appos
# │ │ │ │ │ │ │   │   │                                                       │     │   │ │ │                                               │         │                   │ │ │         │ │ │ │                                   └────► А                   flat:name
# │ │ │ │ │ │ │   │   │                                                       │     │   │ │ │                                               │         │                   │ │ │         │ │ │ │   ┌────────────────────────────────────► .                   punct
# │ │ │ │ │ │ │   │   │                                                       │     │   │ │ │                                               │         │                   │ │ │         │ │ │ │   │ ┌──────────────────────────────────► А                   flat:name
# │ │ │ │ │ │ │   │   │                                                       │     │   │ │ │                                               │         │                   │ │ │         │ │ │ │   │ │ ┌────────────────────────────────► .                   punct
# │ │ │ │ │ │ │   │   │                                                       │     │   │ │ │                               ┌──────────────►│         │                   │ │ │         │ │ │ │   │ │ │                                  ,                   punct
# │ │ │ │ │ │ │   │   │                                                       │     │   │ │ │                               │               │         │                   │ │ │         │ │ │ │   │ │ │                               ┌► с                   case
# │ │ │ │ │ │ │ ┌►│   │                                                       │     │   │ │ │                               │               │         │                   │ │ │         │ │ │ │   │ │ │                             ┌─└─ участием            nmod
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                               │               │         │                   │ │ │         │ │ │ │   │ │ │                             │ ┌► государственных     amod
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                               │               │         │                   │ │ │         │ │ │ │   │ │ │                             └►└─ обвинителей         nmod
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                               │               │         │                   │ │ │         │ │ │ │   │ │ │                             └►┌─ Давыдовой           appos
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                               │               │         │                   │ │ │         │ │ │ │   │ │ │                               └► Д                   appos
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                               │               │         │                   │ │ │         │ │ │ │   │ │ │     ┌──────────────────────────► .                   punct
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                               │               │         │                   │ │ │         │ │ │ │   │ │ │     │ ┌────────────────────────► Е                   flat:name
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                               │               │         │                   │ │ │         │ │ │ │   │ │ │     │ │     ┌──────────────────► .                   punct
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                               │               │         │                   │ │ │         │ │ │ │   │ │ │     │ │     │                 ┌► ,                   punct
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                               │           ┌───│         │                   │ │ │         │ │ │ │ ┌─│ │ │     │ │     │ ┌────────────►┌─└─ Дудукова            conj
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                               │           │   │         │                   │ │ │         │ │ │ │ │ │ │ │     │ │     │ │             │ ┌► М                   flat:name
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                               │           │   │         │                   │ │ │         │ │ │ │ │ │ │ │     │ │     │ │ ┌──────────►│ │  .                   punct
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                               │           │   │         │                   │ │ │         │ │ │ │ │ │ │ │     │ │     │ │ │ ┌────────►│ │  Ю                   flat:name
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                               │           │   │         │                   │ │ │         │ │ │ │ │ │ │ │     │ │     │ │ │ │ ┌──────►│ │  .                   punct
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                               │           │   │         │                   │ │ │         │ │ │ │ │ │ │ │     │ │     │ │ │ │ │       └►│  ,                   punct
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                         ┌─────│           │   │         │                   │ │ │         │ │ │ │ │ │ │ │ ┌───│ │   ┌►│ │ │ │ │         └─ Чубенко             conj
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                         │     │           │   │         │                   │ │ │         │ │ │ │ │ │ │ │ │   │ │ ┌►│ │ │ │ │ │            А                   flat:name
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                         │     │           │   │         │                   │ │ │         │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ ┌────────► .                   punct
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                         │     │           │   │         │                   │ │ │         │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ ┌──────► А                   flat:name
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                         │     │           │   │         │                   │ │ │         │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ ┌────► .                   punct
# │ │ │ │ │ │ │ │ │   │                                                       │     │   │ │ │                         │     │           │   │         │                   │ │ │         │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ ┌──► ,                   punct
# │ │ │ │ │ │ │ │ │ ┌►│                                                       │     │   │ │ │                         │     │           │   │         │                   │ │ │         │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │    подсудимого         conj
# │ │ │ │ │ │ │ │ │ │ │                                                       │     │   │ │ │                         │     │           │   │         │                   │ │ │         │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ ┌► ************        punct
# │ │ │ │ │ │ │ │ │ │ │                                     ┌────────────────►│     │   │ │ │                         │     │           │   │         │                   │ │ │         │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │  а                   cc
# │ │ │ │ │ │ │ │ │ │ │                       ┌─┌─┌─┌─┌───┌─│                 │ ┌──►│   │ │ │                     ┌─┌─│ ┌─┌─│ ┌─┌───┌─┌─│ ┌─│ ┌───┌───│     ┌───┌───┌─┌───└─└─│ ┌───┌─┌─└─└─└─└─│ └─└─└─│ ┌─└─└─│ │ └─└─└─└─└─└─└─└─└─└─ А                   nsubj:pass
# │ │ │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │                 │ │   │   │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │     │   │   │ │       │ │   │ │     │ │ │       │ │ │ │ │ │ │ │ │ │       │ │ └► .                   punct
# │ │ │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │                 │ │   │   │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │     │   │   │ │       │ │   │ │     │ │ │       │ │ │ │ │ │ │ │ │ │       │ └──► А                   flat:name
# │ │ │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │                 │ │   │   │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │     │   │   │ │       │ │   │ │     │ │ │       │ │ │ │ │ │ │ │ │ │       └────► .                   punct
# │ │ │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │                 │ │   │   │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │     │   │   │ │       │ │   │ │     │ │ │       │ │ │ │ │ │ │ │ │ │         ┌──► ,                   punct
# │ │ │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │                 │ │   │   │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │     │   │   │ │       │ │   │ │     │ │ │       │ │ │ │ │ │ │ │ │ │         │ ┌► его                 nmod
# │ │ │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │             ┌───│ │   │ ┌►│ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │     │   │   │ │       │ │   │ │     │ │ │       │ │ │ │ │ │ │ │ │ │         └─└─ защитников          nsubj:pass
# │ │ │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │             │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │     │   │   │ │       │ │   │ │     │ │ │       │ │ │ │ │ │ │ │ │ │           ┌► –                   punct
# │ │ │ │ │ │ │ │ │ │ │                     ┌►│ │ │ │ │   │ │     ┌───────│   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   ┌─│   │   │ │     ┌─└─│ ┌─│ │   ┌─│ │ │       │ │ │ │ │ └─│ │ │ │         ┌─└─ адвокатов           parataxis
# │ │ │ │ │ │ │ │ │ │ │                     │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ ┌─│ │ │ │       │ │ │ │ └───│ │ │ │         └►┌─ Попова              nmod
# │ │ │ │ │ │ │ │ │ │ │                     │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │ │       │ │ │ │     │ │ │ │           └► А                   flat:name
# │ │ │ │ │ │ │ │ │ │ │                     │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │ │       │ │ │ │     │ │ │ └────────────► .                   punct
# │ │ │ │ │ │ │ │ │ │ │                     │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │ │       │ │ │ │     │ │ └──────────────► В                   flat:name
# │ │ │ │ │ │ │ │ │ │ │                     │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │ │       │ │ │ │     │ └────────────────► .                   punct
# │ │ │ │ │ │ │ │ │ │ │                     │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │ └──────►│ │ │ │     │                    ,                   punct
# │ │ │ │ │ │ │ │ │ │ │                     │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │         │ │ │ │     └──────────────────► Колокольниковой     appos
# │ │ │ │ │ │ │ │ │ │ │                     │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │         └►│ │ │                          Е                   flat:name
# │ │ │ │ │ │ │ │ │ │ │                     │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │           │ │ └────────────────────────► .                   punct
# │ │ │ │ │ │ │ │ │ │ │                     │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │           │ └──────────────────────────► В                   flat:name
# │ │ │ │ │ │ │ │ │ │ │                     │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │           └────────────────────────────► .                   punct
# │ │ │ │ │ │ │ │ │ │ │                     │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │                                       ┌► ,                   punct
# │ │ │ │ │ │ │ │ │ │ │ ┌────────►┌─────────│ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │                                 ┌─────└─ рассмотрев          advcl
# │ │ │ │ │ │ │ │ │ │ │ │         │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │                                 │ ┌────► в                   case
# │ │ │ │ │ │ │ │ │ │ │ │         │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │                                 │ │ ┌──► открытом            amod
# │ │ │ │ │ │ │ │ │ │ │ │         │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │                                 │ │ │ ┌► судебном            amod
# │ │ │ │ │ │ │ │ │ │ │ │         │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │                                 └►└─└─└─ заседании           obl
# │ │ │ │ │ │ │ │ │ │ │ │         │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │                     │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │                                       ┌► уголовное           amod
# │ │ │ │ │ │ │ │ │ │ │ │         │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │       ┌────────────►│ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │                                     ┌─└─ дело                nsubj:pass
# │ │ │ │ │ │ │ │ │ │ │ │         │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │       │             │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │                                     │ ┌► по                  case
# │ │ │ │ │ │ │ │ │ │ │ │       ┌─│         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │       │             │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │                                     └►└─ обвинению           nmod
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │       │             │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │     │   │ │ │ │ │ │ │ │                                       ┌► :                   punct
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │       │             │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │ ┌───│   │ │ │ │ │ │ │ │                                 ┌────►└─ \                   parataxis
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │       │             │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │ │   │   │ │ │ │ │ │ │ └────────────────────────────────►│        n                   appos
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │       │             │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │ │   │   │ │ │ │ │ │ └──────────────────────────────────►│        ************        punct
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     ┌►│             │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │ │   │   │ │ │ │ │ │                                     │        ******              punct
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         ┌──►│ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │   │ │   │   │ │ │   │   │ │ │ │ │ │                                     │        **************      punct
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         │   │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │ ┌►│ │   │   │ │ │   │   │ │ │ │ │ │                                     │        ,                   punct
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         │ ┌►│ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │ │ │ │   │   │ │ │   │   │ │ │ │ │ │                                     │        **                  punct
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │ │ │ │   │   │ │ │   │   │ │ │ └►│ │                                     │        **                  punct
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │ │ │ │   │   │ │ │   │   │ │ └──►│ │                                     │        ****                punct
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │ │ │ │   │   │ │ │   │   │ │     │ │                                     │ ┌──►┌─ года                parataxis
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │ │ │ │   │   │ │ │   │   │ │     │ │                                     │ │   └► рождения            nmod
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │ │ │ │   │   │ │ │   │   │ │     │ │                                     │ │   ┌► ,                   punct
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │ │ │ │   │   │ │ │   │   │ │     │ └────────────────────────────────────►│ │ ┌─└─ уроженца            acl
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │ │ │ │   │   │ │ │   │   │ │     │                                       │ │ └──► г                   obj
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │ │ │ │   │   │ │ │   │   └►│     │                                       │ │      .                   punct
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │ │ │ │   │   │ │ │   │     │     └──────────────────────────────────────►│ │      Москвы              appos
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │ │ │ │   │   │ │ │   │     │                                             │ │   ┌► ,                   punct
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │ │ │ │   │   │ │ │   │     └────────────────────────────────────────────►│ │ ┌─└─ гражданина          appos
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │ │ │ │   │   │ │ │   │                                                   │ │ └──► РФ                  nmod
# │ │ │ │ │ │ │ │ │ │ │ │       │ │         │ │ │ │ │ │   │ │     │       │   │ │   │ │ │ │ │     │ │         │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │   │   │ │ │ │   │   │ │ │   │                                                   │ │   ┌► ,                   punct
# │ │ │ │ │ │ │ │ │ │ │ │   ┌─┌─│ │     ┌───│ │ │ │ │ │   │ │     │       │   │ │ ┌─│ │ │ │ │     │ │     ┌───│ │ │ │ │ │ │ │ │ │   │ │ │ │ └►│   │   └─│ │ │ ┌─│   │ │ │   │                                                   │ │ ┌─└─ зарегистрированного acl
# │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │     │   │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │     │   │ │ │ │ │ │ │ │ │ │   │ │ │ │   │   │   │ │ │ │ │ │   │ │ │   │                                                   │ │ │ ┌► по                  case
# │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │     │   │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │     │   │ │ │ │ │ │ │ │ │ │   │ │ │ │   │   │   │ │ │ │ │ │   │ │ │   │                                     ┌─────────────└─└─└►└─ адресу              obl
# │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │     │   │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │     │   │ │ │ │ │ │ │ │ │ │   │ │ │ │   │ ┌►│   │ │ │ │ │ │   │ │ │   │                                     │                      :                   punct
# │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │     │   │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │     │   │ │ │ │ │ │ │ │ │ │   │ │ │ │   │ │ │ ┌►│ │ │ │ │ │   │ │ │   │                                     │                      *****************   parataxis
# │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │     │   │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │     │ ┌►│ │ │ │ │ │ │ │ │ │   │ │ │ │   │ │ │ │ │ │ │ │ │ │   │ │ │   │                                     │                      ,                   punct
# │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │     │   │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │     │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │   │ │ │ │ │ │ │ │ │ │ ┌►│ │ │   │                                     │                      со                  case
# │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │     │   │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │     │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │   │                                     │                   ┌► средне-специальным  amod
# │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │     │ ┌►│ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │   ┌─│ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │   │                                     │                   └─ образованием        conj
# │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │     │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │   │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │   │                                     │                   ┌► ,                   punct
# │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │     │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │   │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │   │                             ┌──────►│                   └─ холостого           amod
# │ │ │ │ │ │ │ │ │ │ │ │ ┌►│ │ │ │     │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │   │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │   │                             │       │                      ,                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │     │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │   │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │   │                             │       │                   ┌► не                  advmod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ ┌──►│ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │   │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │   │                             │       │                 ┌─└─ работающего         acl
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │   │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │   │                             │       │                 └──► ,                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │   │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │   │                             │       │                   ┌► не                  advmod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │   │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │   │                             │       │ ┌────────────────►└─ судимого            acl
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ ┌►│ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │   │                             │       │ │                    ,                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │   │                             │       │ │                 ┌► в                   case
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │ ┌►│                             │       │ │               ┌─└─ совершении          obl
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │                             │       │ │               └──► преступления        nmod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │                             │       │ │                 ┌► ,                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ ┌►│ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ │ │     │ │   │ │ │ │ │ │ │ │ │ │ └─│ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │                             │       │ │               ┌─└─ предусмотренного    acl
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │ └─│     │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │                             │       │ │               └──► ч                   nsubj:pass
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │   │     │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ │ └►│ │ │                             │       │ │                    .                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │   │     │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ │ └──►│ │ │                             │       │ │                    3                   appos
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ │   │     │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ │     │ │ └────────────────────────────►│       │ │                    ст                  conj
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │ └──►│     │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ │ │     │ │                               │       │ │                    .                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │     │     │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ │ │   │ │ │ │ │ │ │ │ │ └►│     │ │                               │       │ │                    30                  appos
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │     │     │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │ └►│   │ │ │ │ │ │ │ │ │   │     │ │                               │       │ │                    ,                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │     │     │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │   │   │ │ │ │ │ │ │ └►│   │     │ │                               │       │ │                    п                   parataxis
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │     │     │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │   │   │ │ │ │ │ │ │   │   │     │ │                     ┌────────►│       │ │                    .                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │     │     │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │   │   │ │ │ │ │ │ │   │   │     │ │                     │         │       │ │                 ┌► «                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │     │     │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │   │   │ │ │ │ │ │ │   │   │     │ │                     │         │       │ │             ┌►┌─└─ г                   nsubj
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │     │     │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │   │   │ │ │ │ │ │ │   │   │     │ │                     │         │       │ │             │ └──► »                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │     │     │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │   │   │ │ │ │ │ │ │   │   │     │ │                     │         │       │ │             │   ┌► ч                   appos
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │     │     │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │   │   │ │ └►│ │ │ │   │   │     │ │                     │         │       │ │             │   │  .                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   │ │ │ │ │     │     │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │   │   └►│   │ │ │ │   │   │     │ │                     │         │       │ │             │   │  4                   appos
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │   └─│ │ │ │     │ ┌─┌─│ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │   │     │   │ │ │ └──►│   │     │ │                     │         │       │ │             │   └─ ст                  nmod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │ └►│     │ │ │ │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │   │     │   │ │ │     │   │     │ │                     │         │       │ │             │      .                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │     │ │ │ │ │   │ │ │ │ │ │ │ │ │ │   │ │ │ │ │   └────►│   │ │ │     │   │     │ │                     │         │       │ │             │      228-1               appos
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │     │ │ │ │ │   │ │ │ │ │ │ │ └►│ │   │ │ │ │ │         │   │ │ │     │   │     │ │                     │         │       │ │             │   ┌─ УК                  nmod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │     │ │ │ │ │   │ │ │ │ │ │ │   │ │   │ │ │ │ │         │   │ │ │     │   │     │ │                     │         │       │ │             │   └► РФ                  nmod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │     └►│ │ │ │   │ │ │ │ │ │ │   │ │   │ │ │ │ │         │   │ │ │     │   │     │ │                     │         │       │ │             │      ,                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │       │ │ │ │   │ │ │ │ │ │ │   │ │   │ │ │ │ └────────►│   │ │ │     │   │     │ │                     │         │       │ │             │      \                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │       │ │ │ │   │ │ │ │ │ │ │   │ │   │ │ │ └──────────►│   │ │ │     │   │     │ │                     │         │       │ │             │      n                   appos
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │       │ │ │ │ ┌─│ │ │ │ │ │ │   │ │   │ └►│             │   │ │ │     │   │     │ │                     │         │       │ │             └───── УСТАНОВИЛ           orphan
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │       │ │ │ │ │ │ │ │ │ │ │ │   │ │   └──►│             │   │ │ │     │   │     │ │                     │         │       │ │                    :                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │       │ │ │ │ │ │ │ │ │ │ │ │   │ └──────►│             │   │ │ │     │   │     │ │                     │         │       │ │                    \                   appos
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │       │ │ │ │ │ │ │ │ │ │ │ │   └────────►│             │   │ │ │     │   │     │ │                     │         │       │ │                    n                   flat:foreign
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │       │ │ │ │ │ │ │ │ │ │ │ └────────────►│             │   │ │ │     │   │     │ │                     │         │       │ │                    ************        punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │       │ │ │ │ │ │ │ │ │ │ └──────────────►│             │   │ │ │     │   │     │ │                     │         │       │ │                    ******              punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │       │ │ │ │ │ │ │ │ │ │                 │             │   │ │ │     │   │     └►│                     │         │       │ │                    ********            punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               ┌─│             │   │ │ │     │   │       │                     │         │       │ │                 ┌─ совершил
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │ │     │   │       │                     │         │       │ │       ┌─────────└► покушение           obj
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │ │     │   │   ┌──►│                     │         │       │ │       │            на                  case
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │     │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │ │     │   │   │ ┌►│                     │         │       │ │       │            незаконный          amod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │   ┌►│       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │ │     │   │   │ │ │                     │         │       │ │       │            сбыт                nmod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │   │ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │ │     │   │   │ │ │                     │         │       │ │       │         ┌► наркотических       amod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │   │ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │ │     │   │   │ │ │                     │         │       │ │       │ ┌──────►└─ средств             nmod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │   │ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │ │     │   │   │ │ │                     │         │       │ │       │ │   ┌────► ,                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │   │ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │ │     │   │   │ │ │                     │         │       │ │     ┌─│ │   │ ┌►┌─ то                  mark
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │   │ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │ │     │   │   │ │ │                     │         │       │ │     │ │ │   │ │ └► есть                fixed
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │   │ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │ │     │   │   │ │ │                     │         │       │ │     │ │ │   │ │ ┌► умышленные          amod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │   │ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │ │     │   │   │ │ │                     │         │ ┌─────└►│     │ │ │ ┌─└─└─└─ действия            parataxis
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │   │ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │ │     │   │   │ │ │                     │         │ │       │     │ │ │ │ │ ┌──► ,                   punct
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │   │ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │ │     │   │   │ │ │                     │         │ │       │     │ │ │ │ │ │ ┌► непосредственно     advmod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │   │ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │ └─────│   │   │ │ │                     │         │ │       │     │ │ │ │ └►└─└─ направленные        acl
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │   │ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │       │   │   │ │ │                     │   ┌────►│ │       │     │ │ │ │        на                  case
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │   │ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │       │   │   │ │ │                     │   │ ┌──►│ │       │     │ │ │ │        незаконный          amod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ ┌─│ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │       │ ┌─│   │ │ │                     │   │ │   │ │       │ ┌───│ └►└─│   ┌─── сбыт                nmod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │       │ │ │   │ │ │                     │   │ │   │ │       │ │   │     │   │ ┌► наркотических       amod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │       │ │ │   │ │ │                     │   │ │   └─│       └─│   │     │   └►└─ средств             nmod
# │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │ │   │ │ │ │ │       │     │ │   │       │ │ │ │ │ │ │ │ │ │               │ │             │   │ │       │ │ │   │ │ │                     │   │ │     │         │   │     │     ┌► ,                   punct
# ...
# │ │ │ │ │ │   │   │   │ │ │ │ │   │ │ │ │             │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │                       │ │ │                                 │ │ ┌► наркотических       amod
# │ │ │ │ │ │   │   │   │ │ │ │ └──►│ │ │ └─────────────│     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │                       │ │ │                               ┌─└─└─└─ средствах           parataxis
# │ │ │ │ │ │   │   │   │ │ │ │     │ │ │               │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │                       │ │ │                               │   ┌──► и                   cc
# │ │ │ │ │ │   │   │   │ │ │ │     │ │ │               │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │                       │ │ │                               │   │ ┌► психотропных        amod
# │ │ │ │ │ │   │   │   │ │ │ │     │ │ │               │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │                       │ └─│                   ┌─┌─┌──────►│   └─└─ веществах           nmod
# │ │ │ │ │ │   │   │   │ │ │ │     │ │ │               │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │                       │   │                   │ │ │       └──────► »                   punct
# │ │ │ │ │ │   │   │   │ │ │ │     │ │ └──────────────►│     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │                       │   │                   │ │ │                ,                   punct
# │ │ │ │ │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │                       │   │                   │ │ │           ┌──► в                   case
# │ │ │ │ │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │ │ │ │ │                       │ │ │ │ │   │ │                       │   │                   │ │ │           │ ┌► неустановленное     amod
# │ │ │ │ │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │ │ │ │ └──────────────────────►│ │ │ │ │   │ │                       │   └───────────────────│ │ │           └─└─ время               obl
# │ │ │ │ │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │ │ │ │                         │ │ │ │ │   │ │                       │                       │ │ │             ┌► и                   cc
# │ │ │ │ │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │ │ │ │                         │ │ │ └─│   │ │                       │                       │ │ │ ┌──────────►└─ месте               conj
# │ │ │ │ │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │ │ │ │                         │ │ │   │   │ └──────────────────────►│                       │ │ │ │              ,                   punct
# │ │ │ │ │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │ │ │ │                         │ │ │   │   │                         │                       │ │ │ │           ┌► в                   case
# │ │ │ │ │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │ └►│ │                         │ │ │   │   │                         │                       │ │ │ │           └─ период              obl
# │ │ │ │ │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │   │ │                         │ │ │   │   │                         │                       │ │ │ │         ┌──► до                  case
# │ │ │ │ │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │   │ │                         │ │ │   │   │                         │                       │ │ │ │         │ ┌► 17                  nummod
# │ │ │ │ │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │   │ └────────────────────────►│ │ │   │   │                         │                       │ │ │ │         └─└─ часов               obl
# │ │ │ │ │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │   │                           │ │ │   │   │                         │                       │ │ │ │           ┌► 59                  nummod
# │ │ │ │ │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ │   │                           │ │ │   │   │                         │                       │ │ │ │   ┌──────►└─ минут               nmod
# │ │ │ └─│ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │ └──►│                           │ │ │   │   │                         │                       │ │ │ │   │     ┌─┌─ 16                  obl
# │ │ │   │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │     │                           │ │ │   │   │                         │                       │ │ │ │   │     │ └► сентября            flat
# │ │ │   │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │     │                           │ │ │   │   │                         │                       │ │ │ │   │     │ ┌► 2015                amod
# │ │ │   │ │   │   │   │ │ │ │     │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │     │                           │ │ │   │   │                         │                       │ │ │ │   │     └►└─ года                nmod
# │ │ │   │ │   │   │   │ │ │ └────►│ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │     │                           │ │ │   │   │                         │                       │ │ │ │   │          ,                   punct
# └─│ └───└─└───│   │   └─│ │       │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │     │                           │ │ │   │   │                         │                     ┌─│ │ │ │   │          вступил
#   │           │   │     │ │       │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │     │                           │ │ │   │   │                         │                     │ │ │ │ │   │   ┌────► в                   case
#   │           │   │     │ │       │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │     │                           │ │ │   │   │                         │                     │ │ │ │ │   │   │ ┌──► предварительный     amod
#   │           │   │     │ │       │ │                 │     │ │   │ │ │   │ │     │   │ │ │       │         │ │ │ │     │                           │ │ │   │   │                         │                     │ │ │ │ │   │   │ │ ┌► преступный          amod
#   │           └───│     │ │       │ │                 │     │ └───│ │ │   │ │     │   │ └─│       │         │ │ │ │     │                           │ │ │   │   │                         └─────────────────────│ │ │ │ │ ┌►│ ┌─└─└─└─ сговор              obl
#   │               │     │ │       │ │                 │     │     │ │ │   │ │     │   │   │       │         │ │ │ │     │                           │ │ │   │   │                                               │ │ │ │ │ │ │ │   ┌──► с                   case
#   │               │     │ │       │ │                 │     │     │ │ │   │ │     │   │   │       │         │ │ │ │     │                           │ │ │   │   │                                               │ │ │ │ │ │ │ │   │ ┌► неустановленными    amod
#   │               └─────│ │       └─└─────────────────│     │     │ │ │   │ │     │   │   │       │         │ │ │ │     │                           │ │ │   │   │                                               │ │ │ │ │ │ │ └──►└─└─ соучастниками       nmod
#   │                     │ └──────────────────────────►│     │     │ │ │   │ │     │   │   │       │         │ │ │ │     │                           │ │ │   │   │                                               │ │ │ │ │ │ │          ,                   punct
#   │                     │                             │     │     │ │ │   │ │     │   │   │       │         │ │ │ │     │                           │ │ │   │   │                                               │ │ │ │ │ │ │       ┌► с                   case
#   │                     │                             │     │     │ │ │   │ │     │   │   └──────►│         │ │ │ │     └───────────────────────────│ │ │   │   │                                               │ │ │ │ │ │ └─────┌─└─ целью               obl
#   │                     │                             │     │     │ │ │   │ │     │   │           │         │ │ │ │                                 │ │ │   │   │                                               │ │ │ │ │ │       │ ┌► незаконного         amod
#   │                     │                             │     │     │ │ │   │ │     │   │           │         │ │ │ │                                 │ │ │   │   │                                               │ │ │ └─└─│     ┌─└►└─ приобретения        nmod
#   │                     │                             │     │     │ │ │   │ │     │   │           │         │ │ │ │                                 │ │ │   │   │                                               │ │ │     │     │   ┌► и                   cc
#   │                     │                             │     │     │ │ │   │ │     │   │           │         │ │ │ │                                 │ │ │   │   │                                               │ │ └────►│     │   │  последующего        amod
#   │                     │                             │     │     │ │ │   │ │     │   │           │         │ │ │ │                                 │ │ │   │   │                                               │ └──────►│     │   │  умышленного         amod
#   │                     │                             │     │     │ │ │   │ │     │   │           │         │ │ │ └────────────────────────────────►│ │ │   │   │                                               │         │     │   │  и                   cc
#   │                     │                             │     │     │ │ │   │ │     │   │           │         │ └►│                                   │ │ │   │   │                                               │         │     │   │  незаконного         conj
#   │                     │                             │     │     │ │ │   │ │     │   │           │         │   │                                   │ │ └───│   │                                               │         │     └──►└─ сбыта               conj
#   │                     │                             │     │     │ │ │   │ │     │   │           │         │   │                                   │ │     │   │                                               │         │         ┌► наркотических       amod
#   │                     │                             │     └────►│ │ │   │ │     │   │           │         │   │                                   │ │     │   │                                               │         │         └─ средств             nmod
#   │                     │                             │           │ │ │   │ │     │   │           └────────►│   │                                   │ │     │   │                                               │         │            ,                   punct
#   │                     │                             │           │ │ │   │ └────►│   │                     │   │                                   │ │     │   │                                               │         │            в                   case
#   │                     │                             │           │ │ └──►│       │   │                     │   │                                   │ │     │   │                                               │         │            крупном             amod
#   │                     └─────────────────────────────│           │ │     │       └──►│                     └───│                                   │ │     │   │                                               │         │            размере             obl
#   │                                                   └──────────►│ │     │           │                         │                                   │ │     │   │                                               │         │            ,                   punct
#   └───────────────────────────────────────────────────────────────│ └─────└───────────└─────────────────────────└───────────────────────────────────└─│     └───│                                               │         └─────┌─┌─── распределили
#                                                                   │                                                                                   │         │                                               │               │ │ ┌► между               case
#                                                                   │                                                                                   │         │                                               │               │ └►└─ собой               obl
#                                                                   │                                                                                   │         │                                               │               │   ┌► преступные          amod
#                                                                   │                                                                                   │         │                                               │               └►┌─└─ роли                obj
#                                                                   │                                                                                   │         │                                               │                 └──► каждого             det
#                                                                   │                                                                                   │         │                                               │                   ┌► и                   cc
#                                                                   └──────────────────────────────────────────────────────────────────────────────────►└─────────└───────────────────────────────────────────────│                 ┌─└─ разработали         conj
#                                                                                                                                                                                                                 │                 │ ┌► преступный          amod
#                                                                                                                                                                                                                 │                 └►└─ план                obj
#                                                                                                                                                                                                                 └────────────────────► .                   punct

# %%
for token in doc.tokens:
    token.lemmatize(morph_vocab)
    
{_.text: _.lemma for _ in doc.tokens[:10]}
# Out:
# {'ПРИГОВОР': 'приговор',
#  '\\': '\\',
#  'n': 'n',
#  'ИМЕНЕМ': 'имя',
#  'РОССИЙСКОЙ': 'российский',
#  'ФЕДЕРАЦИИ': 'федерация',
#  '01': '01',
#  'декабря': 'декабрь'}

# %%
for span in doc.spans:
    span.normalize(morph_vocab)
    
{_.text: _.normal for _ in doc.spans}
# Out:
# {'Москва\\nПреображенский районный суд': 'Москва\\nПреображенский районный суд',
#  'Москвы': 'Москва',
#  'Духновской З.А.': 'Духновской З.А.',
#  'Горшковой А.А.': 'Горшковой А.А.',
#  'Давыдовой Д.Е.': 'Давыдова Д.Е.',
#  'Дудукова М.Ю.': 'Дудукова М.Ю.',
#  'Чубенко А.А.': 'Чубенко А.А.',
#  'А.А.': 'А.А.',
#  'Попова А.В.': 'Попов А.В.',
#  'Колокольниковой Е.В.': 'Колокольниковой Е.В.',
#  'РФ': 'РФ',
#  'Чайхона': 'Чайхона',
#  'Москва': 'Москва',
#  'Службы по': 'Служба по',
#  'ВАО': 'ВАО',
#  'ФСКН': 'ФСКН',
#  'России': 'Россия',
#  'Москве': 'Москва',
#  'Наблюдение': 'Наблюдение',
#  'Службы': 'Служба',
#  'Российской Федерации': 'Российская Федерация',
#  'Правительства': 'Правительство',
#  'А.А.\\nДопрошенный': 'А.А.\\nДопрошенный',
#  'Биткова А.Ю.': 'Битков А.Ю.',
#  'Орел И.В.': 'Орел И.В.',
#  'Самсунг': 'Самсунг',
#  'Русинова А.А.': 'Русинов А.А.',
#  'Русинов А.А.': 'Русины А.А.',
#  'Чайхана': 'Чайхана',
#  'Прасолова Д.А.': 'Прасолова Д.А.',
#  'Кормилицына Д.А.': 'Кормилицына Д.А.',
#  'Лукашенко А.А.': 'Лукашенко А.А.',
#  'ОРМ «Наблюдение»': 'ОРМ «Наблюдение»',
#  'Русинову А.А. Лукашенко': 'Русинову А.А. Лукашенко',
#  'Кормилицыну Д.А.': 'Кормилицын Д.А.',
#  'Русиновым А.А.': 'Русинов А.А.',
#  'SONY ERICSSON': 'SONY ERICSSON',
#  'Билайн': 'Билайн',
#  'Samsung': 'Samsung',
#  'Мегафон': 'Мегафон',
#  'Panasonic': 'Panasonic',
#  'ОРМ «ПТП»': 'ОРМ «ПТП»',
#  'А.А': 'А.А',
#  'ОРМ': 'ОРМ',
#  'Андрея Александровича': 'Андрей Александрович',
#  'А.А.   \\n  Приговор': 'А.А.   \\n  Приговор',
#  'Московский городской суд': 'Московский городской суд',
#  'Соединенных Штатов': 'Соединенные Штаты',
#  'Великобритании': 'Великобритания',
#  'Израиля': 'Израиль',
#  'Южной Африки': 'Южная Африка',
#  'ЧВК': 'ЧВК',
#  'Западе': 'Запад',
#  'Востоке': 'Восток',
#  'Hulliburton': 'Hulliburton',
#  'Blackwater': 'Blackwater',
#  'DynCorp': 'DynCorp',
#  'Logicon': 'Logicon',
#  'MPRI': 'MPRI',
#  'Control Risks': 'Control Risks',
#  'Bechtel': 'Bechtel',
#  'ArmorGroup': 'ArmorGroup',
#  'Erinys': 'Erinys',
#  'Sandline International': 'Sandline International',
#  'Международная оборона и безопасность': 'Международная оборона и безопасность',
#  'Сербскую Краину': 'Сербская Краина',
#  'ООН': 'ООН',
#  'Германии': 'Германия',
#  'Ираке': 'Ирак',
#  'Asgaard German Security Group': 'Asgaard German Security Group',
#  'Известия': 'Известия',
#  'Сомали': 'Сомали',
#  'Сомалийской Республики': 'Сомалийская Республика',
#  'Галадида Дармана': 'Галадида Дарман',
#  'Восточной Европы': 'Восточная Европа',
#  'СССР': 'СССР',
#  'США': 'США',
#  'Афганистане': 'Афганистан',
#  'Пентагон': 'Пентагон',
#  'Китай': 'Китай',
#  'КНР': 'КНР',
#  'Азии': 'Азия',
#  'Африке': 'Африка',
#  'Французской': 'Французская',
#  'Российской империями': 'Российская империи',
#  'Наполеона Бонапарта': 'Наполеон Бонапарт',
#  'Наполеона': 'Наполеон',
#  'Европу': 'Европа',
#  'Франции': 'Франция',
#  'Европе': 'Европа',
#  'Великобритания': 'Великобритания',
#  'Наполеон': 'Наполеон',
#  'Францией': 'Франция',
#  'Россией': 'Россия',
#  'Александр': 'Александр',
#  'Европы': 'Европа',
#  'Французской армией': 'Французская армия',
#  'Российской Империи': 'Российская Империя',
#  'Бородино': 'Бородино',
#  'Москвой': 'Москва',
#  'Цезаря Ложье де Беллекура': 'Цезарь Ложье де Беллекур',
#  'Жорновка': 'Жорновка',
#  'Тверской области': 'Тверская область',
#  'Фёдора Фёдоровича Трефорта': 'Федор Федорович Трефорт',
#  'Твери': 'Тверь',
#  'Трефортов': 'Трефортов',
#  'Тверская область': 'Тверская область',
#  'Неман': 'Неман',
#  'Ковно': 'Ковно',
#  'Наполеоном Бонапартом': 'Наполеон Бонапарт',
#  'М. Б. Барклая-де-Толли': 'М. Б. Барклая-де-Толли',
#  'П. И. Багратиона': 'П. И. Багратион',
#  'А. П. Тормасова': 'А. П. Тормасов',
#  'Александр I': 'Александр I',
#  'Барклая': 'Барклай',
#  'Багратиона': 'Багратион',
#  'Италии': 'Италия',
#  'Евгения Богарне': 'Евгений Богарне',
#  'Вестфалии Жерома Бонапарта': 'Вестфалия Жером Бонапарт',
#  'Макдональда': 'Макдональд',
#  'Петербург': 'Петербург',
#  'Буг': 'Буг',
#  'Австрийский корпус': 'Австрийский корпус',
#  'Шварценберга': 'Шварценберг',
#  'Барклая-де-Толли': 'Барклая-де-Толли',
#  'Империи': 'Империя',
#  'Смоленском': 'Смоленск',
#  'Смоленску': 'Смоленск',
#  'Смоленска': 'Смоленска',
#  'Смоленск': 'Смоленск',
#  'Надежда Наполеона': 'Надежда Наполеона',
#  'Москву': 'Москва',
#  'М.И. Кутузова': 'М.И. Кутузов',
#  'Кутузову': 'Кутузов',
#  'Суворовской школы': 'Суворовская школа',
#  'Кутузов': 'Кутузов',
#  'Россию': 'Россия',
#  'Кальварию': 'Кальварию',
#  'Кальварии': 'Кальварии',
#  'Фридландом': 'Фридланд',
#  'Тильзитом': 'Тильзитом',
#  'Тильзите': 'Тильзит',
#  'Россия': 'Россия',
#  'Англией': 'Англия',
#  'Рейна': 'Рейна',
#  'Аустерлица': 'Аустерлица',
#  'Бородинском поле': 'Бородинское поле',
#  'Фели': 'Фели',
#  'Филях': 'Филях',
#  'Наполеон Бонапарт': 'Наполеон Бонапарт',
#  'Генерала Раппа': 'Генерал Рапп',
#  'Ложье де Беллекура': 'Ложье де Беллекур',
#  'Неаполитанский': 'Неаполитанский',
#  'Мюрат': 'Мюрат',
#  'Верхнего Египта': 'Верхний Египет',
#  'Коленкура': 'Коленкура',
#  'Дель-Фанте': 'Дель-Фанте',
#  'Лихачев': 'Лихачев',
#  'Ложье де Беллекур': 'Ложье де Беллекур',
#  'Наполеоне': 'Наполеон',
#  'Великой армии': 'Великая армия',
#  'Нея': 'Нея',
#  'Ней': 'Ней',
#  'Луи Франсуа Жозеф де Боссе': 'Луи Франсуа Жозеф де Боссе',
#  'Наполеоном': 'Наполеон',
#  'Коленкур': 'Коленкур',
#  'Канвилль': 'Канвилль',
#  'Ваграме': 'Ваграм',
#  'Эслинге': 'Эслинг',
#  'Эйлау': 'Эйлау',
#  'Фридланде': 'Фридланде',
#  'Маренго': 'Маренго',
#  'Адриатики': 'Адриатика',
#  'Калабрии': 'Калабрия',
#  'Центральной': 'Центральная',
#  'Южной Европы': 'Южная Европа',
#  'Луи-Франсуа Лежен': 'Луи-Франсуа Лежен',
#  'Семеновский': 'Семеновский',
#  'Литовский': 'Литовский',
#  'Пьона де Комба': 'Пьон де Комба',
#  'Пьон де Комб': 'Пьон де Комб',
#  'Жан-Рока Куанье': 'Жан-Рока Куанье',
#  'Коленкуру': 'Коленкуру',
#  'Огюста де Коленкура': 'Огюст де Коленкур',
#  'Яблонского': 'Яблонской',
#  'Варшаве': 'Варшава',
#  'Брандт-офицер Вислинского': 'Брандт-офицер Вислинского',
#  'Бородинским полем': 'Бородинское поле',
#  'Лихачева': 'Лихачев',
#  'Колоче': 'Колоче',
#  'Вислинского легиона\\n': 'Вислинский легион\\n',
#  'Десэ': 'Десэ',
#  'Бресанда': 'Бресанд',
#  'Магнаном': 'Магнаном',
#  'Явившийся': 'Явившийся',
#  'Ларрей': 'Ларрей',
#  'Ларрея': 'Ларрей',
#  'Доминик Жан Ларрей-': 'Доминик Жан Ларрей-',
#  'Бородинское сражение-это': 'Бородинское сражение-это',
#  'Вильной': 'Вильной',
#  'Фёдор Фёдорович Трефорт': 'Федор Федорович Трефорт',
#  'Фёдор Трефорт': 'Федор Трефорт',
#  'Суворова': 'Суворов',
#  'Швейцарии': 'Швейцария',
#  'Австрии': 'Австрия',
#  'Восточной Пруссии': 'Восточная Пруссия',
#  'Трефорт': 'Трефорт',
#  'Тобольского пехотного полка': 'Тобольский пехотный полок',
#  'Раевского': 'Раевский',
#  'Калише': 'Калиш',
#  'Ф.Ф. Трефорт': 'Ф.Ф. Трефорт',
#  'Люценом': 'Люцен',
#  'Фёдор Фёдорович': 'Федор Федорович',
#  'Тобольский полк': 'Тобольский полк',
#  'Тверь': 'Тверь',
#  'Тверью': 'Тверью',
#  'Трефорта': 'Трефорт',
#  'Андрей Чаплыгин': 'Андрей Чаплыгин',
#  'Николай Беляев': 'Николай Беляев',
#  'Леонардо Да Винчи': 'Леонардо Да Винчи',
#  'Подольск': 'Подольск',
#  'Древней Греции': 'Древняя Греция',
#  'Парфенона': 'Парфенона',
#  'Поликлета': 'Поликлета',
#  'AB': 'AB',
#  'Пифагор': 'Пифагор',
#  'Леонарда Эйлера': 'Леонард Эйлер',
#  'Лейбниц': 'Лейбниц',
#  'Гольбаху': 'Гольбаху',
#  'Гольбах': 'Гольбах',
#  'Храма Знамения Пресвятой Богородицы': 'Храм Знамения Пресвятой Богородицы',
#  'Абхазии': 'Абхазия',
#  'Института археологии': 'Институт археологии',
#  'РАН': 'РАН',
#  'Очамчира': 'Очамчира',
#  'Республика Абхазия': 'Республика Абхазия',
#  'Колхиды': 'Колхиды',
#  'Северном Кавказе': 'Северный Кавказ',
#  'Сауар': 'Сауар',
#  'Северной Осетии': 'Северная Осетия',
#  'Очамчиры': 'Очамчиры',
#  'Гиеноса': 'Гиеноса',
#  'Очамчирской': 'Очамчирская',
#  'ИА РАН': 'ИА РАН',
#  'Александр Скаков': 'Александр Скаков',
#  'Гиеноса (Гюэноса)': 'Гиенос (Гюэноса)',
#  'Псевдо-Скилака': 'Псевдо-Скилак',
#  'Черноморского побережья': 'Черноморское побережье',
#  'Кавказа': 'Кавказ',
#  'Гиенос': 'Гиенос',
#  'Диоскурида': 'Диоскурида',
#  'Гиэнос': 'Гиэнос',
#  'Херобий': 'Херобий',
#  'Хоре': 'Хоре',
#  'Арий': 'Арий',
#  'Фасис': 'Фасис',
#  'Медея': 'Медея',
#  'Диоскуриады': 'Диоскуриады',
#  'Питиунта': 'Питиунт',
#  'Северном': 'Северный',
#  'Восточном Причерноморье': 'Восточный Причерноморье',
#  'Очамчирская': 'Очамчирская',
#  'Птах-Патека': 'Птах-Патек',
#  'Навкратис': 'Навкратис',
#  'Птах-Патек': 'Птах-Патек',
#  'Сухума': 'Сухум',
#  'Вооруженные Силы': 'Вооруженные Силы',
#  'Вооруженных Силах': 'Вооруженные Силы',
#  'Вооруженных Сил': 'Вооруженные Силы',
#  'Министерством обороны': 'Министерство обороны',
#  'Кремль': 'Кремль',
#  'Вальтера Скотта': 'Вальтер Скотт',
#  'Пушкин': 'Пушкин',
#  'Уралу': 'Урал',
#  'Пётр Гринёв': 'Петр Гринев',
#  'Вашарина': 'Вашарин',
#  'Михельсона': 'Михельсон',
#  'Швабрина': 'Швабрин',
#  'Пугачёву': 'Пугачев',
#  'Шванович': 'Шванович',
#  'Марии Мироновой': 'Мария Миронова',
#  'Марией Васильевной Борисовой': 'Мария Васильевна Борисова',
#  'Швабрин': 'Швабрин',
#  'Марьей': 'Марьей',
#  'Капитанская дочка': 'Капитанская дочка',
#  'Емельян Пугачев': 'Емельян Пугачев',
#  'Екатерина Вторая': 'Екатерина Вторая',
#  'Многомудрый Литрекон': 'Многомудрый Литрекон',
#  'Миронова': 'Миронов',
#  'Петра': 'Петр',
#  'Гринёва': 'Гринев',
#  'Пугачёв': 'Пугачев',
#  'Мария Миронова': 'Мария Миронова',
#  'Пётр': 'Петр',
#  'Оренбурга': 'Оренбург',
#  'Емельян Пугачёв': 'Емельян Пугачев',
#  'Белогорской крепости': 'Белогорская крепость',
#  'Марию Миронову': 'Мария Миронову',
#  'Алексеем Швабриным': 'Алексей Швабрин',
#  'Пугачёвым': 'Пугачев',
#  'Гринёв': 'Гринев',
#  'Емельян': 'Емельян',
#  'Маша': 'Маша',
#  'Пугачёва': 'Пугачев',
#  'Миронову': 'Миронов',
#  'Екатериной II': 'Екатерина II',
#  'Многомудрого Литрекона': 'Многомудрого Литрекона',
#  'Пушкиным': 'Пушкин',
#  'Петр': 'Петр',
#  'Марья Миронова': 'Марья Миронова',
#  'Петру': 'Петр',
#  'Пушкина': 'Пушкин',
#  'Иван Миронов': 'Иван Миронов',
#  'Василиса Миронова': 'Василиса Миронова',
#  'Пётр III': 'Петр III',
#  'Петра Гринёва': 'Петр Гринев',
#  'Алексей Швабрин': 'Алексей Швабрин',
#  'Гринёвым': 'Гринев',
#  'Екатерина II': 'Екатерина II',
#  'Милосердно': 'Милосердно',
#  'Маши': 'Маша',
#  'Петра Гринева': 'Петр Гринев',
#  'Гриневу': 'Гринев',
#  'Петра Третьего': 'Петр Третий',
#  'Пугачеву': 'Пугачев',
#  'Алексея': 'Алексей',
#  'Марью': 'Марью',
#  'Марья': 'Марья',
#  'Казань': 'Казань',
#  'Василиса Егоровна': 'Василиса Егоровна',
#  'Алексей': 'Алексей',
#  'Гринев': 'Гринев',
#  'Гринёву': 'Гриневу',
#  'Семеновском полку': 'Семеновский полк',
#  'Миронов': 'Миронов',
#  'Екатерины II': 'Екатерина II',
#  'Пугачев': 'Пугачев',
#  'Василису Егоровну': 'Василиса Егоровну',
#  'Пугачева': 'Пугачев',
#  'Российской империи': 'Российская империя',
#  'Пугачёвщины': 'Пугачевщины',
#  'Петр Гринев': 'Петр Гринев',
#  'Емельяна Пугачёва': 'Емельян Пугачев',
#  'Екатерины Второй': 'Екатерина Второй',
#  'Урала': 'Урал',
#  'Поволжья': 'Поволжье',
#  'Белогорская крепость': 'Белогорская крепость',
#  'Татищевской': 'Татищевской',
#  'Достоевский': 'Достоевский',
#  'Гоголь': 'Гоголь',
#  'Н. В. Гоголь': 'Н. В. Гоголь',
#  'Н. Я. Прокоповичу': 'Н. Я. Прокоповичу',
#  'В. Ф. Одоевский': 'В. Ф. Одоевский',
#  'Покаместь Швабрин': 'Покаместь Швабрин',
#  'Марии': 'Мария',
#  'В. Г. Белинский': 'В. Г. Белинский',
#  'Марьи Мироновой': 'Марьи Миронова',
#  'П.И. Чайковский': 'П.И. Чайковский',
#  'Капитанской дочке': 'Капитанская дочка',
#  'Марью Миронову': 'Марью Миронов',
#  'Екатерины': 'Екатерина',
#  'Савельича': 'Савельича',
#  'Калеба': 'Калеб',
#  'Зурина': 'Зурина',
#  'Ивана Игнатьевича': 'Иван Игнатьевич',
#  'В. А. Соллогуб': 'В. А. Соллогуб',
#  'Пугачевского': 'Пугачевский',
#  'Н. Н. Страхов': 'Н. Н. Страхов',
#  'В. О. Ключевский': 'В. О. Ключевский',
#  'А. М. Скабичевский': 'А. М. Скабичевский',
#  'Михаил Щепин': 'Михаил Щепин',
#  'Российская Федерация': 'Российская Федерация',
#  'Российской Федерции': 'Российская Федерция',
#  'ВЭП': 'ВЭП',
#  'ВЭД': 'ВЭД',
#  'ВТО': 'ВТО',
#  'ОЭСР': 'ОЭСР',
#  'ЮНКТАД': 'ЮНКТАД',
#  'Комиссия': 'Комиссия',
#  'Всемирная торговая организация (ВТО)': 'Всемирная торговая организация (ВТО)',
#  'Соединенных Штатов Америки': 'Соединенные Штаты Америка',
#  'Банка России': 'Банк России',
#  'МРТ': 'МРТ',
#  'Данио-рерио': 'Данио-рерио',
#  'Данио': 'Данио',
#  'Малой Азии': 'Малая Азия',
#  'Магнезии': 'Магнезия',
#  'Хванг Ти': 'Хванг Ти',
#  'Китае': 'Китай',
#  'Петром Перегрином': 'Петр Перегрин',
#  'Перегрин': 'Перегрин',
#  'Уильяма Гильберта': 'Уильям Гильберт',
#  'Гильберт': 'Гильберт',
#  'Ханс Кристиан Эрстед': 'Ханс Кристиан Эрстед',
#  'Эрстеда': 'Эрстед',
#  'Андре Мари Ампер': 'Андре Мари Ампер',
#  'Ампера': 'Ампер',
#  'Лоренца\\n Сила Лоренца': 'Лоренц\\n Сила Лоренц',
#  'Лоренца': 'Лоренц',
#  'Ампер': 'Ампер',
#  'Б.С. Якоби': 'Б.С. Якоби',
#  'Амперу': 'Амперу',
#  'Самюэль Морзе': 'Самюэль Морзе',
#  'Морзе': 'Морзе',
#  'Гаусс': 'Гаусс',
#  'Луне': 'Луна',
#  'Советский Союз': 'Советский Союз',
#  'Земли': 'Земля',
#  'Дубне': 'Дубне',
#  'СВЧ-поле': 'СВЧ-пол',
#  'Добровольческой армии': 'Добровольческая армия',
#  'Белого движения': 'Белое движение',
#  'С.В. Волковым': 'С.В. Волков',
#  'Первом Кубанском': 'Первый Кубанский',
#  'Бахметьевском архиве': 'Бахметьевский архив',
#  'Колумбийского университета': 'Колумбийский университет',
#  'В.Н. Биркина': 'В.Н. Биркин',
#  'Василий Николаевич Биркин': 'Василий Николаевич Биркин',
#  'Харьковской губернии': 'Харьковская губерния',
#  'Донской кадетский корпус': 'Донской кадетский корпус',
#  'Александра\u202fIII': 'Александр III',
#  'Новочеркасске': 'Новочеркасск',
#  'Биркин': 'Биркин',
#  'Таврический полк': 'Таврический полк',
#  'Западном фронте': 'Западный фронт',
#  'Дон': 'Дон',
#  'Донского кадетского корпуса': 'Донский кадетский корпус',
#  'Дона': 'Дон',
#  'Донского отряда походного атамана донских казаков': 'Донский отряд походного атамана донских казаков',
#  'П.Х. Попова': 'П.Х. Попов',
#  'Степной поход': 'Степной поход',
#  'Весёлой': 'Веселой',
#  'Донской': 'Донской',
#  'Л.Г. Корниловым': 'Л.Г. Корниловым',
#  'Первого Кубанского похода': 'Первый Кубанский поход',
#  'Маркова': 'Марков',
#  'Дон Биркин': 'Дон Биркин',
#  'Донского кадетского корпуса эвакуировался': 'Донский кадетский корпус эвакуировавшийся',
#  'Египет': 'Египет',
#  'Германию': 'Германия',
#  'Биркина': 'Биркин',
#  'Новолеушковской': 'Новолеушковской',
#  'Р. Г.': 'Р. Г.',
#  'Старолеушковскую': 'Старолеушковскую',
#  'Не-е-е': 'Не-е-е',
#  'Японскую войну': 'Японская война',
#  'Ольсивическом': 'Ольсивический',
#  'Фердинандовым Носом': 'Фердинандовым Нос',
#  'Таврического полка': 'Таврический полок',
#  'Белоруссии': 'Белоруссия',
#  'Л.Г. Корнилов': 'Л.Г. Корнилов',
#  'Корниловского ударного полка': 'Корниловский ударный полок',
#  'В.М. Заремба': 'В.М. Заремба',
#  'М.О. Неженцев': 'М.О. Неженцев',
#  'Ростов-на-Дону': 'Ростов-на-Дону',
#  'Славко': 'Славко',
#  'В.С.] Арендт': 'В.С.] Арендт',
#  'С.Л.] Маркова': 'С.Л.] Марков',
#  'Чирикова': 'Чириков',
#  'Старолеушковской': 'Старолеушковская',
#  'Р. Г.]': 'Р. Г.]',
#  'А.Е.] Дударов': 'А.Е.] Дударов',
#  'Арендта': 'Арендт',
#  'Таврического': 'Таврического',
#  'Его Императорского Высочества Великого князя Михаила Николаевича полка': 'Его Императорский Высочества Великий князь Михаила Николаевича полок',
#  'Корниловского полка': 'Корниловский полок',
#  'Полковник': 'Полковник',
#  'Лежанке': 'Лежанке',
#  'Руслан Гагкуев': 'Руслан Гагкуев',
#  'ВОЗ': 'ВОЗ',
#  'Таджикистане': 'Таджикистан',
#  'Украины': 'Украина',
#  'Узбекистане': 'Узбекистан',
#  'Ташкент': 'Ташкент',
#  'Ташкентская': 'Ташкентская',
#  'Андижанская': 'Андижанская',
#  'Ферганская': 'Ферганская',
#  'Навоинская': 'Навоинская',
#  'Джизакской': 'Джизакской',
#  'Кашкадарьинской областях': 'Кашкадарьинская области',
#  'Республики Узбекистан': 'Республика Узбекистан',
#  'ЭКОСАН': 'ЭКОСАН',
#  'Республиканский онкологический центр': 'Республиканский онкологический центр',
#  'Ташкенте': 'Ташкент',
#  'Центральной Азии': 'Центральная Азия',
#  'Узбекистана': 'Узбекистан',
#  'Киеве': 'Киев',
#  'Гриш': 'Гриш',
#  'Володя': 'Володя',
#  'Мерцаловы': 'Мерцаловы',
#  'Гриша': 'Гриша',
#  'Отдал': 'Отдавший',
#  'Мерцалова': 'Мерцалова',
#  'Швейцар': 'Швейцар',
#  'Матушка': 'Матушка',
#  'Савелий Петрович': 'Савелий Петрович',
#  'Володьку': 'Володьку',
#  'Машутки': 'Машутки',
#  'Мерцалов': 'Мерцалов',
#  'Ивановне': 'Ивановна',
#  'Елизавета Ивановна': 'Елизавета Ивановна',
#  'Машутке': 'Машуток',
#  'Морозно': 'Морозно',
#  'Подарочки': 'Подарочки',
#  'Едемте': 'Едемте',
#  'Елизавете Ивановне': 'Елизавета Ивановна',
#  'Елизавету Ивановну': 'Елизавета Ивановну',
#  'Гришка': 'Гришка',
#  'Машутку': 'Машутку',
#  'Афросимова': 'Афросимов',
#  'Мерцалову': 'Мерцалов',
#  'Володю': 'Володя',
#  'Григория Емельяновича Мерцалова': 'Григорий Емельянович Мерцалов',
#  'Гришки': 'Гришка',
#  'Вишню': 'Вишню',
#  'Глеб Гаврилович Смирнов': 'Глеб Гаврилович Смирнов',
#  'Гнилушки': 'Гнилушки',
#  'Девкино': 'Девкино',
#  'Хохотова': 'Хохотов',
#  'Чёрт': 'Черт',
#  'Лошаденка': 'Лошаденка',
#  'До-о-едем': 'До-о-едем',
#  'Клим': 'Клим',
#  'Сибирь': 'Сибирь',
#  'Климушка': 'Климушка',
#  'Голубчик': 'Голубчик'}

# %%
for span in doc.spans:
    if span.type == PER:
        span.extract_fact(names_extractor)
    
{_.normal: _.fact.as_dict for _ in doc.spans if _.fact}
# Out:
# {'Духновской З.А.': {'first': 'З', 'last': 'Духновской', 'middle': 'А'},
#  'Горшковой А.А.': {'first': 'А', 'last': 'Горшковой', 'middle': 'А'},
#  'Давыдова Д.Е.': {'first': 'Д', 'last': 'Давыдова', 'middle': 'Е'},
#  'Дудукова М.Ю.': {'first': 'М', 'last': 'Дудукова', 'middle': 'Ю'},
#  'Чубенко А.А.': {'first': 'А', 'last': 'Чубенко', 'middle': 'А'},
#  'А.А.': {'last': 'А'},
#  'Попов А.В.': {'first': 'А', 'last': 'Попов', 'middle': 'В'},
#  'Колокольниковой Е.В.': {'first': 'Е',
#   'last': 'Колокольниковой',
#   'middle': 'В'},
#  'А.А.\\nДопрошенный': {'last': 'А'},
#  'Битков А.Ю.': {'first': 'А', 'last': 'Битков', 'middle': 'Ю'},
#  'Орел И.В.': {'first': 'И', 'last': 'Орел', 'middle': 'В'},
#  'Русинов А.А.': {'first': 'А', 'last': 'Русинов', 'middle': 'А'},
#  'Прасолова Д.А.': {'first': 'Д', 'last': 'Прасолова', 'middle': 'А'},
#  'Кормилицына Д.А.': {'first': 'Д', 'last': 'Кормилицына', 'middle': 'А'},
#  'Лукашенко А.А.': {'first': 'А', 'last': 'Лукашенко', 'middle': 'А'},
#  'Русинову А.А. Лукашенко': {'first': 'А', 'last': 'Русинову', 'middle': 'А'},
#  'Кормилицын Д.А.': {'first': 'Д', 'last': 'Кормилицын', 'middle': 'А'},
#  'Русины А.А.': {'first': 'А', 'last': 'Русины', 'middle': 'А'},
#  'А.А': {'last': 'А'},
#  'Андрей Александрович': {'first': 'Андрей', 'last': 'Александрович'},
#  'А.А.   \\n  Приговор': {'last': 'А'},
#  'Галадида Дарман': {'first': 'Галадида', 'last': 'Дарман'},
#  'Наполеон Бонапарт': {'first': 'Наполеон', 'last': 'Бонапарт'},
#  'Наполеон': {'first': 'Наполеон'},
#  'Александр': {'first': 'Александр'},
#  'Цезарь Ложье де Беллекур': {'last': 'Цезарь'},
#  'Федор Федорович Трефорт': {'first': 'Федор',
#   'last': 'Трефорт',
#   'middle': 'Федорович'},
#  'Трефортов': {'last': 'Трефортов'},
#  'М. Б. Барклая-де-Толли': {'first': 'М', 'last': 'Барклая', 'middle': 'Б'},
#  'П. И. Багратион': {'first': 'П', 'last': 'Багратион', 'middle': 'И'},
#  'А. П. Тормасов': {'first': 'А', 'last': 'Тормасов', 'middle': 'П'},
#  'Александр I': {'first': 'Александр', 'last': 'I'},
#  'Барклай': {'first': 'Барклай'},
#  'Евгений Богарне': {'first': 'Евгений', 'last': 'Богарне'},
#  'Вестфалия Жером Бонапарт': {'first': 'Вестфалия', 'last': 'Жером'},
#  'Макдональд': {'first': 'Макдональд'},
#  'Шварценберг': {'last': 'Шварценберг'},
#  'Барклая-де-Толли': {'first': 'Барклая'},
#  'Багратион': {'last': 'Багратион'},
#  'Надежда Наполеона': {'first': 'Надежда', 'last': 'Наполеона'},
#  'М.И. Кутузов': {'first': 'М', 'last': 'Кутузов', 'middle': 'И'},
#  'Кутузов': {'last': 'Кутузов'},
#  'Фридландом': {'first': 'Фридландом'},
#  'Рейна': {'first': 'Рейна'},
#  'Генерал Рапп': {'last': 'Генерал'},
#  'Ложье де Беллекур': {'last': 'де'},
#  'Мюрат': {'first': 'Мюрат'},
#  'Дель-Фанте': {'last': 'Дель'},
#  'Лихачев': {'last': 'Лихачев'},
#  'Луи Франсуа Жозеф де Боссе': {'first': 'Луи', 'last': 'Франсуа'},
#  'Канвилль': {'first': 'Канвилль'},
#  'Ваграм': {'first': 'Ваграм'},
#  'Эслинг': {'first': 'Эслинг'},
#  'Фридланде': {'first': 'Фридланде'},
#  'Маренго': {'last': 'Маренго'},
#  'Луи-Франсуа Лежен': {'first': 'Луи'},
#  'Пьон де Комба': {'last': 'де'},
#  'Пьон де Комб': {'last': 'де'},
#  'Жан-Рок Куанье': {'first': 'Жан'},
#  'Жан-Рока Куанье': {'first': 'Жан'},
#  'Огюст де Коленкур': {'first': 'Огюст'},
#  'Яблонской': {'last': 'Яблонской'},
#  'Брандт-офицер Вислинского': {'first': 'Брандт'},
#  'Десэ': {'first': 'Десэ'},
#  'Бресанд': {'first': 'Бресанд'},
#  'Магнаном': {'first': 'Магнаном'},
#  'Ларрей': {'last': 'Ларрей'},
#  'Доминик Жан Ларрей-': {'first': 'Доминик', 'last': 'Жан'},
#  'Федор Трефорт': {'first': 'Федор', 'last': 'Трефорт'},
#  'Суворов': {'last': 'Суворов'},
#  'Раевский': {'last': 'Раевский'},
#  'Ф.Ф. Трефорт': {'first': 'Ф', 'last': 'Трефорт', 'middle': 'Ф'},
#  'Федор Федорович': {'first': 'Федор', 'last': 'Федорович'},
#  'Андрей Чаплыгин': {'first': 'Андрей', 'last': 'Чаплыгин'},
#  'Николай Беляев': {'first': 'Николай', 'last': 'Беляев'},
#  'Леонардо Да Винчи': {'first': 'Леонардо', 'last': 'Да'},
#  'Пифагор': {'first': 'Пифагор'},
#  'Леонард Эйлер': {'first': 'Леонард', 'last': 'Эйлер'},
#  'Лейбниц': {'last': 'Лейбниц'},
#  'Гольбаху': {'last': 'Гольбаху'},
#  'Гольбах': {'last': 'Гольбах'},
#  'Александр Скаков': {'first': 'Александр', 'last': 'Скаков'},
#  'Псевдо-Скилак': {'first': 'Псевдо'},
#  'Медея': {'first': 'Медея'},
#  'Очамчирская': {'last': 'Очамчирская'},
#  'Птах-Патек': {'last': 'Птах'},
#  'Навкратис': {'first': 'Навкратис'},
#  'Вальтер Скотт': {'first': 'Вальтер', 'last': 'Скотт'},
#  'Пушкин': {'last': 'Пушкин'},
#  'Петр Гринев': {'first': 'Петр', 'last': 'Гринев'},
#  'Вашарин': {'first': 'Вашарин'},
#  'Михельсон': {'last': 'Михельсон'},
#  'Швабрина': {'first': 'Швабрина'},
#  'Пугачеву': {'last': 'Пугачеву'},
#  'Мария Миронова': {'first': 'Мария', 'last': 'Миронова'},
#  'Мария Васильевна Борисова': {'first': 'Мария',
#   'last': 'Борисова',
#   'middle': 'Васильевна'},
#  'Швабрин': {'first': 'Швабрин'},
#  'Марьей': {'first': 'Марьей'},
#  'Емельян Пугачев': {'first': 'Емельян', 'last': 'Пугачев'},
#  'Екатерина Вторая': {'first': 'Екатерина', 'last': 'Вторая'},
#  'Миронов': {'first': 'Миронов'},
#  'Петр': {'first': 'Петр'},
#  'Гринева': {'last': 'Гринева'},
#  'Пугачев': {'last': 'Пугачев'},
#  'Мария Миронову': {'first': 'Мария', 'last': 'Миронову'},
#  'Алексей Швабрин': {'first': 'Алексей', 'last': 'Швабрин'},
#  'Гринев': {'last': 'Гринев'},
#  'Емельян': {'first': 'Емельян'},
#  'Маша': {'first': 'Маша'},
#  'Екатерина II': {'first': 'Екатерина', 'last': 'II'},
#  'Марья Миронова': {'first': 'Марья', 'last': 'Миронова'},
#  'Иван Миронов': {'first': 'Иван', 'last': 'Миронов'},
#  'Василиса Миронова': {'first': 'Василиса', 'last': 'Миронова'},
#  'Петр III': {'first': 'Петр', 'last': 'III'},
#  'Милосердно': {'last': 'Милосердно'},
#  'Петр Третий': {'first': 'Петр', 'last': 'Третий'},
#  'Алексей': {'first': 'Алексей'},
#  'Марью': {'first': 'Марью'},
#  'Марья': {'first': 'Марья'},
#  'Василиса Егоровна': {'first': 'Василиса', 'last': 'Егоровна'},
#  'Гриневу': {'last': 'Гриневу'},
#  'Василиса Егоровну': {'first': 'Василиса', 'last': 'Егоровну'},
#  'Екатерина Второй': {'first': 'Екатерина', 'last': 'Второй'},
#  'Татищевской': {'last': 'Татищевской'},
#  'Достоевский': {'last': 'Достоевский'},
#  'Гоголь': {'last': 'Гоголь'},
#  'Н. В. Гоголь': {'first': 'Н', 'last': 'Гоголь', 'middle': 'В'},
#  'Н. Я. Прокоповичу': {'first': 'Н', 'last': 'Прокоповичу', 'middle': 'Я'},
#  'В. Ф. Одоевский': {'first': 'В', 'last': 'Одоевский', 'middle': 'Ф'},
#  'Покаместь Швабрин': {'first': 'Швабрин', 'last': 'Покаместь'},
#  'Мария': {'first': 'Мария'},
#  'В. Г. Белинский': {'first': 'В', 'last': 'Белинский', 'middle': 'Г'},
#  'Марьи Миронова': {'first': 'Марьи', 'last': 'Миронова'},
#  'П.И. Чайковский': {'first': 'П', 'last': 'Чайковский', 'middle': 'И'},
#  'Марью Миронов': {'first': 'Марью', 'last': 'Миронов'},
#  'Екатерина': {'first': 'Екатерина'},
#  'Зурина': {'first': 'Зурина'},
#  'Иван Игнатьевич': {'first': 'Иван', 'last': 'Игнатьевич'},
#  'В. А. Соллогуб': {'first': 'В', 'last': 'Соллогуб', 'middle': 'А'},
#  'Н. Н. Страхов': {'first': 'Н', 'last': 'Страхов', 'middle': 'Н'},
#  'В. О. Ключевский': {'first': 'В', 'last': 'Ключевский', 'middle': 'О'},
#  'А. М. Скабичевский': {'first': 'А', 'last': 'Скабичевский', 'middle': 'М'},
#  'Михаил Щепин': {'first': 'Михаил', 'last': 'Щепин'},
#  'Хванг Ти': {'first': 'Хванг', 'last': 'Ти'},
#  'Петр Перегрин': {'first': 'Петр', 'last': 'Перегрин'},
#  'Перегрин': {'last': 'Перегрин'},
#  'Уильям Гильберт': {'first': 'Уильям', 'last': 'Гильберт'},
#  'Гильберт': {'last': 'Гильберт'},
#  'Ханс Кристиан Эрстед': {'first': 'Ханс'},
#  'Андре Мари Ампер': {'first': 'Андре', 'last': 'Мари'},
#  'Ампера': {'last': 'Ампера'},
#  'Ампер': {'last': 'Ампер'},
#  'Лоренц\\n Сила Лоренц': {'last': 'Лоренц'},
#  'Лоренц': {'last': 'Лоренц'},
#  'Б.С. Якоби': {'first': 'Б', 'last': 'Якоби', 'middle': 'С'},
#  'Амперу': {'last': 'Амперу'},
#  'Самюэль Морзе': {'first': 'Самюэль', 'last': 'Морзе'},
#  'Морзе': {'last': 'Морзе'},
#  'Гаусс': {'last': 'Гаусс'},
#  'С.В. Волков': {'first': 'С', 'last': 'Волков', 'middle': 'В'},
#  'В.Н. Биркин': {'first': 'В', 'last': 'Биркин', 'middle': 'Н'},
#  'Василий Николаевич Биркин': {'first': 'Василий',
#   'last': 'Биркин',
#   'middle': 'Николаевич'},
#  'Александр III': {'first': 'Александр', 'last': 'III'},
#  'Биркин': {'last': 'Биркин'},
#  'Дон': {'first': 'Дон'},
#  'П.Х. Попов': {'first': 'П', 'last': 'Попов', 'middle': 'Х'},
#  'Донской': {'last': 'Донской'},
#  'Л.Г. Корниловым': {'first': 'Л', 'last': 'Корниловым', 'middle': 'Г'},
#  'Марков': {'first': 'Марков'},
#  'Дон Биркин': {'first': 'Дон', 'last': 'Биркин'},
#  'Р. Г.': {'last': 'Р'},
#  'Не-е-е': {'last': 'Не'},
#  'Л.Г. Корнилов': {'first': 'Л', 'last': 'Корнилов', 'middle': 'Г'},
#  'В.М. Заремба': {'first': 'В', 'last': 'Заремба', 'middle': 'М'},
#  'М.О. Неженцев': {'first': 'М', 'last': 'Неженцев', 'middle': 'О'},
#  'Славко': {'last': 'Славко'},
#  'В.С.] Арендт': {'last': 'В'},
#  'С.Л.] Марков': {'last': 'С'},
#  'Чириков': {'last': 'Чириков'},
#  'Р. Г.]': {'last': 'Р'},
#  'А.Е.] Дударов': {'last': 'А'},
#  'Арендт': {'last': 'Арендт'},
#  'Полковник': {'last': 'Полковник'},
#  'Руслан Гагкуев': {'first': 'Руслан', 'last': 'Гагкуев'},
#  'Андижанская': {'last': 'Андижанская'},
#  'Ферганская': {'last': 'Ферганская'},
#  'Навоинская': {'last': 'Навоинская'},
#  'Гриш': {'first': 'Гриш'},
#  'Володя': {'first': 'Володя'},
#  'Мерцаловы': {'last': 'Мерцаловы'},
#  'Гриша': {'first': 'Гриша'},
#  'Мерцалов': {'last': 'Мерцалов'},
#  'Савелий Петрович': {'first': 'Савелий', 'last': 'Петрович'},
#  'Володьку': {'first': 'Володьку'},
#  'Машутки': {'first': 'Машутки'},
#  'Елизавета Ивановна': {'first': 'Елизавета', 'last': 'Ивановна'},
#  'Мерцалова': {'last': 'Мерцалова'},
#  'Машуток': {'first': 'Машуток'},
#  'Морозно': {'last': 'Морозно'},
#  'Подарочки': {'last': 'Подарочки'},
#  'Елизавета Ивановну': {'first': 'Елизавета', 'last': 'Ивановну'},
#  'Гришка': {'first': 'Гришка'},
#  'Машутку': {'first': 'Машутку'},
#  'Афросимов': {'first': 'Афросимов'},
#  'Григорий Емельянович Мерцалов': {'first': 'Григорий',
#   'last': 'Мерцалов',
#   'middle': 'Емельянович'},
#  'Вишню': {'last': 'Вишню'},
#  'Глеб Гаврилович Смирнов': {'first': 'Глеб',
#   'last': 'Смирнов',
#   'middle': 'Гаврилович'},
#  'Черт': {'last': 'Черт'},
#  'До-о-едем': {'last': 'До'},
#  'Клим': {'first': 'Клим'},
#  'Климушка': {'last': 'Климушка'},
#  'Голубчик': {'last': 'Голубчик'}}

# %%
forms = morph_vocab('стали')
forms
# Out:
# [MorphForm(normal='стать', pos='VERB', feats={'VerbForm': 'Fin', 'Aspect': 'Perf', 'Number': 'Plur', 'Tense': 'Past', 'Mood': 'Ind'}),
#  MorphForm(normal='сталь', pos='NOUN', feats={'Animacy': 'Inan', 'Gender': 'Fem', 'Number': 'Sing', 'Case': 'Gen'}),
#  MorphForm(normal='сталь', pos='NOUN', feats={'Animacy': 'Inan', 'Gender': 'Fem', 'Number': 'Plur', 'Case': 'Nom'}),
#  MorphForm(normal='сталь', pos='NOUN', feats={'Animacy': 'Inan', 'Gender': 'Fem', 'Number': 'Sing', 'Case': 'Dat'}),
#  MorphForm(normal='сталь', pos='NOUN', feats={'Animacy': 'Inan', 'Gender': 'Fem', 'Number': 'Sing', 'Case': 'Loc'}),
#  MorphForm(normal='сталь', pos='NOUN', feats={'Animacy': 'Inan', 'Gender': 'Fem', 'Number': 'Plur', 'Case': 'Acc'})]

# %%
morph_vocab.__call__.cache_info()
# Out:
# CacheInfo(hits=25315, misses=10850, maxsize=10000, currsize=10000)

# %%
morph_vocab.lemmatize('стали', 'VERB', {})
# Out:
# 'стать'

# %%
morph_vocab.lemmatize('стали', 'X', {'Case': 'Gen'})
# Out:
# 'сталь'

# %%
print('Words in vocab + 2 for pad and unk: %d' % len(emb.vocab.words) )
# Out:
# Words in vocab + 2 for pad and unk: 250002

# %%
emb['навек'][:100]
# Out:
# array([ 0.3309305 ,  0.18249014,  0.23347412,  0.14935994, -0.17402406,
#        -0.47864223, -0.24524143,  0.15673256, -0.08669729, -0.11727095,
#         0.13135901,  0.5481293 ,  0.7048632 ,  0.22077431, -0.78015256,
#         0.43273082,  0.13458823,  0.6609183 ,  0.03002832,  0.14311466,
#        -0.5047413 ,  0.4969848 ,  0.14717759,  0.38688493,  0.3237942 ,
#        -0.04422767,  0.18814448,  0.53533834,  0.00823402, -0.00508584,
#         0.01242104, -0.24465695, -0.02266642,  0.3197186 , -0.03069695,
#         0.16558675,  0.16404535, -0.19663632,  0.63850045, -0.42745766,
#        -0.18280992, -0.17906225,  0.33154383,  0.05501431,  0.04037222,
#        -0.3435012 , -0.35397884,  0.03054078, -0.01661319, -0.11361139,
#         0.10814258, -0.09624135, -0.12813228,  0.10973183,  0.18781611,
#        -0.10195816,  0.22453588, -0.20526455, -0.33552003,  0.1652816 ,
#         0.54490954,  0.9377614 , -0.2514508 , -0.5247126 ,  0.33496034,
#        -0.19549994, -0.29204327,  0.33321744, -0.38820186,  0.06752613,
#         0.29465148,  0.2497819 , -0.36366552, -0.10175869, -0.34384972,
#        -0.06889932, -0.18760093, -0.16136989,  0.5067996 ,  0.44330174,
#        -0.12642021, -1.030235  , -0.12297952, -0.07049348, -0.37420636,
#        -0.00412196, -0.1205455 , -0.01730496,  0.1395569 ,  0.26324365,
#         0.41065142,  0.28789604, -0.3920543 ,  0.5264155 , -0.39986327,
#         0.03105181, -0.18054019, -0.42718935,  0.25011477,  0.36638457],
#       dtype=float32)

# %%
markup = ner_tagger(text)
markup.print()
# Out:
# ПРИГОВОР\nИМЕНЕМ  РОССИЙСКОЙ ФЕДЕРАЦИИ\n01 декабря 2016 года
#
# Москва\nПреображенский районный суд Москвы в составе судьи Духновской
# LOC──────────────────────────────── LOC───                 PER────────
# З.А., при секретаре Горшковой А.А., с участием государственных
# ────                PER───────────
# обвинителей Давыдовой Д.Е., Дудукова М.Ю., Чубенко А.А., подсудимого
#             PER───────────  PER──────────  PER─────────
# ************а А.А., его защитников – адвокатов Попова А.В.,
#               PER─                             PER────────
# Колокольниковой Е.В., рассмотрев в открытом судебном заседании
# PER─────────────────
# уголовное дело по обвинению:\n************ ****** **************, **
# ** **** года рождения, уроженца г. Москвы, гражданина РФ,
#                                    LOC───             LO
# зарегистрированного по адресу: *****************, со средне-
# специальным образованием, холостого, не работающего, не судимого,  в
# совершении преступления, предусмотренного ч. 3 ст. 30, п.«г» ч. 4 ст.
# 228-1 УК РФ, \nУСТАНОВИЛ:\n************ ****** ******** совершил
#          LO
# покушение на незаконный сбыт наркотических средств, то есть умышленные
#  действия, непосредственно направленные на незаконный сбыт
# наркотических средств, совершенные группой лиц по предварительному
# сговору, в крупном размере, при этом преступление не было доведено до
# конца по не зависящим от него обстоятельствам, а именно:\nТак
# ************ А.А., с целью быстрого и незаконного материального
# обогащения, из корыстных побуждений, имея преступный умысел,
# направленный на незаконный сбыт наркотических средств группой лиц по
# предварительному сговору, в крупном размере, осознавая общественную
# опасность последствий своих действий и желая их наступления, в
# нарушение ст. ст. 5, 8, 14, 20 и 24 Федерального Закона РФ от 8 января
#                                                         LO
#  1998 года № 3-ФЗ «О наркотических средствах и психотропных
# веществах», в неустановленное время и месте, в период до 17 часов 59
# минут 16 сентября 2015 года, вступил в предварительный преступный
# сговор с неустановленными соучастниками, с целью незаконного
# приобретения и последующего умышленного и незаконного сбыта
# наркотических средств, в крупном размере, распределили между собой
# преступные роли каждого и разработали преступный план. \nВо исполнение
#  своего совместного преступного плана, согласно распределению ролей,
# один из его неустановленных соучастников, в неустановленном время и
# месте, в период до 17 часов 59 минут 16 сентября 2015 года, при
# неустановленных обстоятельствах, в нарушение Федерального закона РФ от
#                                                                  LO
#  8 января 1998 года № 3-ФЗ «О наркотических средствах и психотропных
# веществах» незаконно приобрел у неустановленного  лица наркотическое
# средство – героин, в крупном размере, расфасованное в сто пятьдесят
# один сверток из полимерного материала общей массой 293,25 г.,
# упакованные в сверток из полимерного материала с веществом, после
# чего, второй неустановленный соучастник ************а А.А., продолжая
#                                                       PER─
# реализовывать совместный с последним преступный умысел, поместил
# указанный сверток с наркотическим средством в тайник, оборудованный
# возле одиннадцатого дерева от начала зеленого забора на парковке,
# возле ресторана «Чайхона» по адресу: г.Москва, ул.Первомайская, д.
#                  ORG────               LOC───
# 106а, о месте нахождения которого сообщил ************у А.А. в ходе
#                                                         PER─
# телефонного разговора первый неустановленный соучастник.\nПродолжая
# реализовывать совместный с соучастниками преступный умысел, в
# совместных с соучастниками интересах, ************ А.А. 16 сентября
#                                                    PER─
# 2015 года, в 17 часов 59 минут прибыл по вышеуказанному адресу, где
# забрал из вышеуказанного тайника сверток со ста пятьюдесятью одним
# свертком из полимерного материала, с находящимся внутри каждого
# свертка наркотическим средством - героин, общей массой 293,25 г., о
# чем сообщил в ходе телефонного разговора своему первому
# неустановленному соучастнику, после чего ************ А.А. убрал
#                                                       PER─
# вышеуказанный сверток с наркотическим средством – героин, в левый
# карман джинсовых брюк одетых на нём, которое хранил при себе, и данное
#  наркотическое средство по указанию своего первого неустановленного
# соучастника, с целью дальнейшего сбыта указанного наркотического
# средства неустановленным лицам через «закладку» должен был направиться
#  по адресу, где совместно и согласованно, по указанию второго,
# неустановленного соучастника, планировал поместить наркотические
# средства в «закладки» в неустановленных местах, однако ************
# А.А. и его неустановленные соучастники не смогли осуществить свой
# PER─
# преступный умысел до конца, по не зависящим от них обстоятельствам,
# так как в 18 часов 10 минут 16 сентября 2015 года ************ А.А.
#                                                                PER─
# был задержан сотрудниками 2 отдела Службы по ВАО ФСКН России по
#                                    ORG────── LOC ORG─ LOC───
# г.Москве в ходе проведенного оперативно – розыскного мероприятия
#   LOC───
# «Наблюдение» по адресу: г.Москва, ул.Первомайская, д. 106а. \nДалее,
#  ORG───────               LOC───
# 16 сентября 2015 года, в период времени с 19 часов 25 минут по 20
# часов 10 минут, в помещении Службы по ВАО ФСКН России по г. Москве,
#                             ORG───    LOC ORG─ LOC───       LOC───
# расположенном по адресу: г. Москва, ул. Буженинова, д. 12, в ходе
#                             LOC───
# проведения личного досмотра, из левого кармана джинсовых штанов,
# одетых на ************е А.А., был обнаружен и изъят сверток из
#                         PER─
# полимерного материала, внутри которого находился 151 (сто пятьдесят
# один) расфасованный в полимерный материал сверток, с веществом в виде
# порошка и комков внутри каждого свертка, которое, согласно заключению
# эксперта №  Э-1/2317-15 от 16 октября 2015 года является наркотическим
#  средством – героин, и которое, согласно Постановлению Правительства
# Российской Федерации от 30 июня 1998 года № 681 «Об утверждении
# LOC─────────────────
# перечня наркотических средств, психотропных веществ и их прекурсоров,
# подлежащих контролю в Российской Федерации» (в редакции постановления
#                       LOC─────────────────
# Правительства Российской Федерации от 1 апреля 2016 года № 256),
# ORG────────── LOC─────────────────
# является наркотическим средством и входят в список наркотических
# средств, оборот которых в Российской Федерации запрещен, общей массой
#                           LOC─────────────────
# 293,25 г. из ста пятидесяти одного свертка, что согласно Постановлению
#  Правительства РФ от 1 октября 2012 года № 1002 «Об утверждении
#                LO
# значительного, крупного и особо крупного размеров наркотических
# средств и психотропных веществ, а также значительного, крупного и
# особо крупного размеров для растений, содержащих наркотические
# средства или психотропные вещества, либо их частей, содержащих
# наркотические средства или психотропные вещества, для целей статей
# 228, 228¹, 229 и 229¹ УК РФ», является крупным размером. \nТаким
#                          LO
# образом, ************ А.А. и его неустановленные соучастники, действуя
#                       PER─
#  совместно и согласованно, не довели свой совместный преступный
# умысел, направленный на незаконный сбыт наркотических средств, в
# крупном размере до конца, по не зависящим от них обстоятельствам, так
# как ************ А.А. был задержан сотрудниками 2 отдела Службы по ВАО
#                  PER─                                    ORG────── LOC
#  ФСКН России по г. Москве в ходе проведенного оперативно – розыскного
#  ORG─ LOC───       LOC───
# мероприятия «Наблюдение» по адресу: г. Москва, ул. Первомайская, д.
#              ORG───────                LOC───
# 106а, и вышеуказанное наркотическое средство было изъято в ходе
# проведения личного досмотра ************а А.А.\nДопрошенный в судебном
#                                           PER──────────────
#  заседании подсудимый вину признал частично, подтвердил фактические
# обстоятельства, изложенные выше, показал, что приобрел и хранил для
# собственного употребления наркотическое средство общим весом 293,25
# г., которое 16 сентября 2015 года было обнаружено и изъято при
# изложенных обстоятельствах,  отрицал умысел на покушение на сбыт.
# \nСуд, проведя судебное следствие, выслушав судебные прения и
# последнее слово подсудимого, считает, что в судебном заседании  вина
# ************а А.А. в инкриминируемом преступлении доказана следующими
#               PER─
# исследованными в судебном заседании доказательствами:\n- показаниями
# ************а А.А. на предварительном следствии, согласно которым
#               PER─
# извлек из закладки  сверток  с героином  массой 293,25 г., с целью
# дальнейшего сбыта, которое 16 сентября 2015 года было обнаружено и
# изъято при изложенных обстоятельствах;\n- показаниями свидетелей
# Биткова А.Ю.  и Орел И.В., понятых, в основном аналогичными, согласно
# PER─────────    PER──────
# которым 16 сентября 2015 года у ************а А.А. при личном досмотре
#                                               PER─
#   изъяты: из левого кармана джинс - полимерный сверток со 151
# свертками из полиэтилена, с веществом, мобильные телефоны «Самсунг» и
#                                                            ORG────
# «Сони Эриксон»,  сим-карты, шприц, два пузырька. ************ А.А.
#                                                               PER─
# пояснил, что в 151 свертках - наркотическое средство, героин, которое
# извлек из закладки  с целью  сбыта. Процедура досмотра снималась на
# видеокамеру;\n- показаниями свидетеля Русинова А.А., согласно которым
#                                       PER──────────
# 16 сентября 2015 года, в вечернее время, он, Русинов А.А., и
#                                              PER─────────
# ************ А.А., по предложению последнего,  подошли к дому 106 по
#              PER─
# ул. Первомайской г.Москвы,  ресторану  «Чайхана», где  ************
#                    LOC───               ORG────
# А.А., подняв что-то около дерева, положил в левый карман джинс. Около
# PER─
# дома 106А по ул. Первомайская г. Москвы были задержаны полицией,
#                                  LOC───
# доставлены  по адресу: г. Москва, ул. Буженинова, д.12, где проведен
#                           LOC───
# личный досмотр, получены срезы ногтевых пластин, смывы;\n- показаниями
#  свидетелей Прасолова Д.А., Кормилицына Д.А., Лукашенко А.А.,
#             PER───────────  PER─────────────  PER───────────
# полицейских, в основном аналогичными, согласно которым 16 сентября
# 2015 года в рамках ОРМ «Наблюдение» по адресу: г. Москва, ул.
#                    ORG─────────────               LOC───
# Первомайская, д. 106а задержан ************ А.А. В ходе досмотра у
# ************а А.А. изъяты: из левого кармана джинс полимерный сверток
#               PER─
# со 151 свертками из полиэтилена, с веществом, также изъяты мобильные
# телефоны «Самсунг» и «Сони Эриксон», сим-карты, шприц, два пузырька.
#           ORG────
# ************ А.А. пояснил, что в 151 свертке наркотическое средство -
#              PER─
# героин, которое извлек из закладки  с целью  сбыта, мобильные телефоны
#  принадлежат ему, ************у А.А., рюкзак - Русинову А.А. Лукашенко
#                                 PER─           PER────────────────────
#  А.А. выдал Кормилицыну Д.А. видеокамеру. При осмотре  обнаружен
#  PER─       PER─────────────
# видеофайл с личным досмотром ************а А.А.;\n- протоколом очной
#                                            PER─
# ставки между обвиняемым и свидетелем Русиновым А.А., в ходе проведения
#                                      PER───────────
#  которой ************ А.А. дал показания аналогичные ранее данным на
#                       PER─
# предварительном следствии, Русинов А.А. – аналогичные изложенным выше
#                            PER─────────
#   (л.д. 82-86);\n- актом досмотра и изъятия, согласно которым 16
# сентября 2015 года, по адресу: г. Москва, ул. Буженинова д. 12, в
#                                   LOC───
# присутствии понятых, в ходе проведения личного досмотра из левого
# кармана джинс ************а А.А. изъят сверток  со 151 свертками из
#                             PER─
# полимерного материала, с веществом в виде порошка светлого цвета,
# также изъяты мобильные телефоны «SONY ERICSSON»,  IMEI:
#                                  ORG──────────
# 3559901-570169-9 с сим-картой оператора сотовой связи «Билайн»,
#                                                        ORG───
# «Samsung»,  IMEI: 357795/05/044571/1 с сим-картой оператора сотовой
#  ORG────
# связи «Мегафон» (л.д.15-20);\n- актом осмотра и копирования видео-
#        ORG────
# материалов, согласно которого по адресу: г.Москва, ул.Буженинова, д.12
#                                            LOC───
#  Лукашенко А.А. выдана цифровая видеокамера Panasonic HC-V11ЕЕ, камера
#  PER───────────                             ORG──────
#  осмотрена, обнаруженная информация перекопирована на диск DVD-R (л.д.
#  25);\n- протоколами осмотра предметов, согласно которым осмотрены:
# конверты и полимерный пакет, поступившие с экспертизы, в ходе осмотра
# не вскрывались; конверты с мобильными телефонами, шприцем, два
# пузырька, диск формата DVD R № MFP 696SKO222264 с видеозаписью личного
#  досмотра ************а А.А.; компакт диски «Smart Track» CD-R 52х  с
#                         PER─
# записями ОРМ «ПТП»   (л.д.106-108,114-115,160-168);\n- заключением
#          ORG──────
# химической судебной экспертизы №  Э-1/2317-15, согласно которому
# вещества в виде порошка и комков светло-бежевого цвета из 151
# упаковки, изъятые у ************а А.А., - наркотическое средство,
#                                   PER─
# героин, массой 293,15 г. После экспертизы - масса 290,13 г.
# (л.д.97-103);\n- рапортом об обнаружении признаков преступления в
# действиях ************а А.А. (л.д. 3);\n- справкой об исследовании №
#                         PER─
# И-1/1657, согласно которой в пакете: 151  сверток из полимерного
# материала, в каждом   -  сверток  с веществом в виде порошка и комков.
#  На исследование отбиралась представительная проба по 0,01 г от десяти
#  свертков. Общая масса исследованных веществ 20,05 г. Установлено, что
#  в составе исследуемых веществ содержится героин (л.д. 51);\n-
# протоколом осмотра места происшествия, согласно которого осмотрен
# участок местности по адресу: г. Москва, ул. Первомайская, д. 106а,
#                                 LOC───
# возле одиннадцатого дерева от начала забора на парковке ресторана
# «Чайхана», ничего не изымалось (л.д. 205-206);\n- постановлением о
#  ORG────
# признании и приобщении в качестве вещественных доказательств: героина,
#  изъятого в ходе личного досмотра ************а А.А, срезов ногтевых
#                                                 PER
# пластин, смывов, компакт-дисков, мобильный телефон (л.д.109-110,
# 117-118).\nОценивая вышеприведенные доказательства в их совокупности и
#  признавая их относимыми, допустимыми доказательствами по делу,
# существенных противоречий не содержащих, достаточными, суд приходит к
# выводу о доказанности вины ************а А.А.  в совершении
#                                          PER─
# преступления, описанного в приговоре выше, в связи с этим суд
# квалифицирует действия ************а А.А. по ч.3 ст.30, п.«г» ч.4
#                                      PER─
# ст.228-1 УК РФ, как покушение на незаконный сбыт наркотических
#             LO
# средств, то есть умышленные действия, непосредственно направленные на
# незаконный сбыт наркотических средств, совершенные группой лиц по
# предварительному сговору, в крупном размере, при этом, преступление не
#  было доведено до конца по не зависящим от него обстоятельствам.\nПри
# этом суд не доверяет показаниям подсудимого в судебном заседании в
# части отрицания умысла на сбыт, считает, что показания в этой части
# опровергаются показаниями подсудимого на предварительном следствии,
# которым у суда оснований не доверять нет, так как они последовательны,
#  непротиворечивы, и согласуются со всеми исследованными в судебном
# заседании доказательствами. \nКроме того о наличии в действиях
# ************а А.А. умысла на сбыт наркотического средства по мнению
#               PER─
# суда свидетельствует объем изъятого наркотического средства, его
# расфасовка, то, что изъятие произошло в рамках ОРМ. \nПри назначении
#                                                ORG
# наказания суд учитывает характер и степень общественной опасности
# совершенного преступления, отнесенного законодателем к категории особо
#  тяжких, и данные о личности подсудимого, учитывая
# следующее.\nПодсудимый ************ А.А. не судим, вину частично
#                                     PER─
# признал,  страдает заболеваниями, мать пенсионерка, ветеран труда,
# также страдает заболеваниями, что суд признает в качестве
# обстоятельств, смягчающих наказание.\nОбстоятельств, отягчающих
# наказание, судом не установлено.\nС учетом конкретных обстоятельств
# дела, данных о личности подсудимого, суд приходит к выводу, что
# исправление ************а А.А. возможно только в условиях изоляции от
#                           PER─
# общества и, назначая наказание в виде лишения свободы, не усматривает
# оснований для применения ст.ст.15 ч.6,64,73 УК РФ.\nСуд, учитывая
#                                                LO
# смягчающие обстоятельства, полагает нецелесообразным назначение
# дополнительного наказания в виде штрафа.\nУчитывая, что подсудимый не
# работает, оснований для назначения дополнительного наказания в виде
# лишения права занимать определенные должности или заниматься
# определенной деятельностью, суд не усматривает.\nМестом отбывания
# наказания суд определяет исправительную колонию строгого режима. \nПри
#  постановлении приговора суд считает необходимым распорядиться судьбой
#  вещественных доказательств.\nНа основании изложенного и
# руководствуясь ст.ст.296-299, 307-309 УПК РФ,
#                                           LO
# суд\nПРИГОВОРИЛ:\n****************** признать виновным в совершении
# преступления, предусмотренного ч.3 ст. 30, п.«г» ч. 4 ст. 228-1 УК РФ
#                                                                    LO
# и  назначить уголовное наказание в виде лишения свободы сроком 10
# (десять) лет, с отбыванием наказания в исправительной колонии строгого
#  режима, с исчислением срока наказания с 01 декабря 2016
# года.\nЗасчитать в срок отбытия наказания срок содержания
# ************а Андрея Александровича  под стражей с  16 сентября 2015
#               PER──────────────────
# года до 01 декабря  2016 года.\nМеру пресечения осужденному
# *************************** до вступления приговора в законную силу
# оставить прежней, – содержание под стражей.\nВещественное
# доказательство: наркотическое средство, конверты, срезы ногтевых
# пластин, смывы, сим карту оператора «Мегафон», - уничтожить; компакт
#                                      ORG────
# диск, - оставить при материалах уголовного дела; мобильный телефон
# «Samsung» IMEI:357795/05/044571/1, - вернуть по принадлежности
#  ORG────
# ************у  А.А.   \n  Приговор может быть обжалован в Московский
#                PER────────────────                        ORG────────
# городской суд в течение 10 дней со дня его провозглашения, осужденным
# ─────────────
# в тот же срок со дня получения им копии приговора. В случае подачи
# апелляционной жалобы осужденный имеет право принять участие в
# рассмотрении дела судом апелляционной инстанции.\n\n\tСудья
#
# Духновская З.А. \n Ключевые слова: политология, история, экономика,
# военный бизнес, социум.\nПервые из существующих частных военных
# компаний (ЧВК) появились во время холодной войны. В то же время
# руководство Соединенных Штатов, Великобритании, Израиля и Южной Африки
#             LOC───────────────  LOC───────────  LOC────   LOC─────────
#  непосредственно способствовало их созданию. ЧВК могли поручать самую
# “грязную” работу (например, свержение законных правительств или
# организацию террористических группировок), а в случае неудачи
# открещиваться от них под предлогом того, что действовали коммерческие
# структуры.\nПосле окончания холодной войны спрос на услуги ЧВК стал
#                                                            ORG
# еще выше, в то время как взрывной рост предложения произошел из-за
# развала вооруженных сил на Западе и на Востоке: многие уволенные
#                            LOC───      LOC────
# военнослужащие вышли на рынок труда. \n К середине 2000-х годов
# количество ЧВК (речь идет о компаниях, оказывающих военные услуги, а
#            ORG
# не занимающихся логистикой) перевалило за сотню, численность их
# сотрудников достигла 2 миллионов человек, общая рыночная капитализация
#  превысила 20 миллиардов долларов, а объем предоставляемых услуг
# составил различные данные, от 60 до 180 миллиардов долларов в год.
# Наиболее известными и крупными ЧВК являются Hulliburton, Blackwater,
#                                ORG          ORG────────  ORG───────
# DynCorp, Logicon, Brown & Root, MPRI, Control Risks, Bechtel,
# ORG────  ORG────                ORG─  ORG──────────  ORG────
# ArmorGroup, Erinys, Sandline International, Международная оборона и
# ORG───────  ORG───  ORG───────────────────  ORG─────────────────────
# безопасность. Их услуги становятся все более разнообразными. Они
# ────────────
# занимаются разминированием, охраной важных объектов, организацией
# доставки различного рода грузов, разработкой планов военного
# строительства и боевого применения вооруженных сил (например, MPRI
# обучала хорватские вооруженные силы, которые осенью 1995 года
# разгромили и ликвидировали Сербскую Краину). В связи с этим
#                            LOC────────────
# официальные международные организации, включая ООН, иногда становятся
#                                                ORG
# работодателями для ЧВК. \n Услуги ЧВК тем более востребованы в
#                    ORG            ORG
# ситуации, когда большинство западных армий совершенно не готовы к
# проведению операций, подразумевающих серьезные потери. Но "частники"
# не считаются с убытками. Их потери не включены в официальную
# статистику стран, что очень удобно с точки зрения пропаганды. А в
# составе частных комитетов безопасности есть граждане и тех стран,
# которые официально не участвуют в войне и даже осуждают ее. Например,
# значительное количество наемников из Германии воюет в Ираке в рядах
#                                      LOC─────         LOC──
# американских и британских ЧВК, хотя немецкое руководство было и
#                           ORG
# остается одним из главных противников этой войны. А недавно стало
# известно, что немецкая частная охранная компания Asgaard German
#                                                  ORG────────────
# Security Group (о которой писали "Известия") направила в Сомали группу
# ──────────────                    ORG─────               LOC───
#  из 100 бойцов, которые будут воевать на стороне самопровозглашенного
# "президента Сомалийской Республики" Галадида Дармана, не получившего
#             LOC───────────────────  PER─────────────
# признания со стороны международного сообщества. \n Многие ЧВК
#                                                           ORG
# стремятся вербовать иностранцев. При этом предпочтение часто отдается
# гражданам Восточной Европы и бывшего СССР, а также развивающихся
#           LOC─────────────           LOC─
# стран, поскольку они отличаются хорошим уровнем подготовки и готовы
# воевать за меньшие деньги, чем граждане западных стран, чьи зарплаты в
#  зонах конфликтов могут достигать 20 тысяч долларов в месяц.
# Содержание наемника, кстати, стоит примерно в 10 раз дороже, чем
# солдата регулярной армии. \n Тот факт, что руководство государства
# формально не несет ответственности ни за потери ЧВК, ни за
#                                                 ORG
# преступления, совершенные их сотрудниками, приводит к их все большему
# вовлечению в войны с регулярными армиями или вместо них. Высокая
# стоимость отходит на второй план. Так, на сегодняшний день в Ираке
#                                                              LOC──
# задействовано более 400 ЧВК, общая численность их личного состава
# превышает 200 тысяч человек, то есть больше, чем войска США и их
#                                                         LOC
# союзников. Потери этих структур, по крайней мере, не меньше, чем у
# регулярных армий, но они не учитываются в официальной статистике. При
# этом ЧВК постоянно становятся участниками разного рода скандалов,
#      ORG
# поскольку их сотрудники ведут себя по отношению к гражданскому
# населению гораздо более жестко, чем "официальные" военнослужащие (в
# Ираке этим особенно славится Blackwater) \n В дополнение к
# LOC──                        ORG───────
# "фактической войне" ЧВК берут на себя все больше и больше
#                     ORG
# вспомогательных функций. Это все виды логистики (включая, например,
# приготовление пищи для военнослужащих и уборку казарм), инженерное
# дело, аэродромное обслуживание, транспортные услуги. В последнее время
#  разведка стала новой сферой деятельности для ЧВК (еще 10 лет назад
#                                               ORG
# такое и представить было невозможно). Таким образом, разработчики
# беспилотников Predator и Global Hawk, активно используемых
# американцами в Ираке и Афганистане, полностью занимаются их
#                LOC──   LOC────────
# обслуживанием и управлением, в том числе непосредственно в боевых
# ситуациях. Офицер регулярной армии только ставит общую задачу. Другие
# ЧВК занимаются сбором и анализом информации о террористических
# ORG
# группировках (в том числе через интернет), предоставляют для
# вооруженных сил услуги переводчиков с восточных языков. \n И
# постепенно количество перешло в качество. Недавно Пентагон обнаружил,
#                                                   ORG─────
# что вооруженные силы США в принципе больше не могут функционировать
#                      LOC
# без частных компаний, без них не может быть проведена даже
# ограниченная военная операция. Например, выяснилось, что поставки
# топлива для группировки союзников в Ираке были приватизированы на
#                                     LOC──
# 100%. Когда-то предполагалось, что привлечение частных собственников
# приведет к экономии военного бюджета. Теперь очевидно, что ситуация
# обратная: их услуги стоят намного дороже, чем если бы
# “государственные” военные выполняли ту же работу самостоятельно. Но,
# видимо, уже слишком поздно. Этот процесс стал необратимым. \n По пути
# создания ЧВК, к тому же действующих в интересах государства, может
#          ORG
# пойти Китай. По крайней мере, об этом говорилось в нашумевшей книге
#       LOC──
# "Китай недоволен", опубликованной год назад и рассматривавшейся как
#  LOC──
# описание плана глобальной военной экспансии КНР. Частные военные
#                                             LOC
# компании, названные в книге "компании по охране безопасности морей",
# должны стать важной частью этого расширения: "Мы можем сказать еще
# более четко: а именно, речь идет об использовании демобилизованных
# военнослужащих, уволившихся из армии. У нас есть такие преимущества,
# как люди и организации, и наши "компании по защите безопасности морей"
#  могут восстановить мир во многих регионах мира, где царят беззаконие
# и беспорядок. Как вы знаете, Китай очень активно занимается
#                              LOC──
# экономической экспансией в Азии и Африке, будет логично, если
#                            LOC─   LOC───
# китайские военные, формально считающиеся "частными владельцами",
# придут за инженерами и рабочими. \n\nВведение \n В истории русского
# народа было две Отечественные войны – 1812 и 1939-1945 годов. Они обе
# являются трагическими в истории России. \n Отечественная война 1812
#                                 LOC───
# года – это война между Французской и Российской империями, которая
#                        LOC────────   LOC─────────────────
# проходила на территории России. Несмотря на превосходство французской
#                         LOC───
# армии, под руководством Наполеона Бонапарта, "русским" войскам удалось
#                         PER────────────────
#  одержать победу, несмотря на огромные потери. \n Более того, русским
# удалось выйти победителями в этом тяжелом противостоянии. \n
# Отечественная война 1812 года произошла вследствие стремления
# Наполеона к мировому господству. До этого ему удалось подчинить почти
# PER──────
# всю Европу. Почему почти? Единственным противником Франции в Европе
#     LOC───                                         LOC────   LOC───
# оставалась Великобритания, которую Наполеон не мог подчинить силой
#            LOC───────────          PER─────
# оружия, но пытался континентальной блокадой. \n Стоит заметить, что в
# 1807 году между Францией и Россией был подписан Тильзитский мирный
#                 LOC─────   LOC────
# договор, по главному пункту которого российский император Александр 1
#                                                           PER──────
# обязывался поддерживать Наполеона в континентальной блокаде
#                         PER──────
# Великобритании. Тем не менее обе стороны понимали, что между Францией
# LOC───────────                                               LOC─────
# и Россией тоже начнётся война, так как было понятно, что Наполеон не
#   LOC────                                                PER─────
# остановится на покорении Европы. \n Именно поэтому страны начали
#                          LOC───
# наращивать свой военный потенциал.\nВ 1812 году Наполеон с Французской
#                                                 PER─────   ORG────────
#  армией, состоящей из 675 тысяч человек, вторгся на территорию
# ───────
# Российской Империи. Так для России и российского народа началась
# LOC───────────────          LOC───
# Отечественная война 1812 года. \n Эта война знаменита многими
# сражениями, но в этой работе речь в основном пойдёт о самом знаменитом
#  сражении - сражение при Бородино, что под Москвой. Эта война и битва
#                          LOC─────          LOC────
# будут рассмотрены с необычной стороны, а именно со стороны французской
#  армии. \n В работе будут присутствовать воспоминания французских
# военнослужащих о войне в России и в частности о Бородинском сражении.
#                          LOC───
# Я считаю, что очень интересно посмотреть на уже давно знакомые всем
# события с другой точки зрения и понять, что ощущали противники и как
# относились к происходящему. Хочу отметить, что воспоминания в основном
#  о Бородинском сражении, так как это самый яркий эпизод войны. \n
# Целью проекта является: посмотреть на события 1812 года глазами
# французов. \n Задачи: \n 1. Оживить память о событиях отечественной
# войны 1812 года. \n 2. Показать воспоминания французских
# военнослужащих. \n  3.Рассказать о нашем земляке - участнике войны
# 1812 года. \n Методы исследования: \n Так как я учусь в одиннадцатом
# классе, я провёл дебаты со своими сверстниками. В классе обучается 19
# человек. Был поставлен вопрос о героизме французских и русских солдат
# во время войны 1812 года и Бородинского сражения в частности. Мы
# столкнулись с не большим спором, результатом, которого стала данная
# диаграмма. Я отношусь к 30% и в подтверждение своей точки зрения я
# приведу в пример слова Французского императора Наполеона Бонапарта. \n
#                                                PER────────────────
#  «Из всех моих сражений самое ужасное то, что я дал под Москвой.
#                                                         LOC────
# Французы показали себя в нем достойными одержать победу, а русские –
# называться непобедимыми». \n Так же мной был проведён поиск и анализ
# информации содержащейся в данной работе. Вся информация,
# представленная в проекте, имеет своё подтверждение в литературе,
# находящейся в литературном списке в конце работы. \n Гипотеза: \n
# Целью работы является, как можно более правдиво рассказать о войне
# 1812 года, затронув при этом документы и воспоминания людей, которые
# непосредственно являлись участниками этой войны. Одним из главных
# источников информации по данной теме является дневник Цезаря Ложье де
#                                                       PER─────────────
# Беллекура, под названием «Дневник офицера великой армии в 1812 году».
# ─────────
# \n Данный источник интересен тем, что писался во время непосредственно
#  самой компании и захватывает, как быт солдат, так и события,
# произошедшие за время той войны.\nТак же в поиске информации
# использовался сборник: «Французы в России: 1812 год по воспоминаниям
#                                    LOC───
# современников-иностранцев». Данный сборник включает в себя отрывки из
# воспоминаний многих военнослужащих французской армии, прошедших войну
# 1812 года, чем собственно и ценен. \n В ходе исследовательской работы
# я столкнулся с очень интересными фактами, которые заинтересовали меня,
#  а именно в деревне Жорновка Тверской области, находилась усадьба
#                     LOC───── LOC─────────────
# Фёдора Фёдоровича Трефорта, генерал-майора, коменданта Твери, которая
# PER───────────────────────                             LOC──
# на сегодняшний день не сохранилась. \n К сожалению, территория усадьбы
#  распродана под дачные участки, но сохранилась церковь. В ходе
# исследования я пообщался с местными жителями, которые утверждают, что
# в период СССР местная церковь была клубом. \n Многие жители даже
#          LOC─
# сегодня наслышаны о том, что данная территория, когда-то принадлежала
# дворянскому роду Трефортов, член которого принимал участие во всех
#                  PER──────
# наполеоновских войнах. Подтверждением этому является могила,
# расположенная на церковном погосте, за которой ухаживают местные
# жители. \n Часть церкви (алтарь) перед семейным захоронением Трефортов
#                                                              PER──────
#  (вся церковь находится в очень плачевном состоянии), деревня
# Жорновка, Тверская область, 13.02.2021 г. \n Подходы к определению
# LOC─────  LOC─────────────
# англицизмов\n 12 июня 1812 года (по старому стилю) французская армия
# переправившись, через реку Неман в районе города Ковно, вторглась на
#                            LOC──                 LOC──
# территорию Российской Империи. Полумиллионная армия, включавшая в свой
#            LOC───────────────
#  состав не только французов, но и представителей почти всей Европы,
#                                                             LOC───
# окрылённая многочисленными победами и ведомая самим Наполеоном
#                                                     PER────────
# Бонапартом и многочисленными прославленными генералами и маршалами
# ──────────
# начала быстрое продвижение вглубь большой страны. \n Сильными
# сторонами французской армии являлись большая численность, современное
# вооружение, хорошее снабжение, накопленный с годами войн боевой опыт и
#  вера в непобедимость армии. Противостоящая этой силе русская армия на
#  момент начала войны насчитывала лишь одну треть от общего числа
# французской. \n В связи с недавно окончившейся русско-турецкой войной
# 1806-1812 годов, была разделена на три далеко расположенные друг от
# друга группировки (под командованием М. Б. Барклая-де-Толли , П. И.
#                                      PER───────────────────   PER───
# Багратиона и А. П. Тормасова). Александр I находился при штабе армии
# ──────────   PER────────────   PER────────
# Барклая. Первые удары французской армии приняли на себя, размещённые
# PER────
# на западной границе войска 1-вой армии Барклая-де-Толли и 2-ой армии
# Багратиона (всего 153 тысячи солдат). \n Начало войны было успешным
# LOC───────
# для Наполеона и его армии. Уже к 6 часам утра 12 (24) июня 1812 года
#     PER──────
# авангард французской армии вошёл в российский город Ковно, в течение
#                                                     LOC──
# следующих четырёх дней на берег у Ковно было переправлено ещё 220
#                                   LOC──
# тысяч солдат великой армии. \n Спустя пять дней южнее переправилась
# ещё одна группировка в составе 79 тысяч человек, под командованием
# вице-короля Италии Евгения Богарне. Одновременно ещё южнее Неман
#             LOC─── PER────────────                         LOC──
# пересекают ещё 4 корпуса(79 тысяч человек) под общим командованием
# короля Вестфалии Жерома Бонапарта. \n На северном направлении Неман
#        PER───────────────────────                             LOC──
# пересёк отдельный 10-тый корпус под командованием маршала Макдональда
#                                                           PER────────
# (32 тыс. солдат), который был нацелен на Петербург. На южном
#                                          LOC──────
# направлении через Буг начал переправу и вторжение отдельный
#                   LOC
# Австрийский корпус генерала Шварценберга (30—33 тысяч солдат).
# ORG───────────────          PER─────────
# \n\Быстрое продвижение французских войск заставило российскую армию,
# под командованием Барклая-де-Толли, отступать вглубь страны, уклоняясь
#                   PER─────────────
#  от генерального сражения, дабы сохранить силы и соединиться с армией
# Багратиона. В связи с численным перевесом противника встал вопрос о
# LOC───────
# быстром пополнении российской армии. \n Но в российской Империи не
#                                                         LOC────
# было всеобщей воинской повинности, армия набиралась посредству
# рекрутских наборов. Тогда император Александр 1 решился на необычный
#                                     PER──────
# шаг. 6 июля он издал манифест с призывом создать народное ополчение,
# так армия пополнилась людьми и появились первые партизанские отряды.
# \n Армии Барклая и Багратиона встретились под Смоленском в конце июля,
#                    PER───────                 LOC───────
#  достигнув, таким образом, первого стратегического успеха. \n 16
# августа по (новому стилю) французская армия (180 тысяч человек) под
# командованием Наполеона подошла к Смоленску. После соединения русских
#               PER──────           LOC──────
# армий, генералитет начал требовать от главнокомандующего Барклая-де-
#                                                          ORG────────
# Толли генерального сражения. В6 часов утра французская армия начала
# ─────
# штурм Смоленска. \n Русская армия сражалась стойко и бесстрашно, бой
#       LOC──────
# за город шёл два дня. Сражение за Смоленск ознаменовало развёртывание
#                                   LOC─────
# всенародной войны русского народа с неприятелем. Надежда Наполеона на
#                                                  PER──────────────
# молниеносную войну рухнула. После двух дней боёв Барклая-де-Толли
# отвёл войска из горящего города, чтобы избежать лишних потерь и уже
# заранее проигранного кровопролитного сражения. После взятия Смоленска
#                                                             LOC──────
# армия Наполеона двинулась на Москву. \n Между тем затянувшееся
#       LOC──────              LOC───
# отступление подогревала общественное недовольство. Так же сдача
# Смоленска усугубила положение. Поэтому 20 августа (по новому стилю)
# LOC──────
# император Александр 1 подписывает указ о назначении главнокомандующим
#           PER──────
# русскими войсками М.И. Кутузова. \n В то время Кутузову уже был 67-ой
#                   PER──────────                PER─────
# год. Полководец Суворовской школы, обладавший полувековым боевым
#                 ORG──────────────
# опытом, был уважаем как в рядах армии, так и в народе. Но всё же и ему
#  пришлось отступать, дабы выиграть время для сбора все наличных сил.
# \n По политическим и моральным причинам Кутузов не мог избежать
#                                         PER────
# генерального сражения. 3 сентября (по новому стилю) русская армия
# отступила к деревне Бородино. Дальнейшее отступление означало сдачу
#                     LOC─────
# Москвы. Так же французская армия за время наступления понесла потери и
# LOC───
#  сравнялась по численности с российской. Исходя из всех этих фактов,
# Кутузов решил дать генеральное сражение в 125 км от Москвы у деревни
# PER────                                             LOC───
# Бородино. \n 26 августа (7 сентября по новому стилю) 1812 года
# LOC─────
# произошло сражение, навсегда вошедшее в историю нашего народа.
# Бородинское сражение – крупнейшее сражение Отечественной войны 1812
# года между русской и французской армиями. \n Русская армия насчитывала
#  132 тысячи человек (в том числе 21 тысячу ополченцев). Французская
# насчитывала 135 тысяч солдат. План боя был прост- французы штурмуют
# линию из русских укреплений- флешей и редутов (карта поля боя указана
# ниже) \n Воспоминания французов\n Прежде чем поговорить о дальнейших
# событиях войны стоит отметить то, как французы входили в Россию. \n
#                                                          LOC───
# Прибыли в Кальварию. Никто не сомневался более в войне, но никакого
#           LOC──────
# официального приказа нам еще не было объявлено. Мы провели ночь в
# Кальварии, а наутро нам был прочитан приказ: \n «Солдаты! Вторая
# LOC──────
# польская война началась. Первая окончилась Фридландом и Тильзитом!..
#                                            PER───────   PER──────
# \n В Тильзите Россия поклялась быть в вечной дружбе с Францией и
#      LOC───── LOC───                                  LOC─────
# воевать с Англией. Она нарушает теперь свои клятвы; она не желает
#           LOC────
# более давать никакого объяснения своего странного требования, чтобы
# французские орлы не переходили Рейна, оставляя тем самым наших
#                                PER──
# союзников в ее распоряжении... Россия увлекаема роком, ее судьбы
#                                LOC───
# должны совершиться. \n Неужели она думает, что мы выродились? Разве мы
#  уже не солдаты Аустерлица? Она ставит нас между бесчестьем и войной:
#                 PER───────
# выбор ясен. Итак, идем вперед, перейдем Неман и внесем войну на ее
# территорию. \n Вторая война польская будет столь же славной, как и
# первая, но мир, который мы заключим, принесет с собой и гарантию: он
# положит предел тому гибельному влиянию, которое уже 50 лет оказывает
# Россия на дела Европы. Наполеон» \n Как описать впечатление,
# LOC───         LOC───
# произведенное на нас словами нашего вождя? Горделивый трепет волнует
# нас. Скольким победам предшествовали подобные воззвания! Нельзя
# сомневаться, что и нынешнее воззвание окажется таким же
# ...
#    PER────
# мягкий, ласковый, старческий. Мерцалов молчал, не оборачиваясь.— А я
#                               PER─────
# вот ребятишкам знакомым подарочки купил, — продолжал незнакомец (в
# руках у него было несколько свертков). — Да вот по дороге не утерпел,
# сделал круг, чтобы садом пройти: очень уж здесь хорошо.Мерцалов вообще
#                                                        PER─────
#  был кротким и застенчивым человеком, но при последних словах
# незнакомца его охватил вдруг прилив отчаянной злобы. Он резким
# движением повернулся в сторону старика и закричал, нелепо размахивая
# руками и задыхаясь:— Подарочки!.. Подарочки!.. Знакомым ребятишкам
#                      PER──────
# подарочки!.. А я... а у меня, милостивый государь, в настоящую минуту
# мои ребятишки с голоду дома подыхают... Подарочки!.. А у жены молоко
# пропало, и грудной ребенок целый день не ел... Подарочки!..Мерцалов
# ожидал, что после этих беспорядочных, озлобленных криков старик
# поднимется и уйдет, но он ошибся. Старик приблизил к нему свое умное,
# серьезное лицо с седыми баками и сказал дружелюбно, но серьезным
# тоном:— Подождите... не волнуйтесь! Расскажите мне все по порядку и
# как можно короче. Может быть, вместе мы придумаем что-нибудь для вас.В
#  необыкновенном лице незнакомца было что-то до того спокойное и
# внушающее доверие, что Мерцалов тотчас же без малейшей утайки, но
#                        PER─────
# страшно волнуясь и спеша, передал свою историю. Он рассказал о своей
# болезни, о потере места, о смерти ребенка, обо всех своих несчастиях,
# вплоть до нынешнего дня. Незнакомец слушал, не перебивая его ни
# словом, и только все пытливее и пристальнее заглядывал в его глаза,
# точно желая проникнуть в самую глубь этой наболевшей, возмущенной
# души. Вдруг он быстрым, совсем юношеским движением вскочил с своего
# места и схватил Мерцалова за руку. Мерцалов невольно тоже встал.—
#                 PER──────          PER─────
# Едемте! — сказал незнакомец, увлекая за руку Мерцалова. — Едемте
# PER───                                       PER──────
# скорее!.. Счастье ваше, что вы встретились с врачом. Я, конечно, ни за
#  что не могу ручаться, но... поедемте!Минут через десять Мерцалов и
#                                                          PER─────
# доктор уже входили в подвал. Елизавета Ивановна лежала на постели
#                              PER───────────────
# рядом со своей больной дочерью, зарывшись лицом в грязные,
# замаслившиеся подушки. Мальчишки хлебали борщ, сидя на тех же местах.
# Испуганные долгим отсутствием отца и неподвижностью матери, они
# плакали, размазывая слезы по лицу грязными кулаками и обильно проливая
#  их в закопченный чугунок. Войдя в комнату, доктор скинул с себя
# пальто и, оставшись в старомодном, довольно поношенном сюртуке,
# подошел к Елизавете Ивановне. Она даже не подняла головы при его
#           PER───────────────
# приближении.— Ну, полно, полно, голубушка, — заговорил доктор, ласково
#  погладив женщину по спине. — Вставайте-ка! Покажите мне вашу
# больную.И точно так же, как недавно в саду, что-то ласковое и
# убедительное, звучавшее в его голосе, заставило Елизавету Ивановну
#                                                 PER───────────────
# мигом подняться с постели и беспрекословно исполнить все, что говорил
# доктор. Через две минуты Гришка уже растапливал печку дровами, за
#                          PER───
# которыми чудесный доктор послал к соседям, Володя раздувал изо всех
#                                            PER───
# сил самовар, Елизавета Ивановна обворачивала Машутку согревающим
#              PER───────────────              PER────
# компрессом... Немного погодя явился и Мерцалов. На три рубля,
#                                       PER─────
# полученные от доктора, он успел купить за это время чаю, сахару, булок
#  и достать в ближайшем трактире горячей пищи. Доктор сидел за столом и
#  что-то писал на клочке бумажки, который он вырвал из записной книжки.
#  Окончив это занятие и изобразив внизу какой-то своеобразный крючок
# вместо подписи, он встал, прикрыл написанное чайным блюдечком и
# сказал:— Вот с этой бумажкой вы пойдете в аптеку... давайте через два
# часа по чайной ложке. Это вызовет у малютки отхаркивание...
# Продолжайте согревающий компресс... Кроме того, хотя бы вашей дочери и
#  сделалось лучше, во всяком случае пригласите завтра доктора
# Афросимова. Это дельный врач и хороший человек. Я его сейчас же
# PER───────
# предупрежу. Затем прощайте, господа! Дай бог, чтобы наступающий год
# немного снисходительнее отнесся к вам, чем этот, а главное — не
# падайте никогда духом.Пожав руки Мерцалову и Елизавете Ивановне, все
#                                  PER──────   PER───────────────
# еще не оправившимся от изумления, и потрепав мимоходом по щеке
# разинувшего рот Володю, доктор быстро всунул свои ноги в глубокие
#                 PER───
# калоши и надел пальто. Мерцалов опомнился только тогда, когда доктор
#                        PER─────
# уже был в коридоре, и кинулся вслед за ним.Так как в темноте нельзя
# было ничего разобрать, то Мерцалов закричал наугад:— Доктор! Доктор,
#                           PER─────
# постойте!.. Скажите мне ваше имя, доктор! Пусть хоть мои дети будут за
#  вас молиться!И он водил в воздухе руками, чтобы поймать невидимого
# доктора. Но в это время в другом конце коридора спокойный старческий
# голос произнес:— Э! Вот еще пустяки выдумали!.. Возвращайтесь-ка домой
#  скорей!Когда он возвратился, его ожидал сюрприз: под чайным блюдцем
# вместе с рецептом чудесного доктора лежало несколько крупных кредитных
#  билетов...В тот же вечер Мерцалов узнал и фамилию своего неожиданного
#                           PER─────
#  благодетеля. На аптечном ярлыке, прикрепленном к пузырьку с
# лекарством, четкою рукою аптекаря было написано: «По рецепту
# профессора Пирогова».Я слышал этот рассказ, и неоднократно, из уст
# самого Григория Емельяновича Мерцалова — того самого Гришки, который в
#        PER────────────────────────────               PER───
#  описанный мною сочельник проливал слезы в закоптелый чугунок с пустым
#  борщом. Теперь он занимает довольно крупный, ответственный пост в
# одном из банков, слывя образцом честности и отзывчивости на нужды
# бедности. И каждый раз, заканчивая свое повествование о чудесном
# докторе, он прибавляет голосом, дрожащим от скрываемых слез:— С этих
# пор точно благодетельный ангел снизошёл в нашу семью. Все
# переменилось. В начале января отец отыскал место, матушка встала на
# ноги, меня с братом удалось пристроить в гимназию на казенный счет.
# Просто чудо совершил этот святой человек. А мы нашего чудесного
# доктора только раз видели с тех пор — это когда его перевозили
# мертвого в его собственное имение Вишню. Да и то не его видели, потому
#                                   PER──
#  что то великое, мощное и святое, что жило и горело в чудесном докторе
#  при его жизни, угасло невозвратимо.\n Землемер Глеб Гаврилович
#                                                 PER─────────────
# Смирнов приехал на станцию «Гнилушки». До усадьбы, куда он был вызван
# ───────                     LOC─────
# для межевания, оставалось еще проехать на лошадях верст
# тридцать—сорок. (Ежели возница не пьян и лошади не клячи, то и
# тридцати верст не будет, а коли возница с мухой да кони наморены, то
# целых пятьдесят наберется.)\n— Скажите, пожалуйста, где я могу найти
# здесь почтовых лошадей? — обратился землемер к станционному
# жандарму.\n— Которых? Почтовых? Тут за сто верст путевой собаки не
# сыщешь, а не то что почтовых… Да вам куда ехать?\n— В Девкино, имение
#                                                       LOC────
# генерала Хохотова.\n— Что ж? — зевнул жандарм. — Ступайте за станцию,
#          PER─────
# там на дворе иногда бывают мужики, возят пассажиров.\nЗемлемер
# вздохнул и поплелся за станцию. Там, после долгих поисков, разговоров
# и колебаний, он нашел здоровеннейшего мужика, угрюмого, рябого,
# одетого в рваную сермягу и лапти.\n— Чёрт знает какая у тебя телега! —
#                                      PER─
#  поморщился землемер, влезая в телегу. — Не разберешь, где у нее зад,
# где перед…\n— Что ж тут разбирать-то? Где лошадиный хвост, там перед,
# а где сидит ваша милость, там зад…\nЛошаденка была молодая, но тощая,
#                                     PER──────
# с растопыренными ногами и покусанными ушами. Когда возница приподнялся
#  и стегнул ее веревочным кнутом, она только замотала головой, когда же
#  он выбранился и стегнул ее еще раз, то телега взвизгнула и задрожала,
#  как в лихорадке. После третьего удара телега покачнулась, после же
# четвертого она тронулась с места.\n— Этак мы всю дорогу поедем? —
# спросил землемер, чувствуя сильную тряску и удивляясь способности
# русских возниц соединять тихую, черепашью езду с душу выворачивающей
# тряской.\n— До-о-едем! — успокоил возница. — Кобылка молодая, шустрая…
#             PER──────
#  Дай ей только разбежаться, так потом и не остановишь… Но-о-о,
# прокля…тая!\nКогда телега выехала со станции, были сумерки. Направо от
#  землемера тянулась темная, замерзшая равнина, без конца и краю…
# Поедешь по ней, так наверно заедешь к чёрту на кулички. На горизонте,
# где она исчезала и сливалась с небом, лениво догорала холодная осенняя
#  заря… Налево от дороги в темнеющем воздухе высились какие-то бугры,
# не то прошлогодние стоги, не то деревня. Что было впереди, землемер не
#  видел, ибо с этой стороны всё поле зрения застилала широкая,
# неуклюжая спина возницы. Было тихо, но холодно, морозно.\n«Какая,
# однако, здесь глушь! — думал землемер, стараясь прикрыть свои уши
# воротником от шинели. — Ни кола ни двора. Не ровен час — нападут и
# ограбят, так никто и не узнает, хоть из пушек пали… Да и возница
# ненадежный… Ишь, какая спинища! Этакое дитя природы пальцем тронет,
# так душа вон! И морда у него зверская, подозрительная».\n— Эй, милый,
# — спросил землемер, — как тебя зовут?\n— Меня-то? Клим.\n— Что, Клим,
#                                                   PER─          PER─
# как у вас здесь? Не опасно? Не шалят?\n— Ничего, бог миловал… Кому ж
# шалить?\n— Это хорошо, что не шалят… Но на всякий случай все-таки я
# взял с собой три револьвера, — соврал землемер. — А с револьвером,
# знаешь, шутки плохи. С десятью разбойниками можно
# справиться…\nСтемнело. Телега вдруг заскрипела, завизжала, задрожала
# и, словно нехотя, повернула налево.\n«Куда же это он меня повез? —
# подумал землемер. — Ехал всё прямо и вдруг налево. Чего доброго,
# завезет, подлец, в какую-нибудь трущобу и… и… Бывают ведь случаи!»\n—
# Послушай, — обратился он к вознице. — Так ты говоришь, что здесь не
# опасно? Это жаль… Я люблю с разбойниками драться… На вид-то я худой,
# болезненный, а силы у меня, словно у быка… Однажды напало на меня три
# разбойника… Так что ж ты думаешь? Одного я так трахнул, что… что,
# понимаешь, богу душу отдал, а два другие из-за меня в Сибирь пошли на
#                                                       LOC───
# каторгу. И откуда у меня сила берется, не знаю… Возьмешь одной рукой
# какого-нибудь здоровилу, вроде тебя, и…. и сковырнешь.\nКлим оглянулся
#                                                         PER─
#  на землемера, заморгал всем лицом и стегнул по лошаденке.\n— Да,
# брат… — продолжал землемер. — Не дай бог со мной связаться. Мало того,
#  что разбойник без рук, без ног останется, но еще и перед судом
# ответит… Мне все судьи и исправники знакомы. Человек я казенный,
# нужный… Я вот еду, а начальству известно… так и глядят, чтоб мне кто-
# нибудь худа не сделал. Везде по дороге за кустиками урядники да
# сотские понатыканы… По… по…постой! — заорал вдруг землемер. — Куда же
# это ты въехал? Куда ты меня везешь?\n— Да нешто не видите?
# Лес!\n«Действительно, лес… — подумал землемер. — А я-то испугался!
# Однако, не нужно выдавать своего волнения… Он уже заметил, что я
# трушу. Отчего это он стал так часто на меня оглядываться? Наверное,
# замышляет что-нибудь… Раньше ехал еле-еле, нога за ногу, а теперь ишь
# как мчится!»\n— Послушай, Клим, зачем ты так гонишь лошадь?\n— Я ее не
#                           PER─
#  гоню. Сама разбежалась… Уж как разбежится, так никаким средствием ее
# не остановишь… И сама она не рада, что у ней ноги такие.\n— Врешь,
# брат! Вижу, что врешь! Только я тебе не советую так быстро ехать.
# Попридержи-ка лошадь… Слышишь? Попридержи!\n— Зачем?\n— А затем…
# затем, что за мной со станции должны выехать четыре товарища. Надо,
# чтоб они нас догнали… Они обещали догнать меня в этом лесу… С ними
# веселей будет ехать… Народ здоровый, коренастый… у каждого по
# пистолету… Что это ты всё оглядываешься и движешься, как на иголках?
# а? Я, брат, тово… брат… На меня нечего оглядываться… интересного во
# мне ничего нет… Разве вот револьверы только… Изволь, если хочешь, я их
#  выну, покажу… Изволь…\nЗемлемер сделал вид, что роется в карманах, и
# в это время случилось то, чего он не мог ожидать при всей своей
# трусости. Клим вдруг вывалился из телеги и на четвереньках побежал к
#           PER─
# чаще.\n— Караул! — заголосил он. — Караул! Бери, окаянный, и лошадь и
# телегу, только не губи ты моей души! Караул!\nПослышались скорые,
# удаляющиеся шаги, треск хвороста — и всё смолкло… Землемер, не
# ожидавший такого реприманда, первым делом остановил лошадь, потом
# уселся поудобней на телеге и стал думать.\n«Убежал… испугался, дурак…
# Ну, как теперь быть? Самому продолжать путь нельзя, потому что дороги
# не знаю, да и могут подумать, что я у него лошадь украл… Как быть?» —
# Клим! Клим!\n— Клим!.. — ответило эхо.\nОт мысли, что ему всю ночь
# PER─  PER─     PER─
# придется просидеть в темном лесу на холоде и слышать только волков,
# эхо да фырканье тощей кобылки, землемера стало коробить вдоль спины,
# словно холодным терпугом.\n— Климушка! — закричал он. — Голубчик! Где
#                              PER─────                   PER─────
# ты, Климушка?\nЧаса два кричал землемер, и только после того, как он
#     PER─────
# охрип и помирился с мыслью о ночевке в лесу, слабый ветерок донес до
# него чей-то стон.\n— Клим! Это ты, голубчик? Поедем!\n— У… убьешь!\n—
#                      PER─
# Да я пошутил, голубчик! Накажи меня господь, пошутил! Какие у меня
# револьверы! Это я от страха врал! Сделай милость, поедем!
# Мерзну!\nКлим, сообразив, вероятно, что настоящий разбойник давно бы
#          PER─
# уж исчез с лошадью и телегой, вышел из лесу и нерешительно подошел к
# своему пассажиру.\n— Ну, чего, дура, испугался? Я… я пошутил, а ты
# испугался… Садись!\n— Бог с тобой, барин, — проворчал Клим, влезая в
#                                                       PER─
# телегу. — Если б знал, и за сто целковых не повез бы. Чуть я не помер
# от страха…\nКлим стегнул по лошаденке. Телега задрожала. Клим стегнул
#             PER─                                         PER─
# еще раз, и телега покачнулась. После четвертого удара, когда телега
# тронулась с места, землемер закрыл уши воротником и задумался. Дорога
# и Клим ему уже не казались опасными.
#   PER─

# %%
import numpy
import sys
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint

# %%
file = text #Начало тренировки

# %%
def tokenize_words(input):
    # lowercase everything to standardize it
    input = input.lower()

    # instantiate the tokenizer
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(input)

    # if the created token isn't in the stop words, make it part of "filtered"
    filtered = filter(lambda token: token not in stopwords.words('russian'), tokens)
    return " ".join(filtered)

# %%
processed_inputs = tokenize_words(file)

# %%
chars = sorted(list(set(processed_inputs)))
char_to_num = dict((c, i) for i, c in enumerate(chars))

# %%
input_len = len(processed_inputs)
vocab_len = len(chars)
print ("Total number of characters:", input_len)
print ("Total vocab:", vocab_len)
# Out:
# Total number of characters: 160575
# Total vocab: 72

# %%
seq_length = 100
x_data = []
y_data = []

# %%
# loop through inputs, start at the beginning and go until we hit
# the final character we can create a sequence out of
for i in range(0, input_len - seq_length, 1):
    # Define input and output sequences
    # Input is the current character plus desired sequence length
    in_seq = processed_inputs[i:i + seq_length]

    # Out sequence is the initial character plus total sequence length
    out_seq = processed_inputs[i + seq_length]

    # We now convert list of characters to integers based on
    # previously and add the values to our lists
    x_data.append([char_to_num[char] for char in in_seq])
    y_data.append(char_to_num[out_seq])

# %%
n_patterns = len(x_data)
print ("Total Patterns:", n_patterns)
# Out:
# Total Patterns: 160475

# %%
X = numpy.reshape(x_data, (n_patterns, seq_length, 1))
X = X/float(vocab_len)

# %%
y = np_utils.to_categorical(y_data)

# %%
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(128))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
filepath = "model_Generating an annotation to the text.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
desired_callbacks = [checkpoint]

# %%
model.fit(X, y, epochs=10, batch_size=2048, callbacks=desired_callbacks)
# Out:
# Epoch 1/10
# 79/79 [==============================] - ETA: 0s - loss: 3.3087
# Epoch 1: loss improved from inf to 3.30872, saving model to model_Generating an annotation to the text.hdf5
# 79/79 [==============================] - 840s 10s/step - loss: 3.3087
# Epoch 2/10
# 79/79 [==============================] - ETA: 0s - loss: 3.2010
# Epoch 2: loss improved from 3.30872 to 3.20096, saving model to model_Generating an annotation to the text.hdf5
# 79/79 [==============================] - 697s 9s/step - loss: 3.2010
# Epoch 3/10
# 79/79 [==============================] - ETA: 0s - loss: 3.1892
# Epoch 3: loss improved from 3.20096 to 3.18920, saving model to model_Generating an annotation to the text.hdf5
# 79/79 [==============================] - 820s 10s/step - loss: 3.1892
# Epoch 4/10
# 79/79 [==============================] - ETA: 0s - loss: 3.1835
# Epoch 4: loss improved from 3.18920 to 3.18349, saving model to model_Generating an annotation to the text.hdf5
# 79/79 [==============================] - 979s 12s/step - loss: 3.1835
# Epoch 5/10
# 79/79 [==============================] - ETA: 0s - loss: 3.1789
# Epoch 5: loss improved from 3.18349 to 3.17891, saving model to model_Generating an annotation to the text.hdf5
# 79/79 [==============================] - 793s 10s/step - loss: 3.1789
# Epoch 6/10
# 79/79 [==============================] - ETA: 0s - loss: 3.1700
# Epoch 6: loss improved from 3.17891 to 3.17003, saving model to model_Generating an annotation to the text.hdf5
# 79/79 [==============================] - 705s 9s/step - loss: 3.1700
# Epoch 7/10
# 79/79 [==============================] - ETA: 0s - loss: 3.0868
# Epoch 7: loss improved from 3.17003 to 3.08676, saving model to model_Generating an annotation to the text.hdf5
# 79/79 [==============================] - 796s 10s/step - loss: 3.0868
# Epoch 8/10
# 79/79 [==============================] - ETA: 0s - loss: 2.9834
# Epoch 8: loss improved from 3.08676 to 2.98339, saving model to model_Generating an annotation to the text.hdf5
# 79/79 [==============================] - 617s 8s/step - loss: 2.9834
# Epoch 9/10
# 79/79 [==============================] - ETA: 0s - loss: 2.9435
# Epoch 9: loss improved from 2.98339 to 2.94347, saving model to model_Generating an annotation to the text.hdf5
# 79/79 [==============================] - 613s 8s/step - loss: 2.9435
# Epoch 10/10
# 79/79 [==============================] - ETA: 0s - loss: 2.9191
# Epoch 10: loss improved from 2.94347 to 2.91915, saving model to model_Generating an annotation to the text.hdf5
# 79/79 [==============================] - 613s 8s/step - loss: 2.9191

# %%
filename = "model_Generating an annotation to the text.hdf5"
model.load_weights(filename)
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
num_to_char = dict((i, c) for i, c in enumerate(chars))

# %%
start = numpy.random.randint(0, len(x_data) - 1)
pattern = x_data[start]
print("Annotation:")
print("\"", ''.join([num_to_char[value] for value in pattern]), "\"")
# Out:
# Annotation:
# " замуж приданного минимален согласилась стать супругой нелюбимого человека n 3 иван миронов бедный оф "
